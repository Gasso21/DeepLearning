# %% [markdown]
# # VGG16_ImageNet

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
from tensorflow import keras
from keras.applications.vgg16 import VGG16

base_model = VGG16(weights="imagenet",
                   include_top=False,
                   input_shape=(224,224,3)
                  )
base_model.summary()
# Out:
# Metal device set to: Apple M2
# 2023-03-19 14:28:17.761281: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-03-19 14:28:17.761367: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
for layer in base_model.layers:
    layer.trainable = False
    
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
from keras.layers import Dense, Flatten

last_layer = base_model.get_layer('block5_pool') # 마지막층에 접근
last_output = last_layer.output # 마지막 층의 출력을 다음 층의 입력으로

x = Flatten()(last_output)
x = Dense(5, activation='softmax', name='softmax')(x)

# %%
new_model = keras.Model(inputs=base_model.input, outputs=x)
new_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  softmax (Dense)             (None, 5)                 125445
#
# =================================================================
# Total params: 14,840,133
# Trainable params: 125,445
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

data_files = os.path.join(os.getcwd(),'transfer_lr_data_files')

train_imgs = np.load(data_files+'/target_images.npy')
train_labels = np.load(data_files+'/target_labels.npy')

test_imgs = np.load(data_files+'/test_images.npy')
test_labels = np.load(data_files+'/test_labels.npy')

print(train_imgs.shape)
print(train_labels[0])
# Out:
# (65, 224, 224, 3)
# [1. 0. 0. 0. 0.]

# %%
Dict = ['Hat', 'Cube', 'Card', 'Torch', 'screw']

# %%
n_train = train_imgs.shape[0]
n_test = test_imgs.shape[0]
idx = np.random.randint(0, n_train, size=9)
images = train_imgs[idx]
labels = train_labels[idx]

plt.figure(figsize=(5,5))
for i in range(len(idx)):
    plt.subplot(3, 3, i+1)
    plt.imshow(images[i], cmap='gray')
    plt.axis('off')
    plt.title("Label : {}".format(Dict[np.argmax(labels[i])]))
plt.show()

# %%
# %load_ext tensorboard

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
import math

# Model Checkpoints
model_name = 'transfer_lr.{epoch:02d}.h5'
filepath1 = os.path.join(os.getcwd(), 'transfer_lr')
if not os.path.isdir(filepath1):
    os.makedirs(filepath1)
    
filepath2 = os.path.join(filepath1, model_name)
checkpoints = ModelCheckpoint(filepath=filepath2,
                              monitor='val_accuracy',
                              verbose=1,
                              save_best_only=True
                             )

# Model lr_scheduler setting
initial_lrate = 0.01

def decay(epoch, steps=100):
    initial_lrate = 0.01
    drop = 0.96
    epochs_drop = 10
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    return lrate

lr_scheduler = LearningRateScheduler(decay)

sgd = keras.optimizers.SGD(learning_rate=initial_lrate, momentum=0.9, nesterov=False)

# Tensorboard
log_dir = 'log'
filepath3 = os.path.join(filepath1, log_dir)
tensorboard_cb = keras.callbacks.TensorBoard(filepath3, histogram_freq=1)

# Compile and training
batch_size = 20
epochs = 50

new_model.compile(loss='categorical_crossentropy',
                  optimizer=sgd,
                  metrics=['accuracy']
                 )

hist = new_model.fit(train_imgs, train_labels, batch_size=batch_size, epochs=epochs,
                     validation_data=(test_imgs, test_labels), 
                     callbacks=[checkpoints, lr_scheduler, tensorboard_cb],
                     verbose=2,
                     shuffle=True
                    )
# Out:
# Epoch 1/50
# 2023-03-19 14:28:26.847858: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-03-19 14:28:27.115284: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-03-19 14:28:28.223378: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_accuracy improved from -inf to 0.11111, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/transfer_lr/transfer_lr.01.h5
# 4/4 - 3s - loss: 8.6578 - accuracy: 0.2462 - val_loss: 70.6759 - val_accuracy: 0.1111 - lr: 0.0100 - 3s/epoch - 642ms/step
# Epoch 2/50
#
# Epoch 2: val_accuracy improved from 0.11111 to 0.55556, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/transfer_lr/transfer_lr.02.h5
# 4/4 - 2s - loss: 55.8064 - accuracy: 0.2462 - val_loss: 17.3733 - val_accuracy: 0.5556 - lr: 0.0100 - 2s/epoch - 480ms/step
# Epoch 3/50
#
# Epoch 3: val_accuracy improved from 0.55556 to 0.66667, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/transfer_lr/transfer_lr.03.h5
# 4/4 - 2s - loss: 37.7956 - accuracy: 0.2923 - val_loss: 33.4454 - val_accuracy: 0.6667 - lr: 0.0100 - 2s/epoch - 539ms/step
# Epoch 4/50
#
# Epoch 4: val_accuracy did not improve from 0.66667
# 4/4 - 2s - loss: 53.6967 - accuracy: 0.4462 - val_loss: 19.8457 - val_accuracy: 0.3333 - lr: 0.0100 - 2s/epoch - 492ms/step
# Epoch 5/50
#
# Epoch 5: val_accuracy did not improve from 0.66667
# 4/4 - 2s - loss: 30.8201 - accuracy: 0.4154 - val_loss: 40.3593 - val_accuracy: 0.3333 - lr: 0.0100 - 2s/epoch - 480ms/step
# Epoch 6/50
#
# Epoch 6: val_accuracy improved from 0.66667 to 0.88889, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/transfer_lr/transfer_lr.06.h5
# 4/4 - 2s - loss: 14.8167 - accuracy: 0.5385 - val_loss: 4.4646 - val_accuracy: 0.8889 - lr: 0.0100 - 2s/epoch - 505ms/step
# Epoch 7/50
#
# Epoch 7: val_accuracy improved from 0.88889 to 1.00000, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/CV_Model/transfer_lr/transfer_lr.07.h5
# 4/4 - 2s - loss: 8.8234 - accuracy: 0.6923 - val_loss: 0.0021 - val_accuracy: 1.0000 - lr: 0.0100 - 2s/epoch - 471ms/step
# Epoch 8/50
#
# Epoch 8: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.3943 - accuracy: 0.9538 - val_loss: 4.3888 - val_accuracy: 0.8889 - lr: 0.0100 - 2s/epoch - 475ms/step
# Epoch 9/50
#
# Epoch 9: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 6.2493 - accuracy: 0.8462 - val_loss: 0.0018 - val_accuracy: 1.0000 - lr: 0.0100 - 2s/epoch - 471ms/step
# Epoch 10/50
#
# Epoch 10: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.9022 - accuracy: 0.9692 - val_loss: 1.2081 - val_accuracy: 0.8889 - lr: 0.0096 - 2s/epoch - 478ms/step
# Epoch 11/50
#
# Epoch 11: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.8067 - accuracy: 0.9231 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0096 - 2s/epoch - 466ms/step
# Epoch 12/50
#
# Epoch 12: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0539 - accuracy: 0.9846 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0096 - 2s/epoch - 450ms/step
# Epoch 13/50
#
# Epoch 13: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.3824 - accuracy: 0.9692 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0096 - 2s/epoch - 453ms/step
# Epoch 14/50
#
# Epoch 14: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 1.4225e-05 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0096 - 2s/epoch - 452ms/step
# Epoch 15/50
#
# Epoch 15: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 1.2712e-08 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0096 - 2s/epoch - 450ms/step
# Epoch 16/50
#
# Epoch 16: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0096 - 2s/epoch - 451ms/step
# Epoch 17/50
#
# Epoch 17: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0096 - 2s/epoch - 446ms/step
# Epoch 18/50
#
# Epoch 18: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0096 - 2s/epoch - 462ms/step
# Epoch 19/50
#
# Epoch 19: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0096 - 2s/epoch - 441ms/step
# Epoch 20/50
#
# Epoch 20: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0092 - 2s/epoch - 444ms/step
# Epoch 21/50
#
# Epoch 21: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0092 - 2s/epoch - 443ms/step
# Epoch 22/50
#
# Epoch 22: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0092 - 2s/epoch - 469ms/step
# Epoch 23/50
#
# Epoch 23: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0092 - 2s/epoch - 479ms/step
# Epoch 24/50
#
# Epoch 24: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0092 - 2s/epoch - 475ms/step
# Epoch 25/50
#
# Epoch 25: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0092 - 2s/epoch - 502ms/step
# Epoch 26/50
#
# Epoch 26: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0092 - 2s/epoch - 451ms/step
# Epoch 27/50
#
# Epoch 27: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0092 - 2s/epoch - 454ms/step
# Epoch 28/50
#
# Epoch 28: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0092 - 2s/epoch - 454ms/step
# Epoch 29/50
#
# Epoch 29: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0092 - 2s/epoch - 434ms/step
# Epoch 30/50
#
# Epoch 30: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0088 - 2s/epoch - 450ms/step
# Epoch 31/50
#
# Epoch 31: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0088 - 2s/epoch - 461ms/step
# Epoch 32/50
#
# Epoch 32: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0088 - 2s/epoch - 472ms/step
# Epoch 33/50
#
# Epoch 33: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0088 - 2s/epoch - 473ms/step
# Epoch 34/50
#
# Epoch 34: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0088 - 2s/epoch - 480ms/step
# Epoch 35/50
#
# Epoch 35: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0088 - 2s/epoch - 467ms/step
# Epoch 36/50
#
# Epoch 36: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0088 - 2s/epoch - 440ms/step
# Epoch 37/50
#
# Epoch 37: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0088 - 2s/epoch - 453ms/step
# Epoch 38/50
#
# Epoch 38: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0088 - 2s/epoch - 456ms/step
# Epoch 39/50
#
# Epoch 39: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0088 - 2s/epoch - 443ms/step
# Epoch 40/50
#
# Epoch 40: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0085 - 2s/epoch - 484ms/step
# Epoch 41/50
#
# Epoch 41: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0085 - 2s/epoch - 447ms/step
# Epoch 42/50
#
# Epoch 42: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0085 - 2s/epoch - 444ms/step
# Epoch 43/50
#
# Epoch 43: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0085 - 2s/epoch - 438ms/step
# Epoch 44/50
#
# Epoch 44: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0085 - 2s/epoch - 463ms/step
# Epoch 45/50
#
# Epoch 45: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0085 - 2s/epoch - 456ms/step
# Epoch 46/50
#
# Epoch 46: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0085 - 2s/epoch - 444ms/step
# Epoch 47/50
#
# Epoch 47: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0085 - 2s/epoch - 441ms/step
# Epoch 48/50
#
# Epoch 48: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0085 - 2s/epoch - 456ms/step
# Epoch 49/50
#
# Epoch 49: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0085 - 2s/epoch - 438ms/step
# Epoch 50/50
#
# Epoch 50: val_accuracy did not improve from 1.00000
# 4/4 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0082 - 2s/epoch - 433ms/step

# %%
# %tensorboard --logdir $filepath3
# Out:
#       <iframe id="tensorboard-frame-7fba9ea52f4834c9" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-7fba9ea52f4834c9");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# # Fine_Tuning

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
from keras.preprocessing.image import load_img, img_to_array
from keras.applications.vgg16 import preprocess_input, decode_predictions, VGG16
import os

# %%
model = VGG16(weights="imagenet", include_top=True, input_shape=(224,224,3))

# %%
image = load_img(os.path.join(os.getcwd(), 'transfer_lr_data_files/image.jpeg'), target_size=(224,224))
image = img_to_array(image)

# %%
image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
# image = image.astype('float32')/255
image = preprocess_input(image)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.imshow(image[0], cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
yhat = model.predict(image)
label = decode_predictions(yhat)
label = label[0][0]
print('%s (%.2f%%)'%(label[1],label[2]*100))
# Out:
# German_shepherd (96.73%)
