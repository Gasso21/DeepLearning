# %% [markdown]
# # WGAN
#
# - **DCGAN의 문제점:**
#     1) discriminator와 generator 간의 균형을 유지하며 학습하기 어려움
#     2) 학습이 완료된 이후에도 mode dropping이 발생 (**mode collapsing**: 생성자가 하나의 최빈값에 치우쳐 변환)
# - **원인:** discriminator가 충분히 제 역할을 해주지 못해 모델이 최적점까지 학습되지 못함
#
#
# - **Wasserstein GAN의 차별점:**
#     1) discriminator 대신 새로 정의한 critic을 사용. discriminator는 Real/Fake를 판별하기 위해 'sigmoid'를 사용, output은 예측 확률값
#     2) critic은 EM(Earth Mover) distance로 부터 얻은 scalar값을 이용
#     3) EM distance는 확률분포 간의 거리를 측정하는 척도 (기존 척도인 KL divergence는 매우 strict하기 때문에 비연속적인 경우가 있어 학습에 어려움이 있음)

# %% [markdown]
# $
# \textbf{Entropy}: H(q) = - \sum\limits^C_{c=1}q(y_c)log(q(y_c)) \\
# \rightarrow C:\text{범주의 개수} \\
# \quad q:\text{Probability mass function} \\
# \textbf{Cross-entropy}: H_p(q) = - \sum\limits^C_{c=1}q(y_c)log(p(y_c)) \\
# \rightarrow q: \text{실제 분포} \\
# \quad p: \text{예측 분포} \\
# \quad \text{Training Data에서는 q를 알기 때문에 dissimilarity를 계산하는데 사용할 수 있음} \\
# \quad \textbf{Cross-entropy} > \textbf{Entropy} \\
# \textbf{Cross-Entropy of Loss Function}: -\cfrac{1}{n}\sum\limits^n_{i=1}\sum\limits^C_{c=1}L_{ic}log(P_{ic})
# $

# %% [markdown]
# $
# \textbf{Kullback-Leibler Divergence}: D_{KL}(q||p) = -\sum\limits^C_{c=1}q(y_c)[log(p(y_c))-log(q(y_c))] = H_p(q) - H(q) \\
# \rightarrow Hp(q) \geq H(q) \\
# \quad \text{예측분포 p를 실제분포 q에 가깝게 하는 것이 목표} \\
# \quad \text{cross-entropy를 최소화 시키는 것이 KL Divergence를 최소화시키는 것} \\
# \quad \text{이것이 불확실성을 제어하고자하는 예측모형의 실질적인 목적}
# $

# %% [markdown]
# $
# \textbf{KL - Divergence }\text{is not symmetric} \\
# \rightarrow D_{KL}(P||Q) \ne D_{KL}(Q||P) \\
# \quad \text{Can't use Distance Metric!}
# $

# %% [markdown]
# $
# \textbf{Jensen - Shannon Divergence}: JSD(P,Q) = \cfrac{1}{2}D_{KL}(P||M) + \cfrac{1}{2}D_{KL}(Q||M) \\
# \qquad \qquad \qquad \qquad \qquad \qquad where \; M = \cfrac{1}{2}(P+Q) \\
# \rightarrow JSD(P,Q) = JSD(Q, P) \\
# $

# %% [markdown]
# $
# \textbf{The Total Variation(TV) distance}: \delta(\mathbb{P}_r,\mathbb{P}_g) = \sup\limits_{A\in\sum}|\mathbb{P}_r(A) - \mathbb{P}_g(A)| \\
# \rightarrow \text{두 확률분포의 측정값이 벌어질 수 있는 가장 큰 값} \\
# $

# %% [markdown]
# $
# \textbf{Earth-Mover(EM) distance or Wasserstein-1}: W(\mathbb{P}_r,\mathbb{P}_g) = \inf\limits_{\gamma\in\prod(\mathbb{P}_r,\mathbb{P}_g)} \mathbb{E}_{(x,y)\thicksim\gamma}[\lVert x-y\rVert] \\
# \rightarrow \text{두 확률분포의 결합확률분포 } \prod(\mathbb{P}_r,\mathbb{P}_g) \text{ 중에서 x와 y 거리의 기대값을 가장 작게 추정한 값} \\
# \rightarrow \text{얼마나 많은 질량 }\gamma(x,y) \text{를 } d=\lVert x-y \rVert \text{만큼 옮겨야하는지에 대한 지표}
# $

# %% [markdown]
# ### GAN에서의 거리함수
# $
# L^{(D)} = - \int_x p_{data}(x)logD(x)dx - \int_x p_g(x)log(1-D(x))dx \\
# \rightarrow L^{(D)} = - \int_x(p_{data}(x)logD(x) + p_g(x)log(1-D(x)))dx \\
# \quad (y \rightarrow alogy + blog(1-y)) \\
# \rightarrow \cfrac{a}{a+b} \text{ 에서 최대값을 갖음} \\
# \rightarrow D^{*}(x) = \cfrac{p_{data}}{p_{data} + p_{g}} \\
# L^{(D^*)} = \mathbb{E}_{x\thicksim p_{data}}log\cfrac{p_{data}}{p_{data}+p_g} - \mathbb{E}_{x\thicksim p_{g}}log\cfrac{p_{g}}{p_{data}+p_g} \\
# \rightarrow 2log2 - D_{KL}\bigg[p_{data}\Vert \cfrac{p_{data}+p_g}{2}\bigg] - D_{KL}\bigg[p_{g}\Vert \cfrac{p_{data}+p_g}{2}\bigg] \\
# \rightarrow L^{(D^*)} = 2log2-2D_{JS}(p_{data} \Vert p_g) \\
# \rightarrow L^{(D^*)} \text{를 최소화 한다는 것은 } D_{JS}(p_{data} \Vert p_g) \text{를 최대화 한다는 것} \\
# \quad \text{즉, 판별기가 실제 데이터에서 가짜 데이터를 정확하게 분류한다는 것을 의미함}
# $

# %% [markdown]
# $
# \text{최적의 생성기는 생성기 분포가 실제 데이터 분포와 동일한 경우일 때 형성} \\
# \text{즉, } G^{(*)}(x) \rightarrow p_g = p_{data} \text{ 를 의미 }
# \text{최적의 생성기가 주워졌을 때, 최적의 판별기는} \\
# \rightarrow D^{(*)}(x) = \cfrac{p_{data}}{p_{data} + p_{g}} = \cfrac{1}{2} \\
# \rightarrow L^{(*)} = 2log2 = 0.60
# $

# %% [markdown]
# ### 두 분포가 겹치는 영역이 없는 경우
# $
# p_{data} = (x,y) \quad where \; x = 0, \; y \thicksim U(0,1) \\
# p_g = (x,y) \quad where \; x = \theta, y \thicksim U(0,1) \\
# $

# %% [markdown]
# $
# \cdot D_{KL}(p_g \Vert p_{data}) = \mathbb{E}_{x=\theta,y\thicksim U(0,1)}\log\cfrac{p_g(x,y)}{p_{data}(x,y)} = \sum 1 \log\cfrac{1}{0} = + \infty \\
# \cdot D_{JS}(p_g \Vert p_{data}) = \cfrac{1}{2}\mathbb{E}_{x=0, y\thicksim U(0,1)}\log\cfrac{p_{data}(x,y)}{\cfrac{p_{data}(x,y) + p_g{(x,y)}}{2}} + \cfrac{1}{2}\mathbb{E}_{x=\theta,y\thicksim U(0,1)}\log\cfrac{p_g(x,y)}{\cfrac{p_{data}(x,y)+p_g(x,y)}{2}} \\
# \qquad\qquad\qquad = \cfrac{1}{2}\sum1\log\cfrac{1}{\frac{1}{2}} + \cfrac{1}{2}\sum1\log\cfrac{1}{\frac{1}{2}} = \log2 \\
# \cdot W(p_{data},p_g) = |\theta|
# $

# %% [markdown]
# # MNIST

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np
import os
import math
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

from keras.layers import concatenate, Dense, Reshape, BatchNormalization, Activation, Conv2DTranspose
from keras.layers import Conv2D, LeakyReLU, Flatten

# %%
from keras import backend as K
from keras.models import load_model

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'),
#  PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
def plot_images(generator,
                noise_input,
                noise_label=None,
                noise_codes=None,
                show=False,
                step=0,
                model_name="gan"):
    """
    # Arguments
        generator (Model)
        noise_input (ndarray)
        show (bool)
        step (int)
        model_name (string)

    """
    filepath = os.path.join(model_name, "generated")
    os.makedirs(filepath, exist_ok=True)
    
    filename = os.path.join(filepath, "%05d.png" %step)
    
    rows = int(math.sqrt(noise_input.shape[0]))
    if noise_label is not None:
        noise_input = [noise_input, noise_label]
        if noise_codes is not None:
            noise_input += noise_codes

    images = generator.predict(noise_input, verbose=None)
    plt.figure(figsize=(2.2, 2.2))
    num_images = images.shape[0]
    image_size = images.shape[1]
    for i in range(num_images):
        plt.subplot(rows, rows, i + 1)
        image = np.reshape(images[i], [image_size, image_size])
        plt.imshow(image, cmap='gray')
        plt.axis('off')
    plt.savefig(filename)
    if show:
        plt.show()
    else:
        plt.close('all')

# %%
def build_generator(inputs, image_size):
    # Stack: BN-ReLU-Conv2DTranspose
    # inputs: z-vector(noise)
    # image_size: Target size
    # return: Model
    
    image_resize = image_size // 4
    kernel_size = 5
    layer_filters = [128, 64, 32, 1]
    
    x = Dense(image_resize*image_resize*layer_filters[0])(inputs)
    x = Reshape((image_resize, image_resize, layer_filters[0]))(x)
    
    for filters in layer_filters:
        # 1st, 2nd Conv layers: strides = 2
        # 3rd, 4th Conv layers: strides = 1
        if filters > layer_filters[-2]: #128, 64
            strides = 2
        else:
            strides = 1
        # BN-ReLU-Conv2DTranspose
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Conv2DTranspose(filters=filters,
                            kernel_size=kernel_size,
                            strides=strides,
                            padding='same'
                           )(x)
        
    x = Activation('sigmoid')(x)
    generator = keras.Model(inputs, x, name='generator')
    return generator

# %%
def build_discriminator(inputs, activation='sigmoid'):
    # BN으로는 수렴하지 않음
    # Stack: LeakyReLU-Conv2D
    # inputs: Image
    # return: Model
    
    kernel_size = 5
    layer_filters = [32, 64, 128, 256]
    
    x = inputs
    for filters in layer_filters:
        # 1st, 2nd, 3rd Conv layers: strides = 2
        # 4th Conv layers: strides = 1
        if filters == layer_filters[-1]:
            strides = 1
        else:
            strides = 2
        # LeakyReLU-Conv2D
        x = LeakyReLU(alpha=0.2)(x)
        x = Conv2D(filters=filters,
                   kernel_size=kernel_size,
                   strides=strides,
                   padding='same'
                  )(x)
    x = Flatten()(x)
    x = Dense(1)(x)
    x = Activation(activation)(x)
    discriminator = keras.Model(inputs, x, name='discriminator')
    return discriminator

# %%
def wasserstein_loss(y_label, y_pred):
    return -K.mean(y_label * y_pred)

# %%
def build_and_train_models():
    (x_train, _), (_, _) = keras.datasets.mnist.load_data()
    
    # Reshape & Normalize
    image_size = x_train.shape[1]
    x_train = np.reshape(x_train, [-1, image_size, image_size, 1])
    x_train = x_train.astype('float32')/255
    
    model_name = 'MNIST_WGAN'
    
    # Additional wgan params
    n_critic = 5
    clip_value = 0.01
    
    # Network Params
    latent_size = 100 # z-vector dimension
    batch_size = 64
    train_steps = 40000
    lr = 5e-5 # DCGAN: 2e-4
    # decay = 6e-8 # decays the lerning rate over time; DCGAN
    input_shape = (image_size, image_size, 1)

    # In Keras 2.11.0, 'decay' argument changed to 'weight_decay'
    # Discriminator model
    inputs = keras.Input(shape=input_shape, name='discriminator_input')
    #discriminator = gan.discriminator(inputs, activation='linear')
    discriminator = build_discriminator(inputs, activation='linear')
    optimizer = keras.optimizers.legacy.RMSprop(learning_rate=lr)
    discriminator.compile(loss=wasserstein_loss,
                          optimizer=optimizer,
                          metrics=['accuracy']
                         )
    discriminator.summary()
    
    # Generator model
    input_shape = (latent_size, )
    inputs = keras.Input(shape=input_shape, name='z_input')
    #generator = gan.generator(inputs, image_size)
    generator = build_generator(inputs, image_size)
    generator.summary()
    
    # Adversarial model
    #optimizer = keras.optimizers.RMSprop(learning_rate=lr*0.5, decay=decay*0.5,)
    discriminator.trainable = False
    ## Adversarial = Generator + Discriminator
    adversarial = keras.Model(inputs, discriminator(generator(inputs)), name='adversarial')
    adversarial.compile(loss=wasserstein_loss,
                        optimizer=optimizer,
                        metrics=['accuracy']
                       )
    adversarial.summary()
    
    models = (generator, discriminator, adversarial)
    params = (batch_size, latent_size, n_critic, clip_value, train_steps, model_name)
    train(models, x_train, params)

# %%
def train(models, x_train, params):
    # Discriminator와 Adversarial Model을 배치 단위로 번갈아 훈련
    ## Discriminator는 제대로 레이블이 붙은 진짜와 가짜 이미지를 가지고 훈련
    ## Adversarial는 진짜인 척하는 가짜 이미지로 훈련
    
    # GAN Model
    generator, discriminator, adversarial = models
    
    # Network Params
    # batch_size, latent_size, train_steps, model_name = params
    batch_size, latent_size, n_critic, clip_value, train_steps, model_name = params
    
    # Save Generator Images every 500 epochs
    save_interval = 500
    
    # Noise_Input
    noise_input = np.random.uniform(-1.0, 1.0, size=[16, latent_size]) # 16 x 100
    
    train_size = x_train.shape[0]
    real_labels = np.ones((batch_size, 1))
    for i in range(train_steps): # train_steps: 40,000
        
        # First - Discriminator Train
        # train discriminator n_critic times
        loss = 0
        acc = 0
        for _ in range(n_critic):
            # 1 batch of real (label=1.0) and fake images (label = -1.0)
            # randomly pick real images from dataset
            rand_indexes = np.random.randint(0, train_size, size=batch_size)
            real_images = x_train[rand_indexes]
            # generate fake images from noise using generator
            # generate noise using uniform distribution
            noise = np.random.uniform(-1.0, 1.0, size=[batch_size, latent_size])
            fake_images = generator.predict(noise, verbose=None)
        
            # train the discriminator network
            # real data label=1, fake data label=-1
            # instead of 1 combined batch of real and fake images,
            # train with 1 batch of real data first, then 1 batch of fake images.
            # this tweak prevents the gradient from vanishing due to opposite signs of real and fake data labels
            # and small magnitude of weights due to clipping.
            real_loss, real_acc = discriminator.train_on_batch(real_images, real_labels)
            fake_loss, fake_acc = discriminator.train_on_batch(fake_images, -real_labels)
            
            # accumulate average loss and accuracy
            loss += 0.5 * (real_loss + fake_loss)
            acc += 0.5 * (real_acc + fake_acc)
            
            # clip discriminator weights to satisfy Lipschitz constraint
            for layer in discriminator.layers:
                weights = layer.get_weights()
                weights = [np.clip(weight, -clip_value, clip_value) for weight in weights]
                layer.set_weights(weights)
        
        # average loss and accuracy per n_critic training iterations
        loss /= n_critic
        acc /= n_critic
        log = "%d: [discriminator loss: %f, acc: %f]" %(i, loss, acc)
        
        # Second - Adversarial Train
        # train the adversarial network for 1 batch
        # 1 batch of fake images with label=1.0
        # since the discriminator weights are frozen in adversarial network
        # only the generator is trained
        # generate noise using uniform distribution
        noise = np.random.uniform(-1.0, 1.0, size=[batch_size, latent_size])

        # train the adversarial network
        # note that unlike in discriminator training,
        # we do not save the fake images in a variable
        # the fake images go to the discriminator input of the adversarial
        # for classification
        # fake images are labelled as real
        # log the loss and accuracy
        loss, acc = adversarial.train_on_batch(noise, real_labels)
        log = "%s: [adversarial loss: %f, acc: %f]" %(log, loss, acc)
        if i % 100 == 0:
            print(log)
        
        # Show generator images per 500 epochs
        if (i+1) % save_interval == 0: # 500
            if (i+1) == train_steps: # 40,000
                show = True
            else:
                show = False
                
            # Make generator images per 500 epochs
            plot_images(generator,
                        noise_input=noise_input,
                        show=show,
                        step=(i+1),
                        model_name=model_name
                       )
    
    # save the model after training the generator
    # the trained generator can be reloaded for future MNIST digit generation
    generator.save(model_name + "/mnist_wgan.h5")

# %%
if __name__=='__main__':
    with tf.device('/GPU:1'):
        build_and_train_models()

"""
if __name__ == '__main__':
    parser = argparse.ArgumentParser()
    help_ = "Load generator h5 model with trained weights"
    parser.add_argument("-g", "--generator", help=help_)
    args = parser.parse_args() # args에 위 내용 저장
    if args.generator:
        generator = load_model(args.generator)
        gan.test_generator(generator)
    else:
        build_and_train_models()
"""
# Out:
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  discriminator_input (InputL  [(None, 28, 28, 1)]      0
#  ayer)
#
#  leaky_re_lu (LeakyReLU)     (None, 28, 28, 1)         0
#
#  conv2d (Conv2D)             (None, 14, 14, 32)        832
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 14, 14, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 64)          51264
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 7, 7, 64)          0
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 128)         204928
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 4, 4, 128)         0
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 256)         819456
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 1)                 4097
#
#  activation (Activation)     (None, 1)                 0
#
# =================================================================
# Total params: 1,080,577
# Trainable params: 1,080,577
# Non-trainable params: 0
# _________________________________________________________________
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  z_input (InputLayer)        [(None, 100)]             0
#
#  dense_1 (Dense)             (None, 6272)              633472
#
#  reshape (Reshape)           (None, 7, 7, 128)         0
#
#  batch_normalization (BatchN  (None, 7, 7, 128)        512
#  ormalization)
#
#  activation_1 (Activation)   (None, 7, 7, 128)         0
#
#  conv2d_transpose (Conv2DTra  (None, 14, 14, 128)      409728
#  nspose)
#
#  batch_normalization_1 (Batc  (None, 14, 14, 128)      512
#  hNormalization)
#
#  activation_2 (Activation)   (None, 14, 14, 128)       0
#
#  conv2d_transpose_1 (Conv2DT  (None, 28, 28, 64)       204864
#  ranspose)
#
#  batch_normalization_2 (Batc  (None, 28, 28, 64)       256
#  hNormalization)
#
#  activation_3 (Activation)   (None, 28, 28, 64)        0
#
#  conv2d_transpose_2 (Conv2DT  (None, 28, 28, 32)       51232
#  ranspose)
#
#  batch_normalization_3 (Batc  (None, 28, 28, 32)       128
#  hNormalization)
#
#  activation_4 (Activation)   (None, 28, 28, 32)        0
#
#  conv2d_transpose_3 (Conv2DT  (None, 28, 28, 1)        801
#  ranspose)
#
#  activation_5 (Activation)   (None, 28, 28, 1)         0
#
# =================================================================
# Total params: 1,301,505
# Trainable params: 1,300,801
# Non-trainable params: 704
# _________________________________________________________________
# Model: "adversarial"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  z_input (InputLayer)        [(None, 100)]             0
#
#  generator (Functional)      (None, 28, 28, 1)         1301505
#
#  discriminator (Functional)  (None, 1)                 1080577
#
# =================================================================
# Total params: 2,382,082
# Trainable params: 1,300,801
# Non-trainable params: 1,081,281
# _________________________________________________________________
# 0: [discriminator loss: 0.012704, acc: 0.000000]: [adversarial loss: -0.000376, acc: 0.000000]
# 100: [discriminator loss: -102.242099, acc: 0.315625]: [adversarial loss: -15.847325, acc: 1.000000]
# 200: [discriminator loss: -5.070751, acc: 0.410938]: [adversarial loss: -46.156277, acc: 1.000000]
# 300: [discriminator loss: -105.199589, acc: 0.500000]: [adversarial loss: -415.995789, acc: 1.000000]
# 400: [discriminator loss: -2.356679, acc: 0.000000]: [adversarial loss: 13.186539, acc: 0.000000]
# 500: [discriminator loss: -21.627078, acc: 0.000000]: [adversarial loss: 150.491409, acc: 0.000000]
# 600: [discriminator loss: -16.682247, acc: 0.020313]: [adversarial loss: 58.390171, acc: 0.000000]
# 700: [discriminator loss: -2.724749, acc: 0.032813]: [adversarial loss: 22.222004, acc: 0.125000]
# 800: [discriminator loss: -0.340483, acc: 0.382812]: [adversarial loss: -14.913737, acc: 1.000000]
# 900: [discriminator loss: -1.139350, acc: 0.018750]: [adversarial loss: -0.594370, acc: 0.515625]
# 1000: [discriminator loss: 1.289040, acc: 0.000000]: [adversarial loss: 16.316185, acc: 0.000000]
# 1100: [discriminator loss: -0.522335, acc: 0.037500]: [adversarial loss: 6.862693, acc: 0.000000]
# 1200: [discriminator loss: -5.048980, acc: 0.251563]: [adversarial loss: -29.887882, acc: 1.000000]
# 1300: [discriminator loss: 0.900963, acc: 0.000000]: [adversarial loss: 15.826555, acc: 0.000000]
# 1400: [discriminator loss: 0.075404, acc: 0.000000]: [adversarial loss: 4.333620, acc: 0.000000]
# 1500: [discriminator loss: 0.542238, acc: 0.000000]: [adversarial loss: 3.376998, acc: 0.000000]
# 1600: [discriminator loss: -0.019072, acc: 0.012500]: [adversarial loss: 0.072704, acc: 0.000000]
# 1700: [discriminator loss: -0.046255, acc: 0.012500]: [adversarial loss: 0.048443, acc: 0.000000]
# 1800: [discriminator loss: -0.037127, acc: 0.010937]: [adversarial loss: -0.026668, acc: 0.000000]
# 1900: [discriminator loss: -0.026256, acc: 0.000000]: [adversarial loss: 0.148016, acc: 0.000000]
# 2000: [discriminator loss: -0.018915, acc: 0.014063]: [adversarial loss: 0.067758, acc: 0.000000]
# 2100: [discriminator loss: -0.077726, acc: 0.031250]: [adversarial loss: 0.043564, acc: 0.000000]
# 2200: [discriminator loss: -0.113162, acc: 0.082812]: [adversarial loss: -0.010463, acc: 0.000000]
# 2300: [discriminator loss: -0.077074, acc: 0.101562]: [adversarial loss: -0.050869, acc: 0.031250]
# 2400: [discriminator loss: -0.076007, acc: 0.079687]: [adversarial loss: -0.025402, acc: 0.109375]
# 2500: [discriminator loss: -0.083957, acc: 0.095312]: [adversarial loss: -0.081831, acc: 0.000000]
# 2600: [discriminator loss: -0.040823, acc: 0.062500]: [adversarial loss: -0.031572, acc: 0.015625]
# 2700: [discriminator loss: -0.047984, acc: 0.029687]: [adversarial loss: 0.032248, acc: 0.000000]
# 2800: [discriminator loss: -0.054653, acc: 0.060937]: [adversarial loss: -0.118815, acc: 0.078125]
# 2900: [discriminator loss: -0.048915, acc: 0.015625]: [adversarial loss: -0.009707, acc: 0.015625]
# 3000: [discriminator loss: -0.038390, acc: 0.028125]: [adversarial loss: 0.061500, acc: 0.000000]
# 3100: [discriminator loss: -0.040744, acc: 0.039062]: [adversarial loss: -0.092239, acc: 0.015625]
# 3200: [discriminator loss: -0.035469, acc: 0.025000]: [adversarial loss: -0.002959, acc: 0.000000]
# 3300: [discriminator loss: -0.032277, acc: 0.006250]: [adversarial loss: -0.034112, acc: 0.000000]
# 3400: [discriminator loss: -0.034414, acc: 0.009375]: [adversarial loss: 0.010509, acc: 0.000000]
# 3500: [discriminator loss: -0.015498, acc: 0.010937]: [adversarial loss: -0.069907, acc: 0.000000]
# 3600: [discriminator loss: -0.033802, acc: 0.014063]: [adversarial loss: -0.074548, acc: 0.000000]
# 3700: [discriminator loss: -0.039733, acc: 0.020313]: [adversarial loss: -0.103703, acc: 0.015625]
# 3800: [discriminator loss: -0.031795, acc: 0.026562]: [adversarial loss: -0.066278, acc: 0.000000]
# 3900: [discriminator loss: -0.035999, acc: 0.009375]: [adversarial loss: -0.068052, acc: 0.000000]
# 4000: [discriminator loss: -0.003669, acc: 0.009375]: [adversarial loss: -0.086163, acc: 0.000000]
# 4100: [discriminator loss: -0.023151, acc: 0.001563]: [adversarial loss: -0.033888, acc: 0.000000]
# 4200: [discriminator loss: -0.020624, acc: 0.000000]: [adversarial loss: 0.009872, acc: 0.000000]
# 4300: [discriminator loss: -0.029970, acc: 0.003125]: [adversarial loss: -0.036757, acc: 0.000000]
# 4400: [discriminator loss: -0.032801, acc: 0.020313]: [adversarial loss: -0.014398, acc: 0.046875]
# 4500: [discriminator loss: -0.021112, acc: 0.000000]: [adversarial loss: 0.019741, acc: 0.000000]
# 4600: [discriminator loss: -0.020341, acc: 0.000000]: [adversarial loss: 0.046669, acc: 0.000000]
# 4700: [discriminator loss: -0.030587, acc: 0.000000]: [adversarial loss: -0.003523, acc: 0.000000]
# 4800: [discriminator loss: -0.022391, acc: 0.000000]: [adversarial loss: 0.018693, acc: 0.000000]
# 4900: [discriminator loss: -0.020148, acc: 0.004687]: [adversarial loss: -0.023974, acc: 0.015625]
# 5000: [discriminator loss: -0.015913, acc: 0.000000]: [adversarial loss: 0.017053, acc: 0.000000]
# 5100: [discriminator loss: -0.025517, acc: 0.000000]: [adversarial loss: 0.012842, acc: 0.000000]
# 5200: [discriminator loss: -0.027990, acc: 0.000000]: [adversarial loss: 0.083588, acc: 0.000000]
# 5300: [discriminator loss: -0.017900, acc: 0.000000]: [adversarial loss: 0.004095, acc: 0.000000]
# 5400: [discriminator loss: -0.031536, acc: 0.003125]: [adversarial loss: 0.008696, acc: 0.000000]
# 5500: [discriminator loss: -0.007620, acc: 0.009375]: [adversarial loss: -0.009419, acc: 0.015625]
# 5600: [discriminator loss: -0.014844, acc: 0.000000]: [adversarial loss: 0.017459, acc: 0.000000]
# 5700: [discriminator loss: -0.036600, acc: 0.000000]: [adversarial loss: 0.025374, acc: 0.000000]
# 5800: [discriminator loss: -0.023428, acc: 0.000000]: [adversarial loss: 0.038634, acc: 0.000000]
# 5900: [discriminator loss: -0.020050, acc: 0.000000]: [adversarial loss: 0.041163, acc: 0.000000]
# 6000: [discriminator loss: -0.021374, acc: 0.003125]: [adversarial loss: -0.043110, acc: 0.000000]
# 6100: [discriminator loss: -0.005859, acc: 0.000000]: [adversarial loss: 0.008114, acc: 0.000000]
# 6200: [discriminator loss: -0.015356, acc: 0.000000]: [adversarial loss: 0.007924, acc: 0.000000]
# 6300: [discriminator loss: -0.021459, acc: 0.020313]: [adversarial loss: -0.077871, acc: 0.015625]
# 6400: [discriminator loss: -0.015520, acc: 0.000000]: [adversarial loss: 0.026256, acc: 0.000000]
# 6500: [discriminator loss: -0.016409, acc: 0.012500]: [adversarial loss: -0.079165, acc: 0.000000]
# 6600: [discriminator loss: -0.026153, acc: 0.000000]: [adversarial loss: 0.051793, acc: 0.000000]
# 6700: [discriminator loss: -0.017360, acc: 0.000000]: [adversarial loss: 0.003968, acc: 0.000000]
# 6800: [discriminator loss: -0.019314, acc: 0.000000]: [adversarial loss: 0.032339, acc: 0.000000]
# 6900: [discriminator loss: -0.024010, acc: 0.000000]: [adversarial loss: 0.020700, acc: 0.000000]
# 7000: [discriminator loss: -0.017529, acc: 0.004687]: [adversarial loss: -0.010319, acc: 0.000000]
# 7100: [discriminator loss: -0.023086, acc: 0.000000]: [adversarial loss: -0.001564, acc: 0.000000]
# 7200: [discriminator loss: -0.015159, acc: 0.000000]: [adversarial loss: -0.025698, acc: 0.000000]
# 7300: [discriminator loss: -0.016584, acc: 0.000000]: [adversarial loss: -0.043693, acc: 0.000000]
# 7400: [discriminator loss: -0.007561, acc: 0.001563]: [adversarial loss: -0.031562, acc: 0.000000]
# 7500: [discriminator loss: -0.016573, acc: 0.000000]: [adversarial loss: 0.008652, acc: 0.000000]
# 7600: [discriminator loss: -0.016280, acc: 0.000000]: [adversarial loss: -0.006907, acc: 0.000000]
# 7700: [discriminator loss: -0.017260, acc: 0.000000]: [adversarial loss: 0.073558, acc: 0.000000]
# 7800: [discriminator loss: -0.022543, acc: 0.001563]: [adversarial loss: -0.032873, acc: 0.000000]
# 7900: [discriminator loss: -0.006643, acc: 0.014063]: [adversarial loss: -0.040826, acc: 0.000000]
# 8000: [discriminator loss: -0.013621, acc: 0.018750]: [adversarial loss: 0.032419, acc: 0.015625]
# 8100: [discriminator loss: -0.015757, acc: 0.000000]: [adversarial loss: 0.010668, acc: 0.000000]
# 8200: [discriminator loss: -0.033150, acc: 0.000000]: [adversarial loss: 0.035106, acc: 0.000000]
# 8300: [discriminator loss: -0.002875, acc: 0.004687]: [adversarial loss: 0.013041, acc: 0.000000]
# 8400: [discriminator loss: -0.011627, acc: 0.010937]: [adversarial loss: -0.010772, acc: 0.000000]
# 8500: [discriminator loss: -0.008055, acc: 0.025000]: [adversarial loss: -0.058145, acc: 0.000000]
# 8600: [discriminator loss: -0.012726, acc: 0.001563]: [adversarial loss: -0.051986, acc: 0.015625]
# 8700: [discriminator loss: -0.007013, acc: 0.000000]: [adversarial loss: 0.021512, acc: 0.000000]
# 8800: [discriminator loss: -0.014890, acc: 0.000000]: [adversarial loss: -0.006944, acc: 0.000000]
# 8900: [discriminator loss: -0.014458, acc: 0.000000]: [adversarial loss: -0.018987, acc: 0.000000]
# 9000: [discriminator loss: -0.012101, acc: 0.003125]: [adversarial loss: 0.000750, acc: 0.000000]
# 9100: [discriminator loss: -0.011213, acc: 0.000000]: [adversarial loss: 0.012260, acc: 0.000000]
# 9200: [discriminator loss: -0.014226, acc: 0.000000]: [adversarial loss: -0.014352, acc: 0.000000]
# 9300: [discriminator loss: -0.018521, acc: 0.000000]: [adversarial loss: 0.010575, acc: 0.000000]
# 9400: [discriminator loss: -0.010746, acc: 0.000000]: [adversarial loss: -0.007592, acc: 0.000000]
# 9500: [discriminator loss: -0.015753, acc: 0.000000]: [adversarial loss: -0.007520, acc: 0.000000]
# 9600: [discriminator loss: -0.006084, acc: 0.000000]: [adversarial loss: 0.012538, acc: 0.000000]
# 9700: [discriminator loss: -0.010152, acc: 0.000000]: [adversarial loss: -0.004356, acc: 0.000000]
# 9800: [discriminator loss: -0.011957, acc: 0.001563]: [adversarial loss: -0.002954, acc: 0.000000]
# 9900: [discriminator loss: -0.013025, acc: 0.006250]: [adversarial loss: -0.042977, acc: 0.015625]
# 10000: [discriminator loss: -0.006498, acc: 0.000000]: [adversarial loss: -0.051400, acc: 0.000000]
# 10100: [discriminator loss: -0.022090, acc: 0.000000]: [adversarial loss: 0.017751, acc: 0.000000]
# 10200: [discriminator loss: -0.003675, acc: 0.001563]: [adversarial loss: -0.022700, acc: 0.000000]
# 10300: [discriminator loss: -0.012311, acc: 0.000000]: [adversarial loss: 0.001454, acc: 0.000000]
# 10400: [discriminator loss: -0.015257, acc: 0.000000]: [adversarial loss: 0.028768, acc: 0.000000]
# 10500: [discriminator loss: -0.006877, acc: 0.000000]: [adversarial loss: -0.012751, acc: 0.000000]
# 10600: [discriminator loss: -0.008574, acc: 0.000000]: [adversarial loss: -0.023499, acc: 0.000000]
# 10700: [discriminator loss: -0.013008, acc: 0.000000]: [adversarial loss: 0.019276, acc: 0.000000]
# 10800: [discriminator loss: -0.018816, acc: 0.017188]: [adversarial loss: -0.026561, acc: 0.015625]
# 10900: [discriminator loss: -0.011569, acc: 0.000000]: [adversarial loss: -0.032891, acc: 0.000000]
# 11000: [discriminator loss: -0.004061, acc: 0.003125]: [adversarial loss: -0.013870, acc: 0.000000]
# 11100: [discriminator loss: -0.016639, acc: 0.001563]: [adversarial loss: 0.011131, acc: 0.000000]
# 11200: [discriminator loss: -0.009785, acc: 0.000000]: [adversarial loss: 0.017087, acc: 0.000000]
# 11300: [discriminator loss: -0.007994, acc: 0.003125]: [adversarial loss: -0.011988, acc: 0.000000]
# 11400: [discriminator loss: -0.010640, acc: 0.004687]: [adversarial loss: -0.053917, acc: 0.000000]
# 11500: [discriminator loss: -0.011886, acc: 0.018750]: [adversarial loss: 0.003529, acc: 0.015625]
# 11600: [discriminator loss: -0.008385, acc: 0.000000]: [adversarial loss: -0.018491, acc: 0.000000]
# 11700: [discriminator loss: -0.018950, acc: 0.000000]: [adversarial loss: 0.032185, acc: 0.000000]
# 11800: [discriminator loss: -0.010249, acc: 0.018750]: [adversarial loss: -0.049599, acc: 0.000000]
# 11900: [discriminator loss: -0.015467, acc: 0.000000]: [adversarial loss: -0.005042, acc: 0.000000]
# 12000: [discriminator loss: -0.008173, acc: 0.001563]: [adversarial loss: 0.029693, acc: 0.000000]
# 12100: [discriminator loss: -0.003342, acc: 0.000000]: [adversarial loss: -0.017621, acc: 0.000000]
# 12200: [discriminator loss: -0.009348, acc: 0.000000]: [adversarial loss: 0.001889, acc: 0.000000]
# 12300: [discriminator loss: -0.000391, acc: 0.001563]: [adversarial loss: -0.039462, acc: 0.000000]
# 12400: [discriminator loss: 0.001038, acc: 0.000000]: [adversarial loss: -0.041235, acc: 0.000000]
# 12500: [discriminator loss: -0.012570, acc: 0.001563]: [adversarial loss: -0.025103, acc: 0.000000]
# 12600: [discriminator loss: -0.010666, acc: 0.000000]: [adversarial loss: -0.004602, acc: 0.000000]
# 12700: [discriminator loss: -0.018349, acc: 0.000000]: [adversarial loss: -0.000752, acc: 0.000000]
# 12800: [discriminator loss: -0.018797, acc: 0.004687]: [adversarial loss: -0.050441, acc: 0.015625]
# 12900: [discriminator loss: -0.011717, acc: 0.000000]: [adversarial loss: -0.029124, acc: 0.000000]
# 13000: [discriminator loss: -0.010030, acc: 0.000000]: [adversarial loss: 0.000106, acc: 0.000000]
# 13100: [discriminator loss: -0.013240, acc: 0.010937]: [adversarial loss: -0.016736, acc: 0.015625]
# 13200: [discriminator loss: -0.009591, acc: 0.000000]: [adversarial loss: -0.010524, acc: 0.000000]
# 13300: [discriminator loss: -0.015130, acc: 0.001563]: [adversarial loss: -0.022562, acc: 0.000000]
# 13400: [discriminator loss: -0.015138, acc: 0.000000]: [adversarial loss: -0.024046, acc: 0.000000]
# 13500: [discriminator loss: -0.013027, acc: 0.001563]: [adversarial loss: 0.005325, acc: 0.000000]
# 13600: [discriminator loss: -0.007718, acc: 0.000000]: [adversarial loss: -0.023878, acc: 0.000000]
# 13700: [discriminator loss: -0.012049, acc: 0.000000]: [adversarial loss: -0.022079, acc: 0.000000]
# 13800: [discriminator loss: -0.022412, acc: 0.000000]: [adversarial loss: 0.009984, acc: 0.031250]
# 13900: [discriminator loss: -0.013436, acc: 0.000000]: [adversarial loss: -0.026134, acc: 0.000000]
# 14000: [discriminator loss: -0.010298, acc: 0.000000]: [adversarial loss: -0.061017, acc: 0.000000]
# 14100: [discriminator loss: -0.002383, acc: 0.000000]: [adversarial loss: -0.023090, acc: 0.000000]
# 14200: [discriminator loss: -0.005625, acc: 0.000000]: [adversarial loss: -0.007770, acc: 0.000000]
# 14300: [discriminator loss: -0.007163, acc: 0.000000]: [adversarial loss: -0.017548, acc: 0.000000]
# 14400: [discriminator loss: -0.005949, acc: 0.000000]: [adversarial loss: -0.045475, acc: 0.000000]
# 14500: [discriminator loss: 0.000134, acc: 0.001563]: [adversarial loss: -0.047136, acc: 0.000000]
# 14600: [discriminator loss: -0.006101, acc: 0.000000]: [adversarial loss: -0.013800, acc: 0.000000]
# 14700: [discriminator loss: -0.009832, acc: 0.000000]: [adversarial loss: -0.012518, acc: 0.000000]
# 14800: [discriminator loss: -0.006248, acc: 0.001563]: [adversarial loss: -0.077009, acc: 0.000000]
# 14900: [discriminator loss: -0.020926, acc: 0.000000]: [adversarial loss: -0.003327, acc: 0.000000]
# 15000: [discriminator loss: -0.001449, acc: 0.000000]: [adversarial loss: -0.013308, acc: 0.000000]
# 15100: [discriminator loss: -0.010983, acc: 0.001563]: [adversarial loss: -0.017024, acc: 0.000000]
# 15200: [discriminator loss: -0.006827, acc: 0.000000]: [adversarial loss: 0.011196, acc: 0.000000]
# 15300: [discriminator loss: -0.003785, acc: 0.000000]: [adversarial loss: -0.029426, acc: 0.000000]
# 15400: [discriminator loss: -0.006830, acc: 0.000000]: [adversarial loss: -0.071053, acc: 0.000000]
# 15500: [discriminator loss: -0.011702, acc: 0.000000]: [adversarial loss: -0.030720, acc: 0.000000]
# 15600: [discriminator loss: -0.005526, acc: 0.007812]: [adversarial loss: -0.037109, acc: 0.000000]
# 15700: [discriminator loss: 0.000350, acc: 0.007812]: [adversarial loss: -0.065701, acc: 0.000000]
# 15800: [discriminator loss: -0.006673, acc: 0.017188]: [adversarial loss: -0.090079, acc: 0.078125]
# 15900: [discriminator loss: -0.009017, acc: 0.000000]: [adversarial loss: -0.004157, acc: 0.000000]
# 16000: [discriminator loss: -0.008735, acc: 0.000000]: [adversarial loss: -0.047145, acc: 0.000000]
# 16100: [discriminator loss: -0.001243, acc: 0.000000]: [adversarial loss: -0.024637, acc: 0.000000]
# 16200: [discriminator loss: -0.002093, acc: 0.000000]: [adversarial loss: -0.039985, acc: 0.000000]
# 16300: [discriminator loss: -0.011170, acc: 0.010937]: [adversarial loss: 0.002409, acc: 0.046875]
# 16400: [discriminator loss: -0.008991, acc: 0.001563]: [adversarial loss: -0.067174, acc: 0.000000]
# 16500: [discriminator loss: -0.001790, acc: 0.000000]: [adversarial loss: -0.029575, acc: 0.000000]
# 16600: [discriminator loss: -0.005625, acc: 0.000000]: [adversarial loss: -0.026054, acc: 0.000000]
# 16700: [discriminator loss: 0.000431, acc: 0.000000]: [adversarial loss: -0.043873, acc: 0.000000]
# 16800: [discriminator loss: -0.014654, acc: 0.000000]: [adversarial loss: -0.039994, acc: 0.000000]
# 16900: [discriminator loss: 0.004448, acc: 0.001563]: [adversarial loss: -0.037761, acc: 0.000000]
# 17000: [discriminator loss: -0.012485, acc: 0.000000]: [adversarial loss: 0.012795, acc: 0.000000]
# 17100: [discriminator loss: -0.009076, acc: 0.000000]: [adversarial loss: -0.034082, acc: 0.000000]
# 17200: [discriminator loss: 0.001237, acc: 0.000000]: [adversarial loss: -0.044881, acc: 0.000000]
# 17300: [discriminator loss: -0.002381, acc: 0.000000]: [adversarial loss: -0.031424, acc: 0.000000]
# 17400: [discriminator loss: 0.001022, acc: 0.000000]: [adversarial loss: -0.018174, acc: 0.000000]
# 17500: [discriminator loss: -0.005698, acc: 0.000000]: [adversarial loss: -0.000599, acc: 0.000000]
# 17600: [discriminator loss: -0.009384, acc: 0.000000]: [adversarial loss: -0.054535, acc: 0.000000]
# 17700: [discriminator loss: -0.007340, acc: 0.000000]: [adversarial loss: -0.050865, acc: 0.000000]
# 17800: [discriminator loss: -0.000939, acc: 0.000000]: [adversarial loss: -0.026720, acc: 0.000000]
# 17900: [discriminator loss: -0.004077, acc: 0.000000]: [adversarial loss: -0.020524, acc: 0.000000]
# 18000: [discriminator loss: -0.002863, acc: 0.000000]: [adversarial loss: -0.038221, acc: 0.000000]
# 18100: [discriminator loss: -0.012938, acc: 0.000000]: [adversarial loss: -0.062378, acc: 0.000000]
# 18200: [discriminator loss: -0.003130, acc: 0.000000]: [adversarial loss: -0.015800, acc: 0.000000]
# 18300: [discriminator loss: -0.006124, acc: 0.000000]: [adversarial loss: -0.035947, acc: 0.000000]
# 18400: [discriminator loss: 0.001220, acc: 0.001563]: [adversarial loss: -0.003490, acc: 0.000000]
# 18500: [discriminator loss: -0.003936, acc: 0.000000]: [adversarial loss: -0.029881, acc: 0.000000]
# 18600: [discriminator loss: -0.003384, acc: 0.000000]: [adversarial loss: -0.036110, acc: 0.000000]
# 18700: [discriminator loss: -0.005082, acc: 0.000000]: [adversarial loss: -0.014109, acc: 0.000000]
# 18800: [discriminator loss: -0.000816, acc: 0.000000]: [adversarial loss: -0.028907, acc: 0.000000]
# 18900: [discriminator loss: -0.005672, acc: 0.000000]: [adversarial loss: -0.045125, acc: 0.000000]
# 19000: [discriminator loss: 0.002528, acc: 0.000000]: [adversarial loss: -0.006322, acc: 0.000000]
# 19100: [discriminator loss: -0.002985, acc: 0.000000]: [adversarial loss: 0.000673, acc: 0.000000]
# 19200: [discriminator loss: -0.009877, acc: 0.000000]: [adversarial loss: -0.018626, acc: 0.000000]
# 19300: [discriminator loss: -0.006589, acc: 0.000000]: [adversarial loss: -0.044026, acc: 0.000000]
# 19400: [discriminator loss: -0.003753, acc: 0.000000]: [adversarial loss: -0.016121, acc: 0.000000]
# 19500: [discriminator loss: -0.005193, acc: 0.000000]: [adversarial loss: -0.036979, acc: 0.000000]
# 19600: [discriminator loss: -0.002569, acc: 0.000000]: [adversarial loss: -0.050568, acc: 0.000000]
# 19700: [discriminator loss: -0.001032, acc: 0.000000]: [adversarial loss: -0.011683, acc: 0.000000]
# 19800: [discriminator loss: -0.001690, acc: 0.000000]: [adversarial loss: -0.018350, acc: 0.000000]
# 19900: [discriminator loss: -0.017554, acc: 0.006250]: [adversarial loss: -0.042207, acc: 0.015625]
# 20000: [discriminator loss: -0.002144, acc: 0.001563]: [adversarial loss: -0.001554, acc: 0.000000]
# 20100: [discriminator loss: -0.007172, acc: 0.000000]: [adversarial loss: -0.010447, acc: 0.000000]
# 20200: [discriminator loss: 0.001575, acc: 0.001563]: [adversarial loss: 0.000990, acc: 0.000000]
# 20300: [discriminator loss: 0.000035, acc: 0.000000]: [adversarial loss: -0.042068, acc: 0.000000]
# 20400: [discriminator loss: -0.000228, acc: 0.000000]: [adversarial loss: -0.009784, acc: 0.000000]
# 20500: [discriminator loss: -0.003475, acc: 0.000000]: [adversarial loss: -0.001082, acc: 0.000000]
# 20600: [discriminator loss: 0.001903, acc: 0.000000]: [adversarial loss: -0.039430, acc: 0.000000]
# 20700: [discriminator loss: -0.001202, acc: 0.000000]: [adversarial loss: -0.052395, acc: 0.000000]
# 20800: [discriminator loss: -0.006125, acc: 0.000000]: [adversarial loss: -0.045793, acc: 0.000000]
# 20900: [discriminator loss: -0.001091, acc: 0.000000]: [adversarial loss: -0.009389, acc: 0.000000]
# 21000: [discriminator loss: -0.007341, acc: 0.000000]: [adversarial loss: -0.031390, acc: 0.000000]
# 21100: [discriminator loss: -0.012485, acc: 0.000000]: [adversarial loss: -0.036191, acc: 0.000000]
# 21200: [discriminator loss: -0.011927, acc: 0.010937]: [adversarial loss: -0.033119, acc: 0.031250]
# 21300: [discriminator loss: -0.009850, acc: 0.000000]: [adversarial loss: -0.012184, acc: 0.000000]
# 21400: [discriminator loss: -0.008779, acc: 0.000000]: [adversarial loss: -0.021177, acc: 0.000000]
# 21500: [discriminator loss: -0.009672, acc: 0.000000]: [adversarial loss: -0.050252, acc: 0.000000]
# 21600: [discriminator loss: -0.007842, acc: 0.000000]: [adversarial loss: -0.039059, acc: 0.000000]
# 21700: [discriminator loss: -0.004690, acc: 0.000000]: [adversarial loss: -0.047298, acc: 0.000000]
# 21800: [discriminator loss: 0.000528, acc: 0.000000]: [adversarial loss: -0.052958, acc: 0.000000]
# 21900: [discriminator loss: -0.002171, acc: 0.000000]: [adversarial loss: -0.046694, acc: 0.000000]
# 22000: [discriminator loss: -0.002988, acc: 0.000000]: [adversarial loss: -0.034420, acc: 0.000000]
# 22100: [discriminator loss: -0.005164, acc: 0.000000]: [adversarial loss: -0.001836, acc: 0.000000]
# 22200: [discriminator loss: -0.006937, acc: 0.000000]: [adversarial loss: -0.003815, acc: 0.000000]
# 22300: [discriminator loss: -0.006262, acc: 0.000000]: [adversarial loss: -0.043022, acc: 0.000000]
# 22400: [discriminator loss: -0.005123, acc: 0.001563]: [adversarial loss: -0.027538, acc: 0.000000]
# 22500: [discriminator loss: 0.000711, acc: 0.000000]: [adversarial loss: -0.021522, acc: 0.000000]
# 22600: [discriminator loss: -0.006716, acc: 0.007812]: [adversarial loss: -0.020952, acc: 0.015625]
# 22700: [discriminator loss: -0.011720, acc: 0.000000]: [adversarial loss: -0.026246, acc: 0.000000]
# 22800: [discriminator loss: -0.004182, acc: 0.000000]: [adversarial loss: -0.023971, acc: 0.000000]
# 22900: [discriminator loss: -0.000557, acc: 0.000000]: [adversarial loss: -0.027061, acc: 0.000000]
# 23000: [discriminator loss: -0.003169, acc: 0.000000]: [adversarial loss: -0.056407, acc: 0.000000]
# 23100: [discriminator loss: -0.002108, acc: 0.000000]: [adversarial loss: -0.060427, acc: 0.000000]
# 23200: [discriminator loss: -0.013819, acc: 0.001563]: [adversarial loss: -0.047129, acc: 0.031250]
# 23300: [discriminator loss: -0.002997, acc: 0.000000]: [adversarial loss: -0.024261, acc: 0.000000]
# 23400: [discriminator loss: -0.001600, acc: 0.001563]: [adversarial loss: -0.042896, acc: 0.000000]
# 23500: [discriminator loss: -0.008133, acc: 0.000000]: [adversarial loss: -0.058920, acc: 0.000000]
# 23600: [discriminator loss: -0.010392, acc: 0.006250]: [adversarial loss: -0.019583, acc: 0.000000]
# 23700: [discriminator loss: -0.003389, acc: 0.000000]: [adversarial loss: -0.010727, acc: 0.000000]
# 23800: [discriminator loss: -0.006163, acc: 0.000000]: [adversarial loss: -0.021330, acc: 0.000000]
# 23900: [discriminator loss: -0.010776, acc: 0.000000]: [adversarial loss: -0.039667, acc: 0.000000]
# 24000: [discriminator loss: -0.014913, acc: 0.012500]: [adversarial loss: 0.029747, acc: 0.015625]
# 24100: [discriminator loss: 0.000817, acc: 0.003125]: [adversarial loss: -0.067799, acc: 0.000000]
# 24200: [discriminator loss: -0.010670, acc: 0.004687]: [adversarial loss: -0.082781, acc: 0.000000]
# 24300: [discriminator loss: -0.008143, acc: 0.000000]: [adversarial loss: 0.007452, acc: 0.000000]
# 24400: [discriminator loss: -0.000282, acc: 0.000000]: [adversarial loss: -0.101307, acc: 0.000000]
# 24500: [discriminator loss: -0.004310, acc: 0.000000]: [adversarial loss: -0.006195, acc: 0.000000]
# 24600: [discriminator loss: -0.004181, acc: 0.000000]: [adversarial loss: -0.048659, acc: 0.000000]
# 24700: [discriminator loss: 0.000827, acc: 0.001563]: [adversarial loss: -0.033988, acc: 0.000000]
# 24800: [discriminator loss: -0.001799, acc: 0.000000]: [adversarial loss: -0.073494, acc: 0.000000]
# 24900: [discriminator loss: -0.004065, acc: 0.000000]: [adversarial loss: -0.036869, acc: 0.000000]
# 25000: [discriminator loss: 0.007143, acc: 0.000000]: [adversarial loss: -0.072129, acc: 0.000000]
# 25100: [discriminator loss: -0.008327, acc: 0.000000]: [adversarial loss: -0.034398, acc: 0.000000]
# 25200: [discriminator loss: -0.009035, acc: 0.000000]: [adversarial loss: -0.006487, acc: 0.000000]
# 25300: [discriminator loss: -0.009108, acc: 0.000000]: [adversarial loss: -0.048298, acc: 0.000000]
# 25400: [discriminator loss: -0.021163, acc: 0.003125]: [adversarial loss: -0.063420, acc: 0.000000]
# 25500: [discriminator loss: -0.010455, acc: 0.000000]: [adversarial loss: -0.008574, acc: 0.000000]
# 25600: [discriminator loss: 0.004344, acc: 0.000000]: [adversarial loss: -0.027291, acc: 0.000000]
# 25700: [discriminator loss: -0.009246, acc: 0.000000]: [adversarial loss: -0.019432, acc: 0.000000]
# 25800: [discriminator loss: 0.000315, acc: 0.001563]: [adversarial loss: -0.079102, acc: 0.000000]
# 25900: [discriminator loss: -0.019399, acc: 0.000000]: [adversarial loss: 0.045910, acc: 0.000000]
# 26000: [discriminator loss: -0.002004, acc: 0.000000]: [adversarial loss: -0.044626, acc: 0.000000]
# 26100: [discriminator loss: 0.005062, acc: 0.003125]: [adversarial loss: -0.035047, acc: 0.000000]
# 26200: [discriminator loss: -0.003095, acc: 0.000000]: [adversarial loss: -0.020936, acc: 0.000000]
# 26300: [discriminator loss: -0.003624, acc: 0.000000]: [adversarial loss: -0.003152, acc: 0.000000]
# 26400: [discriminator loss: -0.001582, acc: 0.000000]: [adversarial loss: -0.043718, acc: 0.000000]
# 26500: [discriminator loss: -0.005393, acc: 0.000000]: [adversarial loss: -0.030164, acc: 0.000000]
# 26600: [discriminator loss: -0.014063, acc: 0.000000]: [adversarial loss: 0.021789, acc: 0.000000]
# 26700: [discriminator loss: -0.008286, acc: 0.000000]: [adversarial loss: 0.002034, acc: 0.000000]
# 26800: [discriminator loss: -0.010422, acc: 0.000000]: [adversarial loss: -0.055299, acc: 0.000000]
# 26900: [discriminator loss: -0.004532, acc: 0.000000]: [adversarial loss: -0.002558, acc: 0.000000]
# 27000: [discriminator loss: -0.016498, acc: 0.000000]: [adversarial loss: -0.006920, acc: 0.000000]
# 27100: [discriminator loss: -0.001701, acc: 0.000000]: [adversarial loss: -0.029662, acc: 0.000000]
# 27200: [discriminator loss: 0.001836, acc: 0.000000]: [adversarial loss: -0.041078, acc: 0.000000]
# 27300: [discriminator loss: -0.002393, acc: 0.000000]: [adversarial loss: -0.039626, acc: 0.000000]
# 27400: [discriminator loss: -0.003499, acc: 0.000000]: [adversarial loss: -0.023127, acc: 0.000000]
# 27500: [discriminator loss: 0.007916, acc: 0.007812]: [adversarial loss: -0.044052, acc: 0.000000]
# 27600: [discriminator loss: 0.001398, acc: 0.000000]: [adversarial loss: -0.054451, acc: 0.000000]
# 27700: [discriminator loss: -0.020189, acc: 0.000000]: [adversarial loss: -0.074727, acc: 0.031250]
# 27800: [discriminator loss: 0.004899, acc: 0.009375]: [adversarial loss: -0.034425, acc: 0.000000]
# 27900: [discriminator loss: -0.006632, acc: 0.004687]: [adversarial loss: -0.120293, acc: 0.000000]
# 28000: [discriminator loss: -0.007782, acc: 0.000000]: [adversarial loss: -0.009221, acc: 0.000000]
# 28100: [discriminator loss: 0.002048, acc: 0.004687]: [adversarial loss: -0.080497, acc: 0.000000]
# 28200: [discriminator loss: -0.007924, acc: 0.000000]: [adversarial loss: -0.028988, acc: 0.000000]
# 28300: [discriminator loss: -0.002587, acc: 0.000000]: [adversarial loss: -0.046275, acc: 0.000000]
# 28400: [discriminator loss: -0.003720, acc: 0.000000]: [adversarial loss: -0.033458, acc: 0.000000]
# 28500: [discriminator loss: -0.003690, acc: 0.000000]: [adversarial loss: -0.054036, acc: 0.000000]
# 28600: [discriminator loss: -0.015677, acc: 0.006250]: [adversarial loss: -0.018268, acc: 0.031250]
# 28700: [discriminator loss: -0.008499, acc: 0.000000]: [adversarial loss: -0.032440, acc: 0.000000]
# 28800: [discriminator loss: 0.003821, acc: 0.003125]: [adversarial loss: -0.063801, acc: 0.000000]
# 28900: [discriminator loss: -0.002427, acc: 0.000000]: [adversarial loss: -0.040822, acc: 0.000000]
# 29000: [discriminator loss: -0.011748, acc: 0.000000]: [adversarial loss: -0.068098, acc: 0.015625]
# 29100: [discriminator loss: -0.002550, acc: 0.000000]: [adversarial loss: -0.044846, acc: 0.000000]
# 29200: [discriminator loss: -0.005701, acc: 0.001563]: [adversarial loss: -0.010336, acc: 0.000000]
# 29300: [discriminator loss: -0.012273, acc: 0.000000]: [adversarial loss: 0.008212, acc: 0.000000]
# 29400: [discriminator loss: -0.003384, acc: 0.000000]: [adversarial loss: -0.029715, acc: 0.000000]
# 29500: [discriminator loss: -0.003935, acc: 0.000000]: [adversarial loss: -0.011923, acc: 0.000000]
# 29600: [discriminator loss: 0.004439, acc: 0.000000]: [adversarial loss: -0.013744, acc: 0.000000]
# 29700: [discriminator loss: -0.016048, acc: 0.000000]: [adversarial loss: -0.028020, acc: 0.000000]
# 29800: [discriminator loss: -0.006235, acc: 0.001563]: [adversarial loss: -0.033382, acc: 0.000000]
# 29900: [discriminator loss: -0.024014, acc: 0.007812]: [adversarial loss: -0.028206, acc: 0.046875]
# 30000: [discriminator loss: -0.009456, acc: 0.000000]: [adversarial loss: -0.067681, acc: 0.000000]
# 30100: [discriminator loss: -0.019152, acc: 0.001563]: [adversarial loss: 0.046882, acc: 0.000000]
# 30200: [discriminator loss: -0.023676, acc: 0.001563]: [adversarial loss: 0.017033, acc: 0.000000]
# 30300: [discriminator loss: 0.009148, acc: 0.000000]: [adversarial loss: -0.048925, acc: 0.000000]
# 30400: [discriminator loss: -0.006137, acc: 0.000000]: [adversarial loss: -0.020989, acc: 0.000000]
# 30500: [discriminator loss: -0.000006, acc: 0.000000]: [adversarial loss: -0.041039, acc: 0.000000]
# 30600: [discriminator loss: -0.002942, acc: 0.000000]: [adversarial loss: -0.093128, acc: 0.000000]
# 30700: [discriminator loss: -0.016647, acc: 0.000000]: [adversarial loss: 0.019783, acc: 0.000000]
# 30800: [discriminator loss: -0.011353, acc: 0.021875]: [adversarial loss: -0.014881, acc: 0.046875]
# 30900: [discriminator loss: -0.010183, acc: 0.035937]: [adversarial loss: 0.004833, acc: 0.000000]
# 31000: [discriminator loss: -0.005691, acc: 0.000000]: [adversarial loss: -0.043880, acc: 0.000000]
# 31100: [discriminator loss: -0.008038, acc: 0.000000]: [adversarial loss: -0.020826, acc: 0.000000]
# 31200: [discriminator loss: -0.011097, acc: 0.000000]: [adversarial loss: -0.000895, acc: 0.000000]
# 31300: [discriminator loss: -0.007053, acc: 0.000000]: [adversarial loss: -0.028693, acc: 0.000000]
# 31400: [discriminator loss: 0.001253, acc: 0.014063]: [adversarial loss: -0.069828, acc: 0.046875]
# 31500: [discriminator loss: -0.005442, acc: 0.000000]: [adversarial loss: -0.042939, acc: 0.000000]
# 31600: [discriminator loss: -0.007046, acc: 0.000000]: [adversarial loss: -0.003284, acc: 0.000000]
# 31700: [discriminator loss: -0.005180, acc: 0.000000]: [adversarial loss: -0.030221, acc: 0.000000]
# 31800: [discriminator loss: -0.004037, acc: 0.000000]: [adversarial loss: -0.038995, acc: 0.000000]
# 31900: [discriminator loss: 0.000001, acc: 0.000000]: [adversarial loss: 0.010310, acc: 0.000000]
# 32000: [discriminator loss: -0.003010, acc: 0.001563]: [adversarial loss: -0.048575, acc: 0.000000]
# 32100: [discriminator loss: -0.001376, acc: 0.000000]: [adversarial loss: -0.041673, acc: 0.000000]
# 32200: [discriminator loss: 0.001006, acc: 0.000000]: [adversarial loss: -0.076093, acc: 0.000000]
# 32300: [discriminator loss: -0.005859, acc: 0.000000]: [adversarial loss: -0.038253, acc: 0.000000]
# 32400: [discriminator loss: -0.011284, acc: 0.000000]: [adversarial loss: 0.014956, acc: 0.000000]
# 32500: [discriminator loss: -0.000243, acc: 0.000000]: [adversarial loss: -0.045520, acc: 0.000000]
# 32600: [discriminator loss: 0.001129, acc: 0.000000]: [adversarial loss: -0.054798, acc: 0.000000]
# 32700: [discriminator loss: -0.000097, acc: 0.000000]: [adversarial loss: -0.029081, acc: 0.000000]
# 32800: [discriminator loss: -0.002899, acc: 0.000000]: [adversarial loss: -0.042880, acc: 0.000000]
# 32900: [discriminator loss: -0.014380, acc: 0.001563]: [adversarial loss: 0.001903, acc: 0.015625]
# 33000: [discriminator loss: 0.001085, acc: 0.000000]: [adversarial loss: -0.081075, acc: 0.000000]
# 33100: [discriminator loss: 0.003529, acc: 0.000000]: [adversarial loss: -0.049753, acc: 0.000000]
# 33200: [discriminator loss: -0.018006, acc: 0.000000]: [adversarial loss: -0.008009, acc: 0.000000]
# 33300: [discriminator loss: -0.002903, acc: 0.000000]: [adversarial loss: -0.032921, acc: 0.000000]
# 33400: [discriminator loss: -0.012252, acc: 0.000000]: [adversarial loss: 0.009178, acc: 0.000000]
# 33500: [discriminator loss: 0.002811, acc: 0.000000]: [adversarial loss: -0.038259, acc: 0.000000]
# 33600: [discriminator loss: 0.000049, acc: 0.000000]: [adversarial loss: -0.029501, acc: 0.000000]
# 33700: [discriminator loss: -0.004863, acc: 0.000000]: [adversarial loss: 0.000962, acc: 0.000000]
# 33800: [discriminator loss: -0.006293, acc: 0.000000]: [adversarial loss: -0.051521, acc: 0.000000]
# 33900: [discriminator loss: -0.005666, acc: 0.000000]: [adversarial loss: -0.026432, acc: 0.000000]
# 34000: [discriminator loss: 0.017353, acc: 0.003125]: [adversarial loss: -0.045561, acc: 0.000000]
# 34100: [discriminator loss: -0.012093, acc: 0.000000]: [adversarial loss: -0.028446, acc: 0.000000]
# 34200: [discriminator loss: -0.006758, acc: 0.000000]: [adversarial loss: -0.045640, acc: 0.000000]
# 34300: [discriminator loss: -0.003817, acc: 0.000000]: [adversarial loss: -0.054870, acc: 0.000000]
# 34400: [discriminator loss: -0.011011, acc: 0.003125]: [adversarial loss: -0.017710, acc: 0.000000]
# 34500: [discriminator loss: 0.006356, acc: 0.000000]: [adversarial loss: -0.019403, acc: 0.000000]
# 34600: [discriminator loss: -0.004414, acc: 0.000000]: [adversarial loss: -0.093461, acc: 0.000000]
# 34700: [discriminator loss: 0.002478, acc: 0.000000]: [adversarial loss: -0.009654, acc: 0.000000]
# 34800: [discriminator loss: -0.013588, acc: 0.014063]: [adversarial loss: -0.040429, acc: 0.015625]
# 34900: [discriminator loss: -0.002105, acc: 0.000000]: [adversarial loss: -0.029526, acc: 0.000000]
# 35000: [discriminator loss: -0.001449, acc: 0.000000]: [adversarial loss: -0.075824, acc: 0.000000]
# 35100: [discriminator loss: -0.000035, acc: 0.000000]: [adversarial loss: -0.019646, acc: 0.000000]
# 35200: [discriminator loss: -0.008918, acc: 0.000000]: [adversarial loss: -0.090707, acc: 0.000000]
# 35300: [discriminator loss: -0.008024, acc: 0.001563]: [adversarial loss: -0.014091, acc: 0.000000]
# 35400: [discriminator loss: 0.004727, acc: 0.006250]: [adversarial loss: -0.118931, acc: 0.000000]
# 35500: [discriminator loss: 0.006121, acc: 0.001563]: [adversarial loss: -0.062090, acc: 0.000000]
# 35600: [discriminator loss: 0.000807, acc: 0.000000]: [adversarial loss: -0.052507, acc: 0.000000]
# 35700: [discriminator loss: -0.004320, acc: 0.000000]: [adversarial loss: -0.071207, acc: 0.000000]
# 35800: [discriminator loss: -0.006360, acc: 0.000000]: [adversarial loss: -0.065568, acc: 0.000000]
# 35900: [discriminator loss: -0.011031, acc: 0.000000]: [adversarial loss: -0.054814, acc: 0.000000]
# 36000: [discriminator loss: -0.007242, acc: 0.004687]: [adversarial loss: -0.029230, acc: 0.000000]
# 36100: [discriminator loss: -0.001645, acc: 0.000000]: [adversarial loss: -0.004678, acc: 0.000000]
# 36200: [discriminator loss: -0.002568, acc: 0.000000]: [adversarial loss: -0.038591, acc: 0.000000]
# 36300: [discriminator loss: -0.007307, acc: 0.000000]: [adversarial loss: -0.078320, acc: 0.000000]
# 36400: [discriminator loss: 0.000982, acc: 0.000000]: [adversarial loss: -0.064441, acc: 0.000000]
# 36500: [discriminator loss: 0.007624, acc: 0.015625]: [adversarial loss: -0.025178, acc: 0.000000]
# 36600: [discriminator loss: 0.006463, acc: 0.000000]: [adversarial loss: -0.023663, acc: 0.000000]
# 36700: [discriminator loss: -0.005792, acc: 0.000000]: [adversarial loss: -0.041204, acc: 0.000000]
# 36800: [discriminator loss: -0.011591, acc: 0.000000]: [adversarial loss: -0.011082, acc: 0.000000]
# 36900: [discriminator loss: -0.004841, acc: 0.000000]: [adversarial loss: -0.038269, acc: 0.000000]
# 37000: [discriminator loss: -0.008208, acc: 0.000000]: [adversarial loss: -0.024491, acc: 0.000000]
# 37100: [discriminator loss: -0.008562, acc: 0.003125]: [adversarial loss: -0.019876, acc: 0.000000]
# 37200: [discriminator loss: 0.003666, acc: 0.000000]: [adversarial loss: -0.031932, acc: 0.000000]
# 37300: [discriminator loss: -0.007094, acc: 0.000000]: [adversarial loss: -0.044090, acc: 0.000000]
# 37400: [discriminator loss: -0.007830, acc: 0.000000]: [adversarial loss: -0.109749, acc: 0.000000]
# 37500: [discriminator loss: 0.000691, acc: 0.000000]: [adversarial loss: -0.050120, acc: 0.000000]
# 37600: [discriminator loss: -0.000489, acc: 0.000000]: [adversarial loss: -0.076101, acc: 0.000000]
# 37700: [discriminator loss: -0.000027, acc: 0.000000]: [adversarial loss: -0.080208, acc: 0.000000]
# 37800: [discriminator loss: -0.001132, acc: 0.004687]: [adversarial loss: -0.064806, acc: 0.000000]
# 37900: [discriminator loss: -0.007358, acc: 0.000000]: [adversarial loss: -0.028215, acc: 0.000000]
# 38000: [discriminator loss: -0.000537, acc: 0.000000]: [adversarial loss: -0.094455, acc: 0.000000]
# 38100: [discriminator loss: 0.002774, acc: 0.003125]: [adversarial loss: -0.065609, acc: 0.000000]
# 38200: [discriminator loss: 0.003141, acc: 0.064062]: [adversarial loss: -0.149409, acc: 0.140625]
# 38300: [discriminator loss: -0.000656, acc: 0.000000]: [adversarial loss: -0.040006, acc: 0.000000]
# 38400: [discriminator loss: -0.007415, acc: 0.000000]: [adversarial loss: -0.066634, acc: 0.000000]
# 38500: [discriminator loss: -0.002229, acc: 0.000000]: [adversarial loss: -0.028768, acc: 0.000000]
# 38600: [discriminator loss: -0.005414, acc: 0.025000]: [adversarial loss: 0.025548, acc: 0.031250]
# 38700: [discriminator loss: -0.012188, acc: 0.003125]: [adversarial loss: -0.047110, acc: 0.015625]
# 38800: [discriminator loss: -0.007382, acc: 0.000000]: [adversarial loss: -0.040496, acc: 0.000000]
# 38900: [discriminator loss: 0.001540, acc: 0.000000]: [adversarial loss: -0.031239, acc: 0.000000]
# 39000: [discriminator loss: -0.001312, acc: 0.000000]: [adversarial loss: -0.022225, acc: 0.000000]
# 39100: [discriminator loss: 0.005510, acc: 0.000000]: [adversarial loss: -0.041023, acc: 0.000000]
# 39200: [discriminator loss: -0.006675, acc: 0.000000]: [adversarial loss: -0.046730, acc: 0.000000]
# 39300: [discriminator loss: -0.001035, acc: 0.001563]: [adversarial loss: -0.048095, acc: 0.000000]
# 39400: [discriminator loss: 0.008236, acc: 0.018750]: [adversarial loss: -0.049534, acc: 0.000000]
# 39500: [discriminator loss: 0.000910, acc: 0.000000]: [adversarial loss: -0.014772, acc: 0.015625]
# 39600: [discriminator loss: -0.026441, acc: 0.000000]: [adversarial loss: 0.059985, acc: 0.000000]
# 39700: [discriminator loss: 0.000792, acc: 0.001563]: [adversarial loss: -0.060036, acc: 0.000000]
# 39800: [discriminator loss: 0.001343, acc: 0.000000]: [adversarial loss: -0.046239, acc: 0.000000]
# 39900: [discriminator loss: 0.013940, acc: 0.012500]: [adversarial loss: -0.015895, acc: 0.000000]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# '\nif __name__ == \'__main__\':\n    parser = argparse.ArgumentParser()\n    help_ = "Load generator h5 model with trained weights"\n    parser.add_argument("-g", "--generator", help=help_)\n    args = parser.parse_args() # args에 위 내용 저장\n    if args.generator:\n        generator = load_model(args.generator)\n        gan.test_generator(generator)\n    else:\n        build_and_train_models()\n'

# %%
from keras.models import load_model

generator = load_model("./MNIST_WGAN/mnist_wgan.h5", compile=False)
noise = np.random.uniform(-1.0, 1.0, size=[16, 100])
plot_images(generator,
            noise_input=noise,
            show=True,
            model_name="./MNIST_WGAN/test_image"
           )
