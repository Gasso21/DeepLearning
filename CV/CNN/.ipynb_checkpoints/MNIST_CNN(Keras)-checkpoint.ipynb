# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %% [markdown]
# ## Dataset Loading and EDA

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
mnist = keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

unique, counts = np.unique(y_train, return_counts=True)
print(f"Train labels: {dict(zip(unique, counts))}")

unique, counts = np.unique(y_test, return_counts=True)
print(f"Test labels: {dict(zip(unique, counts))}")
# Out:
# Train labels: {0: 5923, 1: 6742, 2: 5958, 3: 6131, 4: 5842, 5: 5421, 6: 5918, 7: 6265, 8: 5851, 9: 5949}
# Test labels: {0: 980, 1: 1135, 2: 1032, 3: 1010, 4: 982, 5: 892, 6: 958, 7: 1028, 8: 974, 9: 1009}

# %%
indexes = np.random.randint(0, x_train.shape[0], size=9)
images = x_train[indexes]
labels = y_train[indexes]

plt.figure(figsize=)

# %% [markdown]
# ### Preprecessing

# %%
from keras.layers import Activation, Dense, Dropout
from keras.layers import Conv2D, MaxPooling2D, Flatten

# %%
num_labels = len(np.unique(y_train))

y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

x_train = np.reshape(x_train, [-1, x_train.shape[1], x_train.shape[2], 1])
x_test = np.reshape(x_test, [-1, x_test.shape[1], x_test.shape[2], 1])
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

input_shape = (x_train.shape[1], x_train.shape[2], 1)
batch_size = 128
kernel_size = 3
pool_size = 2
filters = 64
dropout = 0.2

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(buffer_size=100000)
test_dataset = tf.data.Dataset.from_tensor_slices((x_test, y_test))
# Out:
# Metal device set to: Apple M2
# 2023-01-30 20:57:27.487974: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-30 20:57:27.488112: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ### Modeling
# - Build-up Functional API Model

# %%
def create_func_model():
    inputs = keras.Input(shape = input_shape)
    conv1 = Conv2D(filters=filters,
               kernel_size=kernel_size,
               activation='relu'
              )(inputs)
    maxpool1 = MaxPooling2D(pool_size=pool_size)(conv1)
    conv2 = Conv2D(filters=filters,
               kernel_size=kernel_size,
               activation='relu'
              )(maxpool1)
    maxpool2 = MaxPooling2D(pool_size=pool_size)(conv2)
    conv3 = Conv2D(filters=filters,
               kernel_size=kernel_size,
               activation='relu'
              )(maxpool2)
    flatten1 = Flatten()(conv3)
    drop1 = Dropout(dropout)(flatten1)
    outputs = Dense(num_labels, 
              activation='softmax'
             )(drop1)
    
    model = keras..evalumodels.Model(inputs, outputs)
    return model

func_model = create_func_model()
func_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 26, 26, 64)        640
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 64)          36928
#
#  flatten (Flatten)           (None, 576)               0
#
#  dropout (Dropout)           (None, 576)               0
#
#  dense (Dense)               (None, 10)                5770
#
# =================================================================
# Total params: 80,266
# Trainable params: 80,266
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model=func_model,
                       to_file='cnn-mnist.png',
                       show_shapes=True
                      )

# %%
learning_rate = 0.001
func_model.compile(loss='categorical_crossentropy',
                   optimizer=keras.optimizers.Adam(learning_rate),
                   metrics=['accuracy']
                  )

# %%
history = func_model.fit(x_train, y_train,
                         epochs=10,
                         batch_size=batch_size,
                         validation_data=(x_test, y_test)
                        )
# Out:
# Epoch 1/10
# 2023-01-30 20:57:27.993712: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-01-30 20:57:28.162658: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 469/469 [==============================] - ETA: 0s - loss: 0.2524 - accuracy: 0.9231
# 2023-01-30 20:57:35.611436: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 469/469 [==============================] - 8s 17ms/step - loss: 0.2524 - accuracy: 0.9231 - val_loss: 0.0527 - val_accuracy: 0.9835
# Epoch 2/10
# 469/469 [==============================] - 8s 16ms/step - loss: 0.0633 - accuracy: 0.9804 - val_loss: 0.0377 - val_accuracy: 0.9874
# Epoch 3/10
# 469/469 [==============================] - 8s 16ms/step - loss: 0.0459 - accuracy: 0.9858 - val_loss: 0.0329 - val_accuracy: 0.9891
# Epoch 4/10
# 469/469 [==============================] - 8s 18ms/step - loss: 0.0359 - accuracy: 0.9886 - val_loss: 0.0258 - val_accuracy: 0.9909
# Epoch 5/10
# 469/469 [==============================] - 8s 16ms/step - loss: 0.0308 - accuracy: 0.9902 - val_loss: 0.0277 - val_accuracy: 0.9912
# Epoch 6/10
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0254 - accuracy: 0.9921 - val_loss: 0.0229 - val_accuracy: 0.9931
# Epoch 7/10
# 469/469 [==============================] - 8s 16ms/step - loss: 0.0226 - accuracy: 0.9930 - val_loss: 0.0273 - val_accuracy: 0.9910
# Epoch 8/10
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0202 - accuracy: 0.9934 - val_loss: 0.0244 - val_accuracy: 0.9925
# Epoch 9/10
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0173 - accuracy: 0.9944 - val_loss: 0.0252 - val_accuracy: 0.9919
# Epoch 10/10
# 469/469 [==============================] - 8s 18ms/step - loss: 0.0157 - accuracy: 0.9949 - val_loss: 0.0225 - val_accuracy: 0.9939

# %%
loss, acc = func_model.evaluate(x_test, y_test, batch_size=batch_size)
print(f"Test accuracy: {(100*acc):>.1f}%")
# Out:
# 79/79 [==============================] - 1s 8ms/step - loss: 0.0225 - accuracy: 0.9939
# Test accuracy: 99.4%

# %%
plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.xticks(range(10))
plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(history.history['accuracy'], 'b-', label='acc')
plt.plot(history.history['val_accuracy'], 'r--', label='val_acc')
plt.xlabel('Epoch')
plt.xticks(range(10))
plt.grid()
plt.legend()
plt.show()

# %%
# %load_ext tensorboard

# %%
new_model_1 = create_func_model()
new_model_1.compile(optimizer=tf.keras.optimizers.Adam(learning_rate),
                    loss='categorical_crossentropy',
                    metrics=['accuracy']
                   )

# %%
new_model_1.evaluate(x_test, y_test)
# Out:
#  10/313 [..............................] - ETA: 1s - loss: 2.2988 - accuracy: 0.1094
# 2023-01-30 21:04:11.646358: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 313/313 [==============================] - 2s 5ms/step - loss: 2.3009 - accuracy: 0.0848
# [2.3009023666381836, 0.08480000495910645]

# %%
log_dir = './log/MNIST_MLP'
tensorboard_cb = keras.callbacks.TensorBoard(log_dir, histogram_freq=1)
# histogram_freq=1: save per 1 epoch; Distribution about the weight and bias

# %%
new_model_1.fit(x_train, y_train,
                epochs=10,
                batch_size=batch_size,
                validation_data=(x_test, y_test),
                callbacks=[tensorboard_cb]
               )
# Out:
# Epoch 1/10
#   1/469 [..............................] - ETA: 2:23 - loss: 2.2995 - accuracy: 0.1328
# 2023-01-30 21:14:22.621717: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 469/469 [==============================] - 8s 16ms/step - loss: 0.2561 - accuracy: 0.9216 - val_loss: 0.0583 - val_accuracy: 0.9822
# Epoch 2/10
# 469/469 [==============================] - 8s 18ms/step - loss: 0.0665 - accuracy: 0.9791 - val_loss: 0.0378 - val_accuracy: 0.9886
# Epoch 3/10
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0476 - accuracy: 0.9852 - val_loss: 0.0291 - val_accuracy: 0.9911
# Epoch 4/10
# 469/469 [==============================] - 8s 18ms/step - loss: 0.0388 - accuracy: 0.9876 - val_loss: 0.0352 - val_accuracy: 0.9883
# Epoch 5/10
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0333 - accuracy: 0.9897 - val_loss: 0.0294 - val_accuracy: 0.9893
# Epoch 6/10
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0282 - accuracy: 0.9912 - val_loss: 0.0235 - val_accuracy: 0.9920
# Epoch 7/10
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0245 - accuracy: 0.9920 - val_loss: 0.0264 - val_accuracy: 0.9914
# Epoch 8/10
# 469/469 [==============================] - 8s 16ms/step - loss: 0.0218 - accuracy: 0.9928 - val_loss: 0.0255 - val_accuracy: 0.9913
# Epoch 9/10
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0180 - accuracy: 0.9942 - val_loss: 0.0273 - val_accuracy: 0.9917
# Epoch 10/10
# 469/469 [==============================] - 8s 18ms/step - loss: 0.0170 - accuracy: 0.9948 - val_loss: 0.0222 - val_accuracy: 0.9926

# %%
# %tensorboard --logdir $log_dir
# Out:
#       <iframe id="tensorboard-frame-5cfeac18aa41d68a" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-5cfeac18aa41d68a");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
func_model.save_weights('./save/func_model.skpt')

# %%
func_model.save('./save/func_model')
# Out:
# 2023-01-30 21:24:28.930853: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: ./save/func_model/assets

# %%
func_model_2 = keras.models.load_model('./save/func_model')

# %%
func_model_2.evaluate(x_test, y_test)
# Out:
#  19/313 [>.............................] - ETA: 1s - loss: 0.0209 - accuracy: 0.9934
# 2023-01-30 21:26:04.542315: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0225 - accuracy: 0.9939
# [0.02249039150774479, 0.9939000606536865]
