# %% [markdown]
# # Transfer Learning

# %% [markdown]
# ## ImageNet_VGG16

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
from tensorflow import keras
from keras.applications.vgg16 import VGG16

base_model = VGG16(weights="imagenet",
                   include_top=False,
                   input_shape=(224,224,3)
                  )
base_model.summary()
# Out:
# 2023-06-23 10:42:35.974551: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2023-06-23 10:42:35.974569: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2023-06-23 10:42:35.974574: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2023-06-23 10:42:35.974600: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-06-23 10:42:35.974612: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...

# %%
for layer in base_model.layers:
    layer.trainable = False
    
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
# ...

# %% [markdown]
# # Fine Tuning

# %%
from keras.layers import Dense, Flatten

last_layer = base_model.get_layer('block5_pool') # 마지막층에 접근
last_output = last_layer.output # 마지막 층의 출력을 다음 층의 입력으로

x = Flatten()(last_output)
x = Dense(5, activation='softmax', name='softmax')(x)

# %%
new_model = keras.Model(inputs=base_model.input, outputs=x)
new_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
# ...

# %%
import os

save_dir = os.path.join(os.getcwd(), 'TF')
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)

filepath1 = os.path.join(save_dir, 'TF_VGG16.png')

keras.utils.plot_model(model=new_model,
                       to_file=filepath1,
                       show_shapes=True
                      )

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

filepath2 = os.path.join(save_dir,'transfer_lr_data_files')

train_imgs = np.load(filepath2+'/target_images.npy')
train_labels = np.load(filepath2+'/target_labels.npy')

test_imgs = np.load(filepath2+'/test_images.npy')
test_labels = np.load(filepath2+'/test_labels.npy')

print(train_imgs.shape)
print(train_labels[0])
# Out:
# (65, 224, 224, 3)
# [1. 0. 0. 0. 0.]

# %%
Dict = ['Hat', 'Cube', 'Card', 'Torch', 'screw']

# %%
n_train = train_imgs.shape[0]
n_test = test_imgs.shape[0]
idx = np.random.randint(0, n_train, size=9)
images = train_imgs[idx]
labels = train_labels[idx]

plt.figure(figsize=(5,5))
for i in range(len(idx)):
    plt.subplot(3, 3, i+1)
    plt.imshow(images[i], cmap='gray')
    plt.axis('off')
    plt.title("Label : {}".format(Dict[np.argmax(labels[i])]))
plt.show()

# %%
# %load_ext tensorboard

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
import math

# Model Checkpoints
filepath3 = os.path.join(save_dir, 'checkpoints')
if not os.path.isdir(filepath3):
    os.makedirs(filepath3)
    
model_name = 'transfer_lr.{epoch:02d}.h5'

filepath4 = os.path.join(filepath3, model_name)
checkpoints = ModelCheckpoint(filepath=filepath4,
                              monitor='val_accuracy',
                              verbose=1,
                              save_best_only=True
                             )

# Model lr_scheduler setting
initial_lrate = 0.01

def decay(epoch, steps=100):
    initial_lrate = 0.01
    drop = 0.96
    epochs_drop = 10
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    return lrate

lr_scheduler = LearningRateScheduler(decay)

sgd = keras.optimizers.SGD(learning_rate=initial_lrate, momentum=0.9, nesterov=False)

# Tensorboard
filepath5 = os.path.join(save_dir, 'tensorboard')
tensorboard_cb = keras.callbacks.TensorBoard(filepath5, histogram_freq=1)

# Compile and training
batch_size = 20
epochs = 50

new_model.compile(loss='categorical_crossentropy',
                  optimizer=sgd,
                  metrics=['accuracy']
                 )

hist = new_model.fit(train_imgs, train_labels, batch_size=batch_size, epochs=epochs,
                     validation_data=(test_imgs, test_labels), 
                     callbacks=[checkpoints, lr_scheduler, tensorboard_cb],
                     verbose=2,
                     shuffle=True
                    )
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.SGD`.
# Epoch 1/50
# 2023-06-23 10:54:29.189484: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_accuracy improved from -inf to 0.11111, saving model to /Users/jaehwan/Desktop/Git/DeepLearning/CV/4.Classic_CNNs/TF/checkpoints/transfer_lr.01.h5
# 2023-06-23 10:54:30.633636: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# ...

# %%
# %tensorboard --logdir $filepath5
# Out:
#       <iframe id="tensorboard-frame-7ca738ddc063bb9c" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-7ca738ddc063bb9c");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
plt.plot(hist.history['loss'], 'b-', label='loss')
plt.plot(hist.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.xticks(range(50))
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Image Load and Test

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
from keras.preprocessing.image import load_img, img_to_array
from keras.applications.vgg16 import preprocess_input, decode_predictions, VGG16
import os

# %%
model = VGG16(weights="imagenet", include_top=True, input_shape=(224,224,3))

# %%
image = load_img(os.path.join(os.getcwd(), 'TF/transfer_lr_data_files/GS.png'), target_size=(224,224))
image = img_to_array(image)

# %%
image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
#image = image.astype('float32')/255
image = preprocess_input(image)

# %%
yhat = model.predict(image)
label = decode_predictions(yhat)
label = label[0][0]
print('%s (%.2f%%)'%(label[1],label[2]*100))
# Out:
# 1/1 [==============================] - 0s 164ms/step
# 2023-06-23 12:07:36.996834: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# German_shepherd (100.00%)
