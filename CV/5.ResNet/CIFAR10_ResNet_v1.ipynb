# %%
"""
# !pip uninstall keras
# !pip uninstall tensorflow
"""
# Out:
# Found existing installation: keras 2.9.0
# Uninstalling keras-2.9.0:
#   Would remove:
#     /usr/local/lib/python3.8/dist-packages/keras-2.9.0.dist-info/*
#     /usr/local/lib/python3.8/dist-packages/keras/*
# Proceed (Y/n)? y
#   Successfully uninstalled keras-2.9.0
# Found existing installation: tensorflow 2.9.2
# Uninstalling tensorflow-2.9.2:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/import_pb_to_tensorboard
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.8/dist-packages/tensorflow-2.9.2.dist-info/*
#     /usr/local/lib/python3.8/dist-packages/tensorflow/*
# Proceed (Y/n)? y
#   Successfully uninstalled tensorflow-2.9.2

# %%
"""
# !pip install keras==2.3.1
# !pip install tensorflow==2.2.0
"""
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras==2.3.1
#   Downloading Keras-2.3.1-py2.py3-none-any.whl (377 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.8/377.8 KB 25.9 MB/s eta 0:00:00
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.8/dist-packages (from keras==2.3.1) (1.1.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.8/dist-packages (from keras==2.3.1) (3.1.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.8/dist-packages (from keras==2.3.1) (1.21.6)
# Collecting keras-applications>=1.0.6
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 KB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (from keras==2.3.1) (6.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from keras==2.3.1) (1.15.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.8/dist-packages (from keras==2.3.1) (1.7.3)
# Installing collected packages: keras-applications, keras
# Successfully installed keras-2.3.1 keras-applications-1.0.8
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow==2.2.0
#   Downloading tensorflow-2.2.0-cp38-cp38-manylinux2010_x86_64.whl (516.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 516.3/516.3 MB 3.0 MB/s eta 0:00:00
# Collecting h5py<2.11.0,>=2.10.0
#   Downloading h5py-2.10.0-cp38-cp38-manylinux1_x86_64.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 82.6 MB/s eta 0:00:00
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.2.0) (0.2.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.2.0) (1.21.6)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.2.0) (1.15.0)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.2.0) (1.6.3)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.2.0) (3.19.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.2.0) (3.3.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.2.0) (0.38.4)
# Collecting scipy==1.4.1
#   Downloading scipy-1.4.1-cp38-cp38-manylinux1_x86_64.whl (26.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.0/26.0 MB 76.1 MB/s eta 0:00:00
# Collecting gast==0.3.3
#   Downloading gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Collecting tensorboard<2.3.0,>=2.2.0
#   Downloading tensorboard-2.2.2-py3-none-any.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 101.5 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.3.0,>=2.2.0
#   Downloading tensorflow_estimator-2.2.0-py2.py3-none-any.whl (454 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.6/454.6 KB 47.8 MB/s eta 0:00:00
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.2.0) (1.51.1)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.2.0) (1.14.1)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.2.0) (1.1.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.2.0) (2.2.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.2.0) (1.4.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (0.4.6)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (57.4.0)
# Collecting google-auth<2,>=1.6.3
#   Downloading google_auth-1.35.0-py2.py3-none-any.whl (152 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.9/152.9 KB 20.7 MB/s eta 0:00:00
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (2.25.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (0.2.8)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (6.0.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (2.10)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.12.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.2.2)
# Installing collected packages: tensorflow-estimator, scipy, h5py, gast, cachetools, google-auth, tensorboard, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.9.0
#     Uninstalling tensorflow-estimator-2.9.0:
#       Successfully uninstalled tensorflow-estimator-2.9.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.3
#     Uninstalling scipy-1.7.3:
#       Successfully uninstalled scipy-1.7.3
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.4.0
#     Uninstalling gast-0.4.0:
#       Successfully uninstalled gast-0.4.0
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 5.3.0
#     Uninstalling cachetools-5.3.0:
#       Successfully uninstalled cachetools-5.3.0
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.16.0
#     Uninstalling google-auth-2.16.0:
#       Successfully uninstalled google-auth-2.16.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.9.1
#     Uninstalling tensorboard-2.9.1:
#       Successfully uninstalled tensorboard-2.9.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xarray-einstats 0.5.1 requires scipy>=1.6, but you have scipy 1.4.1 which is incompatible.
# plotnine 0.8.0 requires scipy>=1.5.0, but you have scipy 1.4.1 which is incompatible.
# jaxlib 0.3.25+cuda11.cudnn805 requires scipy>=1.5, but you have scipy 1.4.1 which is incompatible.
# jax 0.3.25 requires scipy>=1.5, but you have scipy 1.4.1 which is incompatible.
# google-api-core 2.11.0 requires google-auth<3.0dev,>=2.14.1, but you have google-auth 1.35.0 which is incompatible.
# Successfully installed cachetools-4.2.4 gast-0.3.3 google-auth-1.35.0 h5py-2.10.0 scipy-1.4.1 tensorboard-2.2.2 tensorflow-2.2.0 tensorflow-estimator-2.2.0

# %% [markdown]
# # CIFAR10

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %% [markdown]
# ## ResNet v1
# ### EDA

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
cifar10 = keras.datasets.cifar10
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

unique, counts = np.unique(y_train, return_counts=True)
print(f"Train Labels: {dict(zip(unique, counts))}")

unique, counts = np.unique(y_test, return_counts=True)
print(f"Test Labels: {dict(zip(unique, counts))}")
# Out:
# Train Labels: {0: 5000, 1: 5000, 2: 5000, 3: 5000, 4: 5000, 5: 5000, 6: 5000, 7: 5000, 8: 5000, 9: 5000}
# Test Labels: {0: 1000, 1: 1000, 2: 1000, 3: 1000, 4: 1000, 5: 1000, 6: 1000, 7: 1000, 8: 1000, 9: 1000}

# %%
y_train.shape
# Out:
# (50000, 1)

# %%
figure =plt.figure(figsize=(10,10))
cols, rows = (10, 10)
k = 1
for i in range(cols):
    for j in np.where(y_train==i)[0][:rows]:
        figure.add_subplot(cols, rows, k)
        plt.imshow(x_train[j], cmap='gray')
        plt.axis('off')
        k += 1

# %% [markdown]
# ### Modeling

# %%
from keras.layers import Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Flatten, Dense
from keras.regularizers import l2

# %%
batch_size = 32 # origin paper trained all networks with bath_size=128
epochs = 200
data_augmentation = True
num_classes = len(np.unique(y_train))

n=3

# Model version
version = 1

# Compute depth from supplied model parameter n
if version == 1:
    depth = n*6+2
elif version == 2:
    depth = n*9+2

# Model name, depth and version
model_type = 'ResNet%d_v%d'%(depth, version)

# Input image dimensions
input_shape = x_train.shape[1:]

# One-hot Encoding
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# Normalize data
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# Subtracting pixel mean improves accuracy
subtract_pixel_mean=True
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print(f"x_train shape: {x_train.shape}")
print(f"y_train shape: {y_train.shape}")
# Out:
# x_train shape: (50000, 32, 32, 3)
# y_train shape: (50000, 10)

# %%
def lr_schedule(epoch):
    # Learning Rate Schedule
    
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print(f"Learning rate: {lr}")
    return lr

# %%
def resnet_layer(inputs, num_filters=16, kernel_size=3, strides=1, activation='relu', batch_normalization=True, conv_first=True):
    # Conv2D-BN-Activation stack builder
    # inputs (tensor) : imput image or previous layer
    # num_filters (int) : Conv2D number of filters
    # kernel_size (int) : Conv2D square kernel dimensions
    # strides (int) : Conv2D square stride dimention
    # activation (string) : Activation name
    # batch_normalization (bool) : wWhether to include BN
    # conv_first (bool) : Conv2D-BN-Activation (True) or bn-activation-conv (False)
    # Returns : x (tensor) as input to the next layer
    
    conv = Conv2D(filters=num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4)
                 )
    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x =Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v1(input_shape, depth, num_classes=10):
    if (depth-2)%6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
        
    num_filters = 16
    num_res_blocks = int((depth-2)/6)
    
    inputs = keras.Input(shape = input_shape)
    x = resnet_layer(inputs=inputs)
    
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:
                strides = 2
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides
                            )
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None
                            )
            if stack > 0 and res_block == 0:
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False
                                )
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes, activation='softmax', kernel_initializer='he_normal')(y)
    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# %%
if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
    
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=keras.optimizers.Adam(learning_rate=lr_schedule(0)),
              metrics=['accuracy']
             )
model.summary()
# Out:
# Learning rate: 0.001
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d_21 (Conv2D)             (None, 32, 32, 16)   448         ['input_2[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 32, 32, 16)  64          ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_19[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 32, 32, 16)  64          ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_20[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 32, 32, 16)  64          ['conv2d_23[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 32, 32, 16)   0           ['activation_19[0][0]',
#                                                                   'batch_normalization_21[0][0]']
#
#  activation_21 (Activation)     (None, 32, 32, 16)   0           ['add_9[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 32, 32, 16)  64          ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 32, 32, 16)  64          ['conv2d_25[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 32, 32, 16)   0           ['activation_21[0][0]',
#                                                                   'batch_normalization_23[0][0]']
#
#  activation_23 (Activation)     (None, 32, 32, 16)   0           ['add_10[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_23[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 32, 32, 16)  64          ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_24[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 32, 32, 16)  64          ['conv2d_27[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 32, 32, 16)   0           ['activation_23[0][0]',
#                                                                   'batch_normalization_25[0][0]']
#
#  activation_25 (Activation)     (None, 32, 32, 16)   0           ['add_11[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 16, 16, 32)   4640        ['activation_25[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 16, 16, 32)  128         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_26[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_26[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 16, 16, 32)   544         ['activation_25[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 16, 16, 32)  128         ['conv2d_29[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 16, 16, 32)   0           ['conv2d_30[0][0]',
#                                                                   'batch_normalization_27[0][0]']
#
#  activation_27 (Activation)     (None, 16, 16, 32)   0           ['add_12[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 16, 16, 32)  128         ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 16, 16, 32)  128         ['conv2d_32[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 16, 16, 32)   0           ['activation_27[0][0]',
#                                                                   'batch_normalization_29[0][0]']
#
#  activation_29 (Activation)     (None, 16, 16, 32)   0           ['add_13[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_29[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 16, 16, 32)  128         ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_30[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 16, 16, 32)  128         ['conv2d_34[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 16, 16, 32)   0           ['activation_29[0][0]',
#                                                                   'batch_normalization_31[0][0]']
#
#  activation_31 (Activation)     (None, 16, 16, 32)   0           ['add_14[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 8, 8, 64)     18496       ['activation_31[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 8, 8, 64)    256         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_32[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_32[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 8, 8, 64)     2112        ['activation_31[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 8, 8, 64)    256         ['conv2d_36[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 8, 8, 64)     0           ['conv2d_37[0][0]',
#                                                                   'batch_normalization_33[0][0]']
#
#  activation_33 (Activation)     (None, 8, 8, 64)     0           ['add_15[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_33[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 8, 8, 64)    256         ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_34[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 8, 8, 64)    256         ['conv2d_39[0][0]']
#  ormalization)
#
#  add_16 (Add)                   (None, 8, 8, 64)     0           ['activation_33[0][0]',
#                                                                   'batch_normalization_35[0][0]']
#
#  activation_35 (Activation)     (None, 8, 8, 64)     0           ['add_16[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_35[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 8, 8, 64)    256         ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_36[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_36[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 8, 8, 64)    256         ['conv2d_41[0][0]']
#  ormalization)
#
#  add_17 (Add)                   (None, 8, 8, 64)     0           ['activation_35[0][0]',
#                                                                   'batch_normalization_37[0][0]']
#
#  activation_37 (Activation)     (None, 8, 8, 64)     0           ['add_17[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 1, 1, 64)    0           ['activation_37[0][0]']
#  oling2D)
#
#  flatten_1 (Flatten)            (None, 64)           0           ['average_pooling2d_1[0][0]']
#
#  dense_1 (Dense)                (None, 10)           650         ['flatten_1[0][0]']
#
# ==================================================================================================
# Total params: 274,442
# Trainable params: 273,066
# Non-trainable params: 1,376
# __________________________________________________________________________________________________

# %%
print(model_type)
# Out:
# ResNet20_v1

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
import os

# %%
# Prepare model saving directory
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_%s_model.{epoch:03d}.h5' %model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir) # 경로 상의 모든 폴더들을 다 만들어줌
filepath = os.path.join(save_dir, model_name)

# %%
# Prepare callbacks for model saving and for learning rate adjustment
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True
                            )
lr_scheduler = LearningRateScheduler(lr_schedule)

# 학습속도 감소 스케줄 전에 지표 개선이 정체되는 경우, 검증 손실이 patience세대 후에 개선되지 않으면 factor만큼 학습속도를 감소
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6
                              )
callbacks = [checkpoint, lr_reducer, lr_scheduler]

# %%
if not data_augmentation:
    print("Not using data augmentation.")
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks
             )
else:
    print("Using real-time data augmentation.")
    #This will do preprocessing and realtime data augmentation
    datagen = ImageDataGenerator(
        # Set input mean to 0 over the dataset
        featurewise_center=False,
        
        # Set each sample mean to 0
        samplewise_center=False,
        
        # Divide inputs by std of dataset
        featurewise_std_normalization=False,
        
        # Divide each input by its std
        samplewise_std_normalization=False,
        
        # Apply ZCA whitening
        zca_whitening=False,
        
        # Epsilon for ZCA whitening
        zca_epsilon=1e-06,
        
        # Randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        
        # Randomly shift images horizontally
        width_shift_range=0.1,
        
        # Randomly shift images vertically
        height_shift_range=0.1,
        
        # Set range for random shear
        shear_range=0.,
        
        # Set range for random zoom
        zoom_range=0.,
        
        # Set range for random channel shifts
        channel_shift_range=0.,
        
        # Set mode for filling points outside the input boundaries
        fill_mode='nearest',
        
        # Value used for fill_mode = "constant"
        cval=0.,
        
        # Randomly flip images
        horizontal_flip=True,
        
        # Randomly flip images
        vertical_flip=False,
        
        # Set rescaling factor (applied before any other transformation)
        rescale=None,
        
        # Set function that will be applied on each input
        preprocessing_function=None,
        
        # Image data format, either "channels_first" or "channels_last"
        data_format=None,
        
        # Fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0
    )
    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied)
    datagen.fit(x_train)
    
    # Fit the model on the batches generated by datagen.flow().
    model.fit(datagen.flow(x_train, y_train, batch_size=batch_size),
              validation_data=(x_test, y_test),
              epochs=epochs, verbose=1, steps_per_epoch=250,
              callbacks=callbacks
             )
    
    # Score trained model
    scores = model.evaluate(x_test, y_test, verbose=1)
    print("Test loss:", scores[0])
    print("Test accuracy:", scores[1])
# Out:
# Using real-time data augmentation.
# Learning rate: 0.001
# Epoch 1/200
# 2023-02-03 20:09:19.624818: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 249/250 [============================>.] - ETA: 0s - loss: 2.0986 - accuracy: 0.3239
# 2023-02-03 20:09:27.936377: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_accuracy improved from -inf to 0.32140, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/ResNet/saved_models/cifar10_ResNet20_v1_model.001.h5
# 250/250 [==============================] - 14s 48ms/step - loss: 2.0987 - accuracy: 0.3238 - val_loss: 2.0175 - val_accuracy: 0.3214 - lr: 0.0010
# Learning rate: 0.001
# Epoch 2/200
# 249/250 [============================>.] - ETA: 0s - loss: 1.7042 - accuracy: 0.4305
# Epoch 2: val_accuracy improved from 0.32140 to 0.34170, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/ResNet/saved_models/cifar10_ResNet20_v1_model.002.h5
# 250/250 [==============================] - 11s 45ms/step - loss: 1.7044 - accuracy: 0.4300 - val_loss: 2.1567 - val_accuracy: 0.3417 - lr: 0.0010
# Learning rate: 0.001
# Epoch 3/200
# 249/250 [============================>.] - ETA: 0s - loss: 1.5907 - accuracy: 0.4779
# Epoch 3: val_accuracy improved from 0.34170 to 0.42490, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/ResNet/saved_models/cifar10_ResNet20_v1_model.003.h5
# 250/250 [==============================] - 11s 45ms/step - loss: 1.5923 - accuracy: 0.4773 - val_loss: 1.8161 - val_accuracy: 0.4249 - lr: 0.0010
# Learning rate: 0.001
# Epoch 4/200
# 249/250 [============================>.] - ETA: 0s - loss: 1.4818 - accuracy: 0.5200
# Epoch 4: val_accuracy improved from 0.42490 to 0.50340, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/ResNet/saved_models/cifar10_ResNet20_v1_model.004.h5
# 250/250 [==============================] - 11s 45ms/step - loss: 1.4816 - accuracy: 0.5199 - val_loss: 1.5376 - val_accuracy: 0.5034 - lr: 0.0010
# Learning rate: 0.001
# Epoch 5/200
# 249/250 [============================>.] - ETA: 0s - loss: 1.4197 - accuracy: 0.5467
# Epoch 5: val_accuracy improved from 0.50340 to 0.51000, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/ResNet/saved_models/cifar10_ResNet20_v1_model.005.h5
# 250/250 [==============================] - 11s 45ms/step - loss: 1.4213 - accuracy: 0.5461 - val_loss: 1.5389 - val_accuracy: 0.5100 - lr: 0.0010
# Learning rate: 0.001
# Epoch 6/200
# 249/250 [============================>.] - ETA: 0s - loss: 1.3677 - accuracy: 0.5693
# Epoch 6: val_accuracy did not improve from 0.51000
# 250/250 [==============================] - 11s 44ms/step - loss: 1.3671 - accuracy: 0.5695 - val_loss: 1.5757 - val_accuracy: 0.5061 - lr: 0.0010
# Learning rate: 0.001
# Epoch 7/200
# 249/250 [============================>.] - ETA: 0s - loss: 1.2960 - accuracy: 0.5925
# Epoch 7: val_accuracy did not improve from 0.51000
# 250/250 [==============================] - 11s 44ms/step - loss: 1.2961 - accuracy: 0.5924 - val_loss: 1.6768 - val_accuracy: 0.4955 - lr: 0.0010
# Learning rate: 0.001
# Epoch 8/200
# 249/250 [============================>.] - ETA: 0s - loss: 1.2202 - accuracy: 0.6254
# Epoch 8: val_accuracy improved from 0.51000 to 0.62740, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/ResNet/saved_models/cifar10_ResNet20_v1_model.008.h5
# 250/250 [==============================] - 11s 45ms/step - loss: 1.2189 - accuracy: 0.6261 - val_loss: 1.2128 - val_accuracy: 0.6274 - lr: 0.0010
# Learning rate: 0.001
# Epoch 9/200
# 249/250 [============================>.] - ETA: 0s - loss: 1.1807 - accuracy: 0.6339
# Epoch 9: val_accuracy did not improve from 0.62740
# 250/250 [==============================] - 11s 44ms/step - loss: 1.1810 - accuracy: 0.6338 - val_loss: 1.5152 - val_accuracy: 0.5580 - lr: 0.0010
# Learning rate: 0.001
# Epoch 10/200
# 250/250 [==============================] - ETA: 0s - loss: 1.1497 - accuracy: 0.6504
# Epoch 10: val_accuracy did not improve from 0.62740
# 250/250 [==============================] - 11s 45ms/step - loss: 1.1497 - accuracy: 0.6504 - val_loss: 1.3237 - val_accuracy: 0.6082 - lr: 0.0010
# Learning rate: 0.001
# Epoch 11/200
# 249/250 [============================>.] - ETA: 0s - loss: 1.1210 - accuracy: 0.6638
# Epoch 11: val_accuracy did not improve from 0.62740
# 250/250 [==============================] - 11s 45ms/step - loss: 1.1203 - accuracy: 0.6643 - val_loss: 1.4829 - val_accuracy: 0.5691 - lr: 0.0010
# Learning rate: 0.001
# Epoch 12/200
# 249/250 [============================>.] - ETA: 0s - loss: 1.0927 - accuracy: 0.6643
# Epoch 12: val_accuracy did not improve from 0.62740
# 250/250 [==============================] - 11s 45ms/step - loss: 1.0936 - accuracy: 0.6638 - val_loss: 1.2898 - val_accuracy: 0.6092 - lr: 0.0010
# Learning rate: 0.001
# Epoch 13/200
# 249/250 [============================>.] - ETA: 0s - loss: 1.0645 - accuracy: 0.6737
# Epoch 13: val_accuracy improved from 0.62740 to 0.65920, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/ResNet/saved_models/cifar10_ResNet20_v1_model.013.h5
# 250/250 [==============================] - 11s 46ms/step - loss: 1.0636 - accuracy: 0.6740 - val_loss: 1.1586 - val_accuracy: 0.6592 - lr: 0.0010
# Learning rate: 0.001
# Epoch 14/200
# 249/250 [============================>.] - ETA: 0s - loss: 1.0368 - accuracy: 0.6883
# Epoch 14: val_accuracy did not improve from 0.65920
# 250/250 [==============================] - 12s 46ms/step - loss: 1.0366 - accuracy: 0.6880 - val_loss: 1.1883 - val_accuracy: 0.6580 - lr: 0.0010
# Learning rate: 0.001
# Epoch 15/200
# 249/250 [============================>.] - ETA: 0s - loss: 1.0030 - accuracy: 0.7057
# Epoch 15: val_accuracy improved from 0.65920 to 0.67630, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/ResNet/saved_models/cifar10_ResNet20_v1_model
- lr: 1.0000e-04
# Learning rate: 0.0001
# Epoch 115/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4576 - accuracy: 0.9023
# Epoch 115: val_accuracy did not improve from 0.87160
# 250/250 [==============================] - 13s 51ms/step - loss: 0.4584 - accuracy: 0.9021 - val_loss: 0.5697 - val_accuracy: 0.8658 - lr: 1.0000e-04
# Learning rate: 0.0001
# Epoch 116/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4593 - accuracy: 0.8992
# Epoch 116: val_accuracy did not improve from 0.87160
# 250/250 [==============================] - 12s 50ms/step - loss: 0.4587 - accuracy: 0.8996 - val_loss: 0.5573 - val_accuracy: 0.8700 - lr: 1.0000e-04
# Learning rate: 0.0001
# Epoch 117/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4575 - accuracy: 0.9002
# Epoch 117: val_accuracy improved from 0.87160 to 0.87740, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/ResNet/saved_models/cifar10_ResNet20_v1_model.117.h5
# 250/250 [==============================] - 12s 49ms/step - loss: 0.4575 - accuracy: 0.9003 - val_loss: 0.5408 - val_accuracy: 0.8774 - lr: 1.0000e-04
# Learning rate: 0.0001
# Epoch 118/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4535 - accuracy: 0.9027
# Epoch 118: val_accuracy did not improve from 0.87740
# 250/250 [==============================] - 13s 50ms/step - loss: 0.4534 - accuracy: 0.9030 - val_loss: 0.5509 - val_accuracy: 0.8717 - lr: 1.0000e-04
# Learning rate: 0.0001
# Epoch 119/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4582 - accuracy: 0.9032
# Epoch 119: val_accuracy did not improve from 0.87740
# 250/250 [==============================] - 12s 48ms/step - loss: 0.4578 - accuracy: 0.9033 - val_loss: 0.5542 - val_accuracy: 0.8692 - lr: 1.0000e-04
# Learning rate: 0.0001
# Epoch 120/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4564 - accuracy: 0.8973
# Epoch 120: val_accuracy did not improve from 0.87740
# 250/250 [==============================] - 12s 49ms/step - loss: 0.4561 - accuracy: 0.8976 - val_loss: 0.5732 - val_accuracy: 0.8654 - lr: 1.0000e-04
# Learning rate: 0.0001
# Epoch 121/200
# 250/250 [==============================] - ETA: 0s - loss: 0.4679 - accuracy: 0.8984
# Epoch 121: val_accuracy did not improve from 0.87740
# 250/250 [==============================] - 12s 50ms/step - loss: 0.4679 - accuracy: 0.8984 - val_loss: 0.5454 - val_accuracy: 0.8721 - lr: 1.0000e-04
# Learning rate: 1e-05
# Epoch 122/200
# 250/250 [==============================] - ETA: 0s - loss: 0.4489 - accuracy: 0.9073
# Epoch 122: val_accuracy did not improve from 0.87740
# 250/250 [==============================] - 13s 51ms/step - loss: 0.4489 - accuracy: 0.9073 - val_loss: 0.5413 - val_accuracy: 0.8737 - lr: 3.1623e-06
# Learning rate: 1e-05
# Epoch 123/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4433 - accuracy: 0.9039
# Epoch 123: val_accuracy did not improve from 0.87740
# 250/250 [==============================] - 12s 48ms/step - loss: 0.4429 - accuracy: 0.9041 - val_loss: 0.5424 - val_accuracy: 0.8733 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 124/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4502 - accuracy: 0.9078
# Epoch 124: val_accuracy did not improve from 0.87740
# 250/250 [==============================] - 11s 46ms/step - loss: 0.4499 - accuracy: 0.9079 - val_loss: 0.5442 - val_accuracy: 0.8725 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 125/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4529 - accuracy: 0.9025
# Epoch 125: val_accuracy did not improve from 0.87740
# 250/250 [==============================] - 12s 47ms/step - loss: 0.4532 - accuracy: 0.9025 - val_loss: 0.5420 - val_accuracy: 0.8728 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 126/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4400 - accuracy: 0.9085
# Epoch 126: val_accuracy did not improve from 0.87740
# 250/250 [==============================] - 11s 46ms/step - loss: 0.4398 - accuracy: 0.9086 - val_loss: 0.5404 - val_accuracy: 0.8722 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 127/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4526 - accuracy: 0.9034
# Epoch 127: val_accuracy did not improve from 0.87740
# 250/250 [==============================] - 12s 47ms/step - loss: 0.4526 - accuracy: 0.9034 - val_loss: 0.5421 - val_accuracy: 0.8741 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 128/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4548 - accuracy: 0.9032
# Epoch 128: val_accuracy did not improve from 0.87740
# 250/250 [==============================] - 11s 45ms/step - loss: 0.4544 - accuracy: 0.9035 - val_loss: 0.5403 - val_accuracy: 0.8752 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 129/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4364 - accuracy: 0.9104
# Epoch 129: val_accuracy did not improve from 0.87740
# 250/250 [==============================] - 11s 45ms/step - loss: 0.4363 - accuracy: 0.9104 - val_loss: 0.5439 - val_accuracy: 0.8729 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 130/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4540 - accuracy: 0.9047
# Epoch 130: val_accuracy did not improve from 0.87740
# 250/250 [==============================] - 11s 45ms/step - loss: 0.4538 - accuracy: 0.9049 - val_loss: 0.5409 - val_accuracy: 0.8732 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 131/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4361 - accuracy: 0.9110
# Epoch 131: val_accuracy did not improve from 0.87740
# 250/250 [==============================] - 11s 46ms/step - loss: 0.4363 - accuracy: 0.9110 - val_loss: 0.5373 - val_accuracy: 0.8744 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 132/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4352 - accuracy: 0.9093
# Epoch 132: val_accuracy did not improve from 0.87740
# 250/250 [==============================] - 11s 45ms/step - loss: 0.4350 - accuracy: 0.9094 - val_loss: 0.5378 - val_accuracy: 0.8747 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 133/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4372 - accuracy: 0.9078
# Epoch 133: val_accuracy did not improve from 0.87740
# 250/250 [==============================] - 11s 45ms/step - loss: 0.4373 - accuracy: 0.9078 - val_loss: 0.5392 - val_accuracy: 0.8740 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 134/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4325 - accuracy: 0.9084
# Epoch 134: val_accuracy did not improve from 0.87740
# 250/250 [==============================] - 11s 46ms/step - loss: 0.4325 - accuracy: 0.9084 - val_loss: 0.5392 - val_accuracy: 0.8745 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 135/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4347 - accuracy: 0.9083
# Epoch 135: val_accuracy did not improve from 0.87740
# 250/250 [==============================] - 11s 46ms/step - loss: 0.4346 - accuracy: 0.9083 - val_loss: 0.5393 - val_accuracy: 0.8742 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 136/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4354 - accuracy: 0.9101
# Epoch 136: val_accuracy did not improve from 0.87740
# 250/250 [==============================] - 11s 46ms/step - loss: 0.4353 - accuracy: 0.9101 - val_loss: 0.5384 - val_accuracy: 0.8745 - lr: 3.1623e-06
# Learning rate: 1e-05
# Epoch 137/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4397 - accuracy: 0.9071
# Epoch 137: val_accuracy did not improve from 0.87740
# 250/250 [==============================] - 12s 47ms/step - loss: 0.4396 - accuracy: 0.9073 - val_loss: 0.5367 - val_accuracy: 0.8745 - lr: 1.0000e-05
# ...
# Epoch 152: val_accuracy did not improve from 0.87740
# 250/250 [==============================] - 12s 47ms/step - loss: 0.4390 - accuracy: 0.9036 - val_loss: 0.5385 - val_accuracy: 0.8740 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 153/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4393 - accuracy: 0.9055
# Epoch 153: val_accuracy did not improve from 0.87740
# 250/250 [==============================] - 12s 48ms/step - loss: 0.4390 - accuracy: 0.9054 - val_loss: 0.5331 - val_accuracy: 0.8762 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 154/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4385 - accuracy: 0.9088
# Epoch 154: val_accuracy did not improve from 0.87740
# 250/250 [==============================] - 12s 48ms/step - loss: 0.4384 - accuracy: 0.9086 - val_loss: 0.5355 - val_accuracy: 0.8749 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 155/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4294 - accuracy: 0.9094
# Epoch 155: val_accuracy did not improve from 0.87740
# 250/250 [==============================] - 12s 47ms/step - loss: 0.4288 - accuracy: 0.9095 - val_loss: 0.5355 - val_accuracy: 0.8761 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 156/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4289 - accuracy: 0.9114
# Epoch 156: val_accuracy did not improve from 0.87740
# 250/250 [==============================] - 11s 45ms/step - loss: 0.4288 - accuracy: 0.9113 - val_loss: 0.5361 - val_accuracy: 0.8761 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 157/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4287 - accuracy: 0.9071
# Epoch 157: val_accuracy did not improve from 0.87740
# 250/250 [==============================] - 11s 45ms/step - loss: 0.4285 - accuracy: 0.9070 - val_loss: 0.5352 - val_accuracy: 0.8750 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 158/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4367 - accuracy: 0.9061
# Epoch 158: val_accuracy did not improve from 0.87740
# 250/250 [==============================] - 11s 45ms/step - loss: 0.4363 - accuracy: 0.9061 - val_loss: 0.5350 - val_accuracy: 0.8762 - lr: 3.1623e-06
# Learning rate: 1e-05
# Epoch 159/200
# 250/250 [==============================] - ETA: 0s - loss: 0.4301 - accuracy: 0.9126
# Epoch 159: val_accuracy did not improve from 0.87740
# 250/250 [==============================] - 11s 45ms/step - loss: 0.4301 - accuracy: 0.9126 - val_loss: 0.5343 - val_accuracy: 0.8760 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 160/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4405 - accuracy: 0.9083
# Epoch 160: val_accuracy improved from 0.87740 to 0.87750, saving model to /Users/jaehwan/Desktop/Git/Artificial-Intelligence/DeepLearning/ResNet/saved_models/cifar10_ResNet20_v1_model.160.h5
# 250/250 [==============================] - 12s 46ms/step - loss: 0.4403 - accuracy: 0.9083 - val_loss: 0.5327 - val_accuracy: 0.8775 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 161/200
# 250/250 [==============================] - ETA: 0s - loss: 0.4267 - accuracy: 0.9123
# Epoch 161: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 12s 47ms/step - loss: 0.4267 - accuracy: 0.9123 - val_loss: 0.5348 - val_accuracy: 0.8760 - lr: 1.0000e-05
# Learning rate: 1e-06
# Epoch 162/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4270 - accuracy: 0.9095
# Epoch 162: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 11s 46ms/step - loss: 0.4263 - accuracy: 0.9099 - val_loss: 0.5357 - val_accuracy: 0.8758 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 163/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4400 - accuracy: 0.9071
# Epoch 163: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 12s 46ms/step - loss: 0.4397 - accuracy: 0.9074 - val_loss: 0.5352 - val_accuracy: 0.8756 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 164/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4416 - accuracy: 0.9061
# Epoch 164: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 12s 47ms/step - loss: 0.4423 - accuracy: 0.9057 - val_loss: 0.5349 - val_accuracy: 0.8769 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 165/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4386 - accuracy: 0.9085
# Epoch 165: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 11s 46ms/step - loss: 0.4390 - accuracy: 0.9084 - val_loss: 0.5360 - val_accuracy: 0.8759 - lr: 5.0000e-07
# Learning rate: 1e-06
# Epoch 166/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4370 - accuracy: 0.9061
# Epoch 166: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 11s 46ms/step - loss: 0.4368 - accuracy: 0.9061 - val_loss: 0.5356 - val_accuracy: 0.8759 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 167/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4281 - accuracy: 0.9113
# Epoch 167: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 11s 46ms/step - loss: 0.4283 - accuracy: 0.9114 - val_loss: 0.5341 - val_accuracy: 0.8759 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 168/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4235 - accuracy: 0.9110
# Epoch 168: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 12s 47ms/step - loss: 0.4238 - accuracy: 0.9109 - val_loss: 0.5350 - val_accuracy: 0.8752 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 169/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4359 - accuracy: 0.9069
# Epoch 169: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 12s 47ms/step - loss: 0.4355 - accuracy: 0.9070 - val_loss: 0.5354 - val_accuracy: 0.8764 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 170/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4396 - accuracy: 0.9057
# Epoch 170: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 12s 47ms/step - loss: 0.4403 - accuracy: 0.9053 - val_loss: 0.5371 - val_accuracy: 0.8756 - lr: 5.0000e-07
# Learning rate: 1e-06
# Epoch 171/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4323 - accuracy: 0.9108
# Epoch 171: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 12s 47ms/step - loss: 0.4321 - accuracy: 0.9109 - val_loss: 0.5364 - val_accuracy: 0.8751 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 172/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4273 - accuracy: 0.9118
# Epoch 172: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 12s 47ms/step - loss: 0.4265 - accuracy: 0.9121 - val_loss: 0.5360 - val_accuracy: 0.8758 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 173/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4406 - accuracy: 0.9047
# Epoch 173: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 12s 47ms/step - loss: 0.4405 - accuracy: 0.9046 - val_loss: 0.5355 - val_accuracy: 0.8765 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 174/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4245 - accuracy: 0.9113
# Epoch 174: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 12s 47ms/step - loss: 0.4242 - accuracy: 0.9114 - val_loss: 0.5375 - val_accuracy: 0.8757 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 175/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4485 - accuracy: 0.9047
# Epoch 175: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 12s 47ms/step - loss: 0.4488 - accuracy: 0.9048 - val_loss: 0.5361 - val_accuracy: 0.8759 - lr: 5.0000e-07
# Learning rate: 1e-06
# Epoch 176/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4265 - accuracy: 0.9106
# Epoch 176: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 12s 46ms/step - loss: 0.4261 - accuracy: 0.9108 - val_loss: 0.5360 - val_accuracy: 0.8757 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 177/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4403 - accuracy: 0.9022
# Epoch 177: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 12s 47ms/step - loss: 0.4398 - accuracy: 0.9023 - val_loss: 0.5352 - val_accuracy: 0.8764 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 178/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4250 - accuracy: 0.9122
# Epoch 178: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 12s 49ms/step - loss: 0.4247 - accuracy: 0.9122 - val_loss: 0.5354 - val_accuracy: 0.8768 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 179/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4369 - accuracy: 0.9104
# Epoch 179: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 12s 47ms/step - loss: 0.4369 - accuracy: 0.9105 - val_loss: 0.5324 - val_accuracy: 0.8770 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 180/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4200 - accuracy: 0.9155
# Epoch 180: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 12s 47ms/step - loss: 0.4199 - accuracy: 0.9155 - val_loss: 0.5352 - val_accuracy: 0.8751 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 181/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4326 - accuracy: 0.9093
# Epoch 181: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 12s 46ms/step - loss: 0.4325 - accuracy: 0.9094 - val_loss: 0.5362 - val_accuracy: 0.8756 - lr: 1.0000e-06
# Learning rate: 5e-07
# Epoch 182/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4430 - accuracy: 0.9075
# Epoch 182: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 11s 45ms/step - loss: 0.4425 - accuracy: 0.9078 - val_loss: 0.5329 - val_accuracy: 0.8769 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 183/200
# 250/250 [==============================] - ETA: 0s - loss: 0.4283 - accuracy: 0.9085
# Epoch 183: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 11s 46ms/step - loss: 0.4283 - accuracy: 0.9085 - val_loss: 0.5341 - val_accuracy: 0.8763 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 184/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4510 - accuracy: 0.9052
# Epoch 184: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 11s 45ms/step - loss: 0.4517 - accuracy: 0.9048 - val_loss: 0.5357 - val_accuracy: 0.8761 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 185/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4239 - accuracy: 0.9129
# Epoch 185: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 11s 45ms/step - loss: 0.4234 - accuracy: 0.9131 - val_loss: 0.5336 - val_accuracy: 0.8768 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 186/200
# 250/250 [==============================] - ETA: 0s - loss: 0.4338 - accuracy: 0.9089
# Epoch 186: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 11s 46ms/step - loss: 0.4338 - accuracy: 0.9089 - val_loss: 0.5338 - val_accuracy: 0.8771 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 187/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4408 - accuracy: 0.9076
# Epoch 187: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 12s 47ms/step - loss: 0.4409 - accuracy: 0.9078 - val_loss: 0.5325 - val_accuracy: 0.8766 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 188/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4354 - accuracy: 0.9093
# Epoch 188: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 11s 46ms/step - loss: 0.4349 - accuracy: 0.9094 - val_loss: 0.5361 - val_accuracy: 0.8754 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 189/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4327 - accuracy: 0.9069
# Epoch 189: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 11s 45ms/step - loss: 0.4328 - accuracy: 0.9066 - val_loss: 0.5322 - val_accuracy: 0.8770 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 190/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4368 - accuracy: 0.9042
# Epoch 190: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 11s 45ms/step - loss: 0.4363 - accuracy: 0.9044 - val_loss: 0.5347 - val_accuracy: 0.8757 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 191/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4288 - accuracy: 0.9090
# Epoch 191: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 11s 45ms/step - loss: 0.4291 - accuracy: 0.9088 - val_loss: 0.5326 - val_accuracy: 0.8769 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 192/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4249 - accuracy: 0.9143
# Epoch 192: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 11s 45ms/step - loss: 0.4242 - accuracy: 0.9146 - val_loss: 0.5331 - val_accuracy: 0.8769 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 193/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4425 - accuracy: 0.9083
# Epoch 193: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 11s 44ms/step - loss: 0.4420 - accuracy: 0.9085 - val_loss: 0.5331 - val_accuracy: 0.8773 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 194/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4453 - accuracy: 0.9044
# Epoch 194: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 11s 45ms/step - loss: 0.4459 - accuracy: 0.9043 - val_loss: 0.5343 - val_accuracy: 0.8764 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 195/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4299 - accuracy: 0.9078
# Epoch 195: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 11s 46ms/step - loss: 0.4295 - accuracy: 0.9079 - val_loss: 0.5354 - val_accuracy: 0.8758 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 196/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4454 - accuracy: 0.9041
# Epoch 196: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 11s 46ms/step - loss: 0.4461 - accuracy: 0.9039 - val_loss: 0.5345 - val_accuracy: 0.8762 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 197/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4377 - accuracy: 0.9071
# Epoch 197: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 11s 45ms/step - loss: 0.4375 - accuracy: 0.9073 - val_loss: 0.5333 - val_accuracy: 0.8762 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 198/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4301 - accuracy: 0.9092
# Epoch 198: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 11s 46ms/step - loss: 0.4303 - accuracy: 0.9092 - val_loss: 0.5328 - val_accuracy: 0.8764 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 199/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4299 - accuracy: 0.9114
# Epoch 199: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 11s 45ms/step - loss: 0.4295 - accuracy: 0.9114 - val_loss: 0.5325 - val_accuracy: 0.8763 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 200/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4467 - accuracy: 0.9037
# Epoch 200: val_accuracy did not improve from 0.87750
# 250/250 [==============================] - 11s 45ms/step - loss: 0.4462 - accuracy: 0.9038 - val_loss: 0.5332 - val_accuracy: 0.8773 - lr: 5.0000e-07
# 313/313 [==============================] - 4s 13ms/step - loss: 0.5332 - accuracy: 0.8773
# Test loss: 0.5332086682319641
# Test accuracy: 0.8773000240325928

# %% [markdown]
# $
# \rightarrow \text{steps_per_epoch*epochs <= The number of datas}
# $
