# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y

# %% [markdown]
# ## Dataset Loading and EDA

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np
import os
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
# Out:
# 2023-06-23 04:56:34.396602: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-06-23 04:56:34.970256: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-23 04:56:36.551319: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
cifar10 = keras.datasets.cifar10
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

unique, counts = np.unique(y_train, return_counts=True)
print(f"Train Labels: {dict(zip(unique, counts))}")

unique, counts = np.unique(y_test, return_counts=True)
print(f"Test Labels: {dict(zip(unique, counts))}")
# Out:
# Train Labels: {0: 5000, 1: 5000, 2: 5000, 3: 5000, 4: 5000, 5: 5000, 6: 5000, 7: 5000, 8: 5000, 9: 5000}
# Test Labels: {0: 1000, 1: 1000, 2: 1000, 3: 1000, 4: 1000, 5: 1000, 6: 1000, 7: 1000, 8: 1000, 9: 1000}

# %%
Dict = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog','horse', 'ship', 'truck']

# %%
indexes = np.random.randint(0, x_train.shape[0], 100)
images = x_train[indexes]
labels = y_train[indexes]

plt.figure(figsize=(10,10))
for i in range(len(indexes)):
    plt.subplot(10, 10, i+1)
    image = images[i]
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.title(Dict[int(labels[i])], fontdict={'fontsize': 10})
plt.show()

# %% [markdown]
# ## Preprocessing

# %%
from keras.layers import Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Flatten, Dense
from keras.regularizers import l2

# %%
num_labels = len(np.unique(y_train))

y_train = keras.utils.to_categorical(y_train, num_labels)
y_test = keras.utils.to_categorical(y_test, num_labels)

x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# Subtracting pixel mean improves accuracy
subtract_pixel_mean=True
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

# %%
version = 1 # Model version
n = 3

# Compute depth from supplied model parameter n
if version == 1:
    depth = n*6+2
elif version == 2:
    depth = n*9+2

# Model name, depth and version
model_type = 'ResNet%d_v%d'%(depth, version)

input_shape = x_train.shape[1:]
batch_size = 32 # origin paper trained all networks with bath_size=128
epochs = 200

# %% [markdown]
# ## Modeling

# %%
def resnet_layer(inputs, num_filters=16, kernel_size=3, strides=1, activation='relu', batch_normalization=True, conv_first=True):
    # Conv2D-BN-Activation stack builder
    # inputs (tensor) : imput image or previous layer
    # num_filters (int) : Conv2D number of filters
    # kernel_size (int) : Conv2D square kernel dimensions
    # strides (int) : Conv2D square stride dimention
    # activation (string) : Activation name
    # batch_normalization (bool) : wWhether to include BN
    # conv_first (bool) : Conv2D-BN-Activation (True) or bn-activation-conv (False)
    # Returns : x (tensor) as input to the next layer
    
    conv = Conv2D(filters=num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4)
                 )
    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x =Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v1(input_shape, depth, num_classes=10):
    if (depth-2)%6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
        
    num_filters = 16
    num_res_blocks = int((depth-2)/6)
    
    inputs = keras.Input(shape = input_shape)
    x = resnet_layer(inputs=inputs)
    
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:
                strides = 2
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides
                            )
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None
                            )
            if stack > 0 and res_block == 0:
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False
                                )
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes, activation='softmax', kernel_initializer='he_normal')(y)
    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# %%
if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
    
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)
    
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 32, 32, 3)]          0         []
#
#  conv2d_42 (Conv2D)          (None, 32, 32, 16)           448       ['input_3[0][0]']
#
#  batch_normalization_38 (Ba  (None, 32, 32, 16)           64        ['conv2d_42[0][0]']
#  tchNormalization)
#
#  activation_38 (Activation)  (None, 32, 32, 16)           0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 32, 32, 16)           2320      ['activation_38[0][0]']
#
#  batch_normalization_39 (Ba  (None, 32, 32, 16)           64        ['conv2d_43[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, 32, 32, 16)           0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  conv2d_44 (Conv2D)          (None, 32, 32, 16)           2320      ['activation_39[0][0]']
#
#  batch_normalization_40 (Ba  (None, 32, 32, 16)           64        ['conv2d_44[0][0]']
#  tchNormalization)
#
#  add_18 (Add)                (None, 32, 32, 16)           0         ['activation_38[0][0]',
#                                                                      'batch_normalization_40[0][0]
#                                                                     ']
#
#  activation_40 (Activation)  (None, 32, 32, 16)           0         ['add_18[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 32, 32, 16)           2320      ['activation_40[0][0]']
#
#  batch_normalization_41 (Ba  (None, 32, 32, 16)           64        ['conv2d_45[0][0]']
#  tchNormalization)
#
#  activation_41 (Activation)  (None, 32, 32, 16)           0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  conv2d_46 (Conv2D)          (None, 32, 32, 16)           2320      ['activation_41[0][0]']
#
#  batch_normalization_42 (Ba  (None, 32, 32, 16)           64        ['conv2d_46[0][0]']
#  tchNormalization)
#
#  add_19 (Add)                (None, 32, 32, 16)           0         ['activation_40[0][0]',
#                                                                      'batch_normalization_42[0][0]
#                                                                     ']
#
#  activation_42 (Activation)  (None, 32, 32, 16)           0         ['add_19[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 32, 32, 16)           2320      ['activation_42[0][0]']
#
#  batch_normalization_43 (Ba  (None, 32, 32, 16)           64        ['conv2d_47[0][0]']
#  tchNormalization)
#
#  activation_43 (Activation)  (None, 32, 32, 16)           0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  conv2d_48 (Conv2D)          (None, 32, 32, 16)           2320      ['activation_43[0][0]']
#
#  batch_normalization_44 (Ba  (None, 32, 32, 16)           64        ['conv2d_48[0][0]']
#  tchNormalization)
#
#  add_20 (Add)                (None, 32, 32, 16)           0         ['activation_42[0][0]',
#                                                                      'batch_normalization_44[0][0]
#                                                                     ']
#
#  activation_44 (Activation)  (None, 32, 32, 16)           0         ['add_20[0][0]']
#
#  conv2d_49 (Conv2D)          (None, 16, 16, 32)           4640      ['activation_44[0][0]']
#
#  batch_normalization_45 (Ba  (None, 16, 16, 32)           128       ['conv2d_49[0][0]']
#  tchNormalization)
#
#  activation_45 (Activation)  (None, 16, 16, 32)           0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_50 (Conv2D)          (None, 16, 16, 32)           9248      ['activation_45[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 16, 16, 32)           544       ['activation_44[0][0]']
#
#  batch_normalization_46 (Ba  (None, 16, 16, 32)           128       ['conv2d_50[0][0]']
#  tchNormalization)
#
#  add_21 (Add)                (None, 16, 16, 32)           0         ['conv2d_51[0][0]',
#                                                                      'batch_normalization_46[0][0]
#                                                                     ']
#
#  activation_46 (Activation)  (None, 16, 16, 32)           0         ['add_21[0][0]']
#
#  conv2d_52 (Conv2D)          (None, 16, 16, 32)           9248      ['activation_46[0][0]']
#
#  batch_normalization_47 (Ba  (None, 16, 16, 32)           128       ['conv2d_52[0][0]']
#  tchNormalization)
#
#  activation_47 (Activation)  (None, 16, 16, 32)           0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  conv2d_53 (Conv2D)          (None, 16, 16, 32)           9248      ['activation_47[0][0]']
#
#  batch_normalization_48 (Ba  (None, 16, 16, 32)           128       ['conv2d_53[0][0]']
#  tchNormalization)
#
#  add_22 (Add)                (None, 16, 16, 32)           0         ['activation_46[0][0]',
#                                                                      'batch_normalization_48[0][0]
#                                                                     ']
#
#  activation_48 (Activation)  (None, 16, 16, 32)           0         ['add_22[0][0]']
#
#  conv2d_54 (Conv2D)          (None, 16, 16, 32)           9248      ['activation_48[0][0]']
#
#  batch_normalization_49 (Ba  (None, 16, 16, 32)           128       ['conv2d_54[0][0]']
#  tchNormalization)
#
#  activation_49 (Activation)  (None, 16, 16, 32)           0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  conv2d_55 (Conv2D)          (None, 16, 16, 32)           9248      ['activation_49[0][0]']
#
#  batch_normalization_50 (Ba  (None, 16, 16, 32)           128       ['conv2d_55[0][0]']
#  tchNormalization)
#
#  add_23 (Add)                (None, 16, 16, 32)           0         ['activation_48[0][0]',
#                                                                      'batch_normalization_50[0][0]
#                                                                     ']
#
#  activation_50 (Activation)  (None, 16, 16, 32)           0         ['add_23[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 8, 8, 64)             18496     ['activation_50[0][0]']
#
#  batch_normalization_51 (Ba  (None, 8, 8, 64)             256       ['conv2d_56[0][0]']
#  tchNormalization)
#
#  activation_51 (Activation)  (None, 8, 8, 64)             0         ['batch_normalization_51[0][0]
#                                                                     ']
#
#  conv2d_57 (Conv2D)          (None, 8, 8, 64)             36928     ['activation_51[0][0]']
#
#  conv2d_58 (Conv2D)          (None, 8, 8, 64)             2112      ['activation_50[0][0]']
#
#  batch_normalization_52 (Ba  (None, 8, 8, 64)             256       ['conv2d_57[0][0]']
#  tchNormalization)
#
#  add_24 (Add)                (None, 8, 8, 64)             0         ['conv2d_58[0][0]',
#                                                                      'batch_normalization_52[0][0]
#                                                                     ']
#
#  activation_52 (Activation)  (None, 8, 8, 64)             0         ['add_24[0][0]']
#
#  conv2d_59 (Conv2D)          (None, 8, 8, 64)             36928     ['activation_52[0][0]']
#
#  batch_normalization_53 (Ba  (None, 8, 8, 64)             256       ['conv2d_59[0][0]']
#  tchNormalization)
#
#  activation_53 (Activation)  (None, 8, 8, 64)             0         ['batch_normalization_53[0][0]
#                                                                     ']
#
#  conv2d_60 (Conv2D)          (None, 8, 8, 64)             36928     ['activation_53[0][0]']
#
#  batch_normalization_54 (Ba  (None, 8, 8, 64)             256       ['conv2d_60[0][0]']
#  tchNormalization)
#
#  add_25 (Add)                (None, 8, 8, 64)             0         ['activation_52[0][0]',
#                                                                      'batch_normalization_54[0][0]
#                                                                     ']
#
#  activation_54 (Activation)  (None, 8, 8, 64)             0         ['add_25[0][0]']
#
#  conv2d_61 (Conv2D)          (None, 8, 8, 64)             36928     ['activation_54[0][0]']
#
#  batch_normalization_55 (Ba  (None, 8, 8, 64)             256       ['conv2d_61[0][0]']
#  tchNormalization)
#
#  activation_55 (Activation)  (None, 8, 8, 64)             0         ['batch_normalization_55[0][0]
#                                                                     ']
#
#  conv2d_62 (Conv2D)          (None, 8, 8, 64)             36928     ['activation_55[0][0]']
#
#  batch_normalization_56 (Ba  (None, 8, 8, 64)             256       ['conv2d_62[0][0]']
#  tchNormalization)
#
#  add_26 (Add)                (None, 8, 8, 64)             0         ['activation_54[0][0]',
#                                                                      'batch_normalization_56[0][0]
#                                                                     ']
#
#  activation_56 (Activation)  (None, 8, 8, 64)             0         ['add_26[0][0]']
#
#  average_pooling2d_2 (Avera  (None, 1, 1, 64)             0         ['activation_56[0][0]']
#  gePooling2D)
#
#  flatten_2 (Flatten)         (None, 64)                   0         ['average_pooling2d_2[0][0]']
#
#  dense_2 (Dense)             (None, 10)                   650       ['flatten_2[0][0]']
#
# ==================================================================================================
# Total params: 274442 (1.05 MB)
# Trainable params: 273066 (1.04 MB)
# Non-trainable params: 1376 (5.38 KB)
# __________________________________________________________________________________________________

# %%
save_dir = os.path.join(os.getcwd(), 'ResNet_v1')
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
    
filepath1 = os.path.join(save_dir, 'ResNet_v1.png')

keras.utils.plot_model(model=model,
                       to_file=filepath1,
                       show_shapes=True
                      )

# %%
def lr_schedule(epoch):
    # Learning Rate Schedule
    
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print(f"Learning rate: {lr}")
    return lr

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator

model_name = 'cifar10_%s_model.{epoch:03d}.h5' %model_type
filepath2 = os.path.join(save_dir, 'checkpoints/' + model_name)

lr_scheduler = LearningRateScheduler(lr_schedule)
checkpoints = ModelCheckpoint(filepath=filepath2,
                              monitor='val_accuracy',
                              verbose=1,
                              save_best_only=True
                             )

# 학습속도 감소 스케줄 전에 지표 개선이 정체되는 경우, 검증 손실이 patience세대 후에 개선되지 않으면 factor만큼 학습속도를 감소
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6
                              )
callbacks = [checkpoints, lr_reducer, lr_scheduler]

model.compile(loss='categorical_crossentropy',
              optimizer=keras.optimizers.Adam(learning_rate=lr_schedule(0)),
              metrics=['accuracy']
             )
# Out:
# Learning rate: 0.001

# %%
data_augmentation = True

if not data_augmentation:
    print("Not using data augmentation.")
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks
             )
else:
    print("Using real-time data augmentation.")
    #This will do preprocessing and realtime data augmentation
    datagen = ImageDataGenerator(
        # Set input mean to 0 over the dataset
        featurewise_center=False,
        
        # Set each sample mean to 0
        samplewise_center=False,
        
        # Divide inputs by std of dataset
        featurewise_std_normalization=False,
        
        # Divide each input by its std
        samplewise_std_normalization=False,
        
        # Apply ZCA whitening
        zca_whitening=False,
        
        # Epsilon for ZCA whitening
        zca_epsilon=1e-06,
        
        # Randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        
        # Randomly shift images horizontally
        width_shift_range=0.1,
        
        # Randomly shift images vertically
        height_shift_range=0.1,
        
        # Set range for random shear
        shear_range=0.,
        
        # Set range for random zoom
        zoom_range=0.,
        
        # Set range for random channel shifts
        channel_shift_range=0.,
        
        # Set mode for filling points outside the input boundaries
        fill_mode='nearest',
        
        # Value used for fill_mode = "constant"
        cval=0.,
        
        # Randomly flip images
        horizontal_flip=True,
        
        # Randomly flip images
        vertical_flip=False,
        
        # Set rescaling factor (applied before any other transformation)
        rescale=None,
        
        # Set function that will be applied on each input
        preprocessing_function=None,
        
        # Image data format, either "channels_first" or "channels_last"
        data_format=None,
        
        # Fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0
    )
    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied)
    datagen.fit(x_train)
    
    # Fit the model on the batches generated by datagen.flow().
    hist = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size),
                     epochs=epochs,
                     validation_data=(x_test, y_test),
                     callbacks=callbacks,
                     verbose=1, 
                     steps_per_epoch=250,
                     shuffle=True
                    )
    
    # Score trained model
    scores = model.evaluate(x_test, y_test, verbose=1)
    print("Test loss:", scores[0])
    print("Test accuracy:", scores[1])
# Out:
# Using real-time data augmentation.
# Learning rate: 0.001
# Epoch 1/200
# 2023-06-23 04:56:58.906251: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2023-06-23 04:57:04.868268: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-06-23 04:57:06.013753: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-06-23 04:57:06.097105: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7f4144001330 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-06-23 04:57:06.097148: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA A100 80GB PCIe MIG 1g.10gb, Compute Capability 8.0
# 2023-06-23 04:57:06.187906: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-06-23 04:57:06.546726: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 249/250 [============================>.] - ETA: 0s - loss: 2.0829 - accuracy: 0.3026
# Epoch 1: val_accuracy improved from -inf to 0.27330, saving model to /home/elicer/ResNet_v1/checkpoint/cifar10_ResNet20_v1_model.001.h5
# 250/250 [==============================] - 24s 31ms/step - loss: 2.0829 - accuracy: 0.3029 - val_loss: 2.1284 - val_accuracy: 0.2733 - lr: 0.0010
# Learning rate: 0.001
# Epoch 2/200
# 249/250 [============================>.] - ETA: 0s - loss: 1.7033 - accuracy: 0.4302
# Epoch 2: val_accuracy improved from 0.27330 to 0.45150, saving model to /home/elicer/ResNet_v1/checkpoint/cifar10_ResNet20_v1_model.002.h5
# 250/250 [==============================] - 6s 23ms/step - loss: 1.7028 - accuracy: 0.4306 - val_loss: 1.6513 - val_accuracy: 0.4515 - lr: 0.0010
# Learning rate: 0.001
# Epoch 3/200
# 249/250 [============================>.] - ETA: 0s - loss: 1.5872 - accuracy: 0.4886
# Epoch 3: val_accuracy improved from 0.45150 to 0.50870, saving model to /home/elicer/ResNet_v1/checkpoint/cifar10_ResNet20_v1_model.003.h5
# 250/250 [==============================] - 6s 23ms/step - loss:
- lr: 1.0000e-04
# Learning rate: 0.0001
# Epoch 103/200
# 250/250 [==============================] - ETA: 0s - loss: 0.4913 - accuracy: 0.8944
# Epoch 103: val_accuracy did not improve from 0.86960
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4913 - accuracy: 0.8944 - val_loss: 0.5789 - val_accuracy: 0.8665 - lr: 1.0000e-04
# Learning rate: 0.0001
# Epoch 104/200
# 247/250 [============================>.] - ETA: 0s - loss: 0.4908 - accuracy: 0.8907
# Epoch 104: val_accuracy did not improve from 0.86960
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4899 - accuracy: 0.8911 - val_loss: 0.5706 - val_accuracy: 0.8670 - lr: 1.0000e-04
# Learning rate: 0.0001
# Epoch 105/200
# 250/250 [==============================] - ETA: 0s - loss: 0.4871 - accuracy: 0.8890
# Epoch 105: val_accuracy did not improve from 0.86960
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4871 - accuracy: 0.8890 - val_loss: 0.5815 - val_accuracy: 0.8662 - lr: 1.0000e-04
# Learning rate: 0.0001
# Epoch 106/200
# 247/250 [============================>.] - ETA: 0s - loss: 0.4941 - accuracy: 0.8893
# Epoch 106: val_accuracy improved from 0.86960 to 0.87080, saving model to /home/elicer/ResNet_v1/checkpoint/cifar10_ResNet20_v1_model.106.h5
# 250/250 [==============================] - 6s 23ms/step - loss: 0.4932 - accuracy: 0.8894 - val_loss: 0.5668 - val_accuracy: 0.8708 - lr: 1.0000e-04
# Learning rate: 0.0001
# Epoch 107/200
# 250/250 [==============================] - ETA: 0s - loss: 0.4785 - accuracy: 0.8928
# Epoch 107: val_accuracy did not improve from 0.87080
# 250/250 [==============================] - 6s 23ms/step - loss: 0.4785 - accuracy: 0.8928 - val_loss: 0.5759 - val_accuracy: 0.8683 - lr: 1.0000e-04
# Learning rate: 0.0001
# Epoch 108/200
# 250/250 [==============================] - ETA: 0s - loss: 0.4897 - accuracy: 0.8864
# Epoch 108: val_accuracy did not improve from 0.87080
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4897 - accuracy: 0.8864 - val_loss: 0.5804 - val_accuracy: 0.8647 - lr: 1.0000e-04
# Learning rate: 0.0001
# Epoch 109/200
# 250/250 [==============================] - ETA: 0s - loss: 0.4881 - accuracy: 0.8881
# Epoch 109: val_accuracy improved from 0.87080 to 0.87250, saving model to /home/elicer/ResNet_v1/checkpoint/cifar10_ResNet20_v1_model.109.h5
# 250/250 [==============================] - 6s 23ms/step - loss: 0.4881 - accuracy: 0.8881 - val_loss: 0.5588 - val_accuracy: 0.8725 - lr: 1.0000e-04
# Learning rate: 0.0001
# Epoch 110/200
# 247/250 [============================>.] - ETA: 0s - loss: 0.4747 - accuracy: 0.8987
# Epoch 110: val_accuracy did not improve from 0.87250
# 250/250 [==============================] - 6s 23ms/step - loss: 0.4753 - accuracy: 0.8987 - val_loss: 0.5740 - val_accuracy: 0.8683 - lr: 1.0000e-04
# Learning rate: 0.0001
# Epoch 111/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4785 - accuracy: 0.8938
# Epoch 111: val_accuracy did not improve from 0.87250
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4789 - accuracy: 0.8939 - val_loss: 0.5623 - val_accuracy: 0.8695 - lr: 1.0000e-04
# Learning rate: 0.0001
# Epoch 112/200
# 248/250 [============================>.] - ETA: 0s - loss: 0.4824 - accuracy: 0.8908
# Epoch 112: val_accuracy did not improve from 0.87250
# 250/250 [==============================] - 6s 23ms/step - loss: 0.4828 - accuracy: 0.8907 - val_loss: 0.5756 - val_accuracy: 0.8663 - lr: 1.0000e-04
# Learning rate: 0.0001
# Epoch 113/200
# 247/250 [============================>.] - ETA: 0s - loss: 0.4875 - accuracy: 0.8908
# Epoch 113: val_accuracy did not improve from 0.87250
# 250/250 [==============================] - 5s 22ms/step - loss: 0.4878 - accuracy: 0.8909 - val_loss: 0.5576 - val_accuracy: 0.8712 - lr: 1.0000e-04
# Learning rate: 0.0001
# Epoch 114/200
# 250/250 [==============================] - ETA: 0s - loss: 0.4749 - accuracy: 0.8935
# Epoch 114: val_accuracy did not improve from 0.87250
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4749 - accuracy: 0.8935 - val_loss: 0.5591 - val_accuracy: 0.8722 - lr: 1.0000e-04
# Learning rate: 0.0001
# Epoch 115/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4753 - accuracy: 0.8957
# Epoch 115: val_accuracy did not improve from 0.87250
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4757 - accuracy: 0.8958 - val_loss: 0.5564 - val_accuracy: 0.8719 - lr: 1.0000e-04
# Learning rate: 0.0001
# Epoch 116/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4686 - accuracy: 0.8921
# Epoch 116: val_accuracy did not improve from 0.87250
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4684 - accuracy: 0.8920 - val_loss: 0.5654 - val_accuracy: 0.8689 - lr: 1.0000e-04
# Learning rate: 0.0001
# Epoch 117/200
# 248/250 [============================>.] - ETA: 0s - loss: 0.4574 - accuracy: 0.9001
# Epoch 117: val_accuracy did not improve from 0.87250
# 250/250 [==============================] - 5s 22ms/step - loss: 0.4568 - accuracy: 0.9005 - val_loss: 0.5577 - val_accuracy: 0.8708 - lr: 1.0000e-04
# Learning rate: 0.0001
# Epoch 118/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4834 - accuracy: 0.8936
# Epoch 118: val_accuracy did not improve from 0.87250
# 250/250 [==============================] - 5s 21ms/step - loss: 0.4826 - accuracy: 0.8940 - val_loss: 0.5695 - val_accuracy: 0.8680 - lr: 1.0000e-04
# Learning rate: 0.0001
# Epoch 119/200
# 248/250 [============================>.] - ETA: 0s - loss: 0.4617 - accuracy: 0.8986
# Epoch 119: val_accuracy did not improve from 0.87250
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4623 - accuracy: 0.8980 - val_loss: 0.5675 - val_accuracy: 0.8684 - lr: 1.0000e-04
# Learning rate: 0.0001
# Epoch 120/200
# 248/250 [============================>.] - ETA: 0s - loss: 0.4708 - accuracy: 0.8949
# Epoch 120: val_accuracy improved from 0.87250 to 0.87390, saving model to /home/elicer/ResNet_v1/checkpoint/cifar10_ResNet20_v1_model.120.h5
# 250/250 [==============================] - 6s 23ms/step - loss: 0.4704 - accuracy: 0.8951 - val_loss: 0.5496 - val_accuracy: 0.8739 - lr: 1.0000e-04
# Learning rate: 0.0001
# Epoch 121/200
# 248/250 [============================>.] - ETA: 0s - loss: 0.4665 - accuracy: 0.8933
# Epoch 121: val_accuracy did not improve from 0.87390
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4673 - accuracy: 0.8930 - val_loss: 0.5757 - val_accuracy: 0.8669 - lr: 1.0000e-04
# Learning rate: 1e-05
# Epoch 122/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4484 - accuracy: 0.8995
# Epoch 122: val_accuracy did not improve from 0.87390
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4491 - accuracy: 0.8991 - val_loss: 0.5537 - val_accuracy: 0.8728 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 123/200
# 250/250 [==============================] - ETA: 0s - loss: 0.4721 - accuracy: 0.8930
# Epoch 123: val_accuracy improved from 0.87390 to 0.87480, saving model to /home/elicer/ResNet_v1/checkpoint/cifar10_ResNet20_v1_model.123.h5
# 250/250 [==============================] - 6s 23ms/step - loss: 0.4721 - accuracy: 0.8930 - val_loss: 0.5482 - val_accuracy: 0.8748 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 124/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4657 - accuracy: 0.8931
# Epoch 124: val_accuracy improved from 0.87480 to 0.87500, saving model to /home/elicer/ResNet_v1/checkpoint/cifar10_ResNet20_v1_model.124.h5
# 250/250 [==============================] - 6s 23ms/step - loss: 0.4653 - accuracy: 0.8931 - val_loss: 0.5451 - val_accuracy: 0.8750 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 125/200
# 247/250 [============================>.] - ETA: 0s - loss: 0.4577 - accuracy: 0.8979
# Epoch 125: val_accuracy improved from 0.87500 to 0.87600, saving model to /home/elicer/ResNet_v1/checkpoint/cifar10_ResNet20_v1_model.125.h5
# 250/250 [==============================] - 6s 23ms/step - loss: 0.4566 - accuracy: 0.8985 - val_loss: 0.5477 - val_accuracy: 0.8760 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 126/200
# 250/250 [==============================] - ETA: 0s - loss: 0.4474 - accuracy: 0.9038
# Epoch 126: val_accuracy improved from 0.87600 to 0.87650, saving model to /home/elicer/ResNet_v1/checkpoint/cifar10_ResNet20_v1_model.126.h5
# 250/250 [==============================] - 6s 23ms/step - loss: 0.4474 - accuracy: 0.9038 - val_loss: 0.5426 - val_accuracy: 0.8765 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 127/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4596 - accuracy: 0.8996
# Epoch 127: val_accuracy did not improve from 0.87650
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4595 - accuracy: 0.8996 - val_loss: 0.5427 - val_accuracy: 0.8754 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 128/200
# 250/250 [==============================] - ETA: 0s - loss: 0.4443 - accuracy: 0.9044
# Epoch 128: val_accuracy did not improve from 0.87650
# 250/250 [==============================] - 6s 23ms/step - loss: 0.4443 - accuracy: 0.9044 - val_loss: 0.5406 - val_accuracy: 0.8763 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 129/200
# 250/250 [==============================] - ETA: 0s - loss: 0.4542 - accuracy: 0.9008
# Epoch 129: val_accuracy did not improve from 0.87650
# 250/250 [==============================] - 6s 23ms/step - loss: 0.4542 - accuracy: 0.9008 - val_loss: 0.5415 - val_accuracy: 0.8762 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 130/200
# 248/250 [============================>.] - ETA: 0s - loss: 0.4500 - accuracy: 0.9011
# Epoch 130: val_accuracy did not improve from 0.87650
# 250/250 [==============================] - 6s 23ms/step - loss: 0.4493 - accuracy: 0.9013 - val_loss: 0.5429 - val_accuracy: 0.8760 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 131/200
# 250/250 [==============================] - ETA: 0s - loss: 0.4432 - accuracy: 0.9039
# Epoch 131: val_accuracy improved from 0.87650 to 0.87670, saving model to /home/elicer/ResNet_v1/checkpoint/cifar10_ResNet20_v1_model.131.h5
# 250/250 [==============================] - 6s 23ms/step - loss: 0.4432 - accuracy: 0.9039 - val_loss: 0.5403 - val_accuracy: 0.8767 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 132/200
# 247/250 [============================>.] - ETA: 0s - loss: 0.4513 - accuracy: 0.9018
# Epoch 132: val_accuracy did not improve from 0.87670
# 250/250 [==============================] - 6s 23ms/step - loss: 0.4526 - accuracy: 0.9016 - val_loss: 0.5409 - val_accuracy: 0.8765 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 133/200
# 250/250 [==============================] - ETA: 0s - loss: 0.4423 - accuracy: 0.9014
# Epoch 133: val_accuracy did not improve from 0.87670
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4423 - accuracy: 0.9014 - val_loss: 0.5392 - val_accuracy: 0.8767 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 134/200
# 250/250 [==============================] - ETA: 0s - loss: 0.4515 - accuracy: 0.9000
# Epoch 134: val_accuracy did not improve from 0.87670
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4515 - accuracy: 0.9000 - val_loss: 0.5403 - val_accuracy: 0.8765 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 135/200
# 247/250 [============================>.] - ETA: 0s - loss: 0.4597 - accuracy: 0.8973
# Epoch 135: val_accuracy did not improve from 0.87670
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4607 - accuracy: 0.8969 - val_loss: 0.5403 - val_accuracy: 0.8758 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 136/200
# 250/250 [==============================] - ETA: 0s - loss: 0.4480 - accuracy: 0.9045
# Epoch 136: val_accuracy did not improve from 0.87670
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4480 - accuracy: 0.9045 - val_loss: 0.5413 - val_accuracy: 0.8754 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 137/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4597 - accuracy: 0.8995
# ...
# Learning rate: 1e-05
# Epoch 153/200
# 247/250 [============================>.] - ETA: 0s - loss: 0.4460 - accuracy: 0.8998
# Epoch 153: val_accuracy did not improve from 0.87790
# 250/250 [==============================] - 5s 22ms/step - loss: 0.4454 - accuracy: 0.9000 - val_loss: 0.5380 - val_accuracy: 0.8775 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 154/200
# 247/250 [============================>.] - ETA: 0s - loss: 0.4431 - accuracy: 0.9035
# Epoch 154: val_accuracy did not improve from 0.87790
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4428 - accuracy: 0.9034 - val_loss: 0.5367 - val_accuracy: 0.8770 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 155/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4462 - accuracy: 0.9049
# Epoch 155: val_accuracy did not improve from 0.87790
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4459 - accuracy: 0.9050 - val_loss: 0.5374 - val_accuracy: 0.8766 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 156/200
# 250/250 [==============================] - ETA: 0s - loss: 0.4497 - accuracy: 0.9030
# Epoch 156: val_accuracy did not improve from 0.87790
# 250/250 [==============================] - 6s 23ms/step - loss: 0.4497 - accuracy: 0.9030 - val_loss: 0.5381 - val_accuracy: 0.8774 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 157/200
# 247/250 [============================>.] - ETA: 0s - loss: 0.4505 - accuracy: 0.9045
# Epoch 157: val_accuracy did not improve from 0.87790
# 250/250 [==============================] - 6s 23ms/step - loss: 0.4508 - accuracy: 0.9045 - val_loss: 0.5382 - val_accuracy: 0.8764 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 158/200
# 247/250 [============================>.] - ETA: 0s - loss: 0.4535 - accuracy: 0.8993
# Epoch 158: val_accuracy did not improve from 0.87790
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4535 - accuracy: 0.8992 - val_loss: 0.5381 - val_accuracy: 0.8766 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 159/200
# 250/250 [==============================] - ETA: 0s - loss: 0.4411 - accuracy: 0.9067
# Epoch 159: val_accuracy did not improve from 0.87790
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4411 - accuracy: 0.9067 - val_loss: 0.5364 - val_accuracy: 0.8769 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 160/200
# 247/250 [============================>.] - ETA: 0s - loss: 0.4419 - accuracy: 0.9004
# Epoch 160: val_accuracy did not improve from 0.87790
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4416 - accuracy: 0.9006 - val_loss: 0.5362 - val_accuracy: 0.8777 - lr: 1.0000e-05
# Learning rate: 1e-05
# Epoch 161/200
# 250/250 [==============================] - ETA: 0s - loss: 0.4438 - accuracy: 0.9026
# Epoch 161: val_accuracy did not improve from 0.87790
# 250/250 [==============================] - 6s 23ms/step - loss: 0.4438 - accuracy: 0.9026 - val_loss: 0.5378 - val_accuracy: 0.8769 - lr: 1.0000e-05
# Learning rate: 1e-06
# Epoch 162/200
# 248/250 [============================>.] - ETA: 0s - loss: 0.4383 - accuracy: 0.9041
# Epoch 162: val_accuracy did not improve from 0.87790
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4394 - accuracy: 0.9038 - val_loss: 0.5372 - val_accuracy: 0.8768 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 163/200
# 248/250 [============================>.] - ETA: 0s - loss: 0.4481 - accuracy: 0.9011
# Epoch 163: val_accuracy did not improve from 0.87790
# 250/250 [==============================] - 6s 23ms/step - loss: 0.4478 - accuracy: 0.9013 - val_loss: 0.5365 - val_accuracy: 0.8769 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 164/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4530 - accuracy: 0.9019
# Epoch 164: val_accuracy did not improve from 0.87790
# 250/250 [==============================] - 6s 23ms/step - loss: 0.4533 - accuracy: 0.9018 - val_loss: 0.5367 - val_accuracy: 0.8766 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 165/200
# 247/250 [============================>.] - ETA: 0s - loss: 0.4447 - accuracy: 0.9017
# Epoch 165: val_accuracy did not improve from 0.87790
# 250/250 [==============================] - 5s 22ms/step - loss: 0.4445 - accuracy: 0.9016 - val_loss: 0.5365 - val_accuracy: 0.8769 - lr: 5.0000e-07
# Learning rate: 1e-06
# Epoch 166/200
# 248/250 [============================>.] - ETA: 0s - loss: 0.4438 - accuracy: 0.9031
# Epoch 166: val_accuracy improved from 0.87790 to 0.87800, saving model to /home/elicer/ResNet_v1/checkpoint/cifar10_ResNet20_v1_model.166.h5
# 250/250 [==============================] - 6s 23ms/step - loss: 0.4424 - accuracy: 0.9038 - val_loss: 0.5357 - val_accuracy: 0.8780 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 167/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4530 - accuracy: 0.9005
# Epoch 167: val_accuracy did not improve from 0.87800
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4531 - accuracy: 0.9005 - val_loss: 0.5351 - val_accuracy: 0.8774 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 168/200
# 248/250 [============================>.] - ETA: 0s - loss: 0.4334 - accuracy: 0.9054
# Epoch 168: val_accuracy improved from 0.87800 to 0.87820, saving model to /home/elicer/ResNet_v1/checkpoint/cifar10_ResNet20_v1_model.168.h5
# 250/250 [==============================] - 6s 23ms/step - loss: 0.4324 - accuracy: 0.9057 - val_loss: 0.5351 - val_accuracy: 0.8782 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 169/200
# 248/250 [============================>.] - ETA: 0s - loss: 0.4480 - accuracy: 0.9035
# Epoch 169: val_accuracy did not improve from 0.87820
# 250/250 [==============================] - 6s 23ms/step - loss: 0.4474 - accuracy: 0.9039 - val_loss: 0.5353 - val_accuracy: 0.8779 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 170/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4472 - accuracy: 0.9044
# Epoch 170: val_accuracy did not improve from 0.87820
# 250/250 [==============================] - 6s 23ms/step - loss: 0.4480 - accuracy: 0.9041 - val_loss: 0.5372 - val_accuracy: 0.8774 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 171/200
# 248/250 [============================>.] - ETA: 0s - loss: 0.4420 - accuracy: 0.9031
# Epoch 171: val_accuracy did not improve from 0.87820
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4410 - accuracy: 0.9035 - val_loss: 0.5375 - val_accuracy: 0.8770 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 172/200
# 250/250 [==============================] - ETA: 0s - loss: 0.4600 - accuracy: 0.8955
# Epoch 172: val_accuracy did not improve from 0.87820
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4600 - accuracy: 0.8955 - val_loss: 0.5362 - val_accuracy: 0.8776 - lr: 5.0000e-07
# Learning rate: 1e-06
# Epoch 173/200
# 247/250 [============================>.] - ETA: 0s - loss: 0.4445 - accuracy: 0.8999
# Epoch 173: val_accuracy did not improve from 0.87820
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4432 - accuracy: 0.9005 - val_loss: 0.5362 - val_accuracy: 0.8766 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 174/200
# 248/250 [============================>.] - ETA: 0s - loss: 0.4455 - accuracy: 0.9034
# Epoch 174: val_accuracy did not improve from 0.87820
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4451 - accuracy: 0.9036 - val_loss: 0.5355 - val_accuracy: 0.8767 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 175/200
# 250/250 [==============================] - ETA: 0s - loss: 0.4557 - accuracy: 0.9025
# Epoch 175: val_accuracy did not improve from 0.87820
# 250/250 [==============================] - 6s 23ms/step - loss: 0.4557 - accuracy: 0.9025 - val_loss: 0.5371 - val_accuracy: 0.8773 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 176/200
# 248/250 [============================>.] - ETA: 0s - loss: 0.4421 - accuracy: 0.9008
# Epoch 176: val_accuracy did not improve from 0.87820
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4420 - accuracy: 0.9009 - val_loss: 0.5354 - val_accuracy: 0.8776 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 177/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4470 - accuracy: 0.9007
# Epoch 177: val_accuracy did not improve from 0.87820
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4476 - accuracy: 0.9006 - val_loss: 0.5358 - val_accuracy: 0.8775 - lr: 5.0000e-07
# Learning rate: 1e-06
# Epoch 178/200
# 248/250 [============================>.] - ETA: 0s - loss: 0.4467 - accuracy: 0.9023
# Epoch 178: val_accuracy did not improve from 0.87820
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4465 - accuracy: 0.9025 - val_loss: 0.5359 - val_accuracy: 0.8781 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 179/200
# 248/250 [============================>.] - ETA: 0s - loss: 0.4512 - accuracy: 0.9071
# Epoch 179: val_accuracy improved from 0.87820 to 0.87860, saving model to /home/elicer/ResNet_v1/checkpoint/cifar10_ResNet20_v1_model.179.h5
# 250/250 [==============================] - 6s 23ms/step - loss: 0.4511 - accuracy: 0.9071 - val_loss: 0.5349 - val_accuracy: 0.8786 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 180/200
# 248/250 [============================>.] - ETA: 0s - loss: 0.4454 - accuracy: 0.9055
# Epoch 180: val_accuracy did not improve from 0.87860
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4453 - accuracy: 0.9055 - val_loss: 0.5369 - val_accuracy: 0.8772 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 181/200
# 247/250 [============================>.] - ETA: 0s - loss: 0.4394 - accuracy: 0.9049
# Epoch 181: val_accuracy did not improve from 0.87860
# 250/250 [==============================] - 6s 23ms/step - loss: 0.4389 - accuracy: 0.9050 - val_loss: 0.5347 - val_accuracy: 0.8780 - lr: 1.0000e-06
# Learning rate: 5e-07
# Epoch 182/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4482 - accuracy: 0.9007
# Epoch 182: val_accuracy did not improve from 0.87860
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4478 - accuracy: 0.9009 - val_loss: 0.5367 - val_accuracy: 0.8772 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 183/200
# 250/250 [==============================] - ETA: 0s - loss: 0.4479 - accuracy: 0.9007
# Epoch 183: val_accuracy did not improve from 0.87860
# 250/250 [==============================] - 5s 22ms/step - loss: 0.4479 - accuracy: 0.9007 - val_loss: 0.5366 - val_accuracy: 0.8775 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 184/200
# 247/250 [============================>.] - ETA: 0s - loss: 0.4391 - accuracy: 0.9068
# Epoch 184: val_accuracy did not improve from 0.87860
# 250/250 [==============================] - 5s 22ms/step - loss: 0.4378 - accuracy: 0.9076 - val_loss: 0.5352 - val_accuracy: 0.8778 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 185/200
# 248/250 [============================>.] - ETA: 0s - loss: 0.4502 - accuracy: 0.8989
# Epoch 185: val_accuracy did not improve from 0.87860
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4511 - accuracy: 0.8989 - val_loss: 0.5367 - val_accuracy: 0.8775 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 186/200
# 250/250 [==============================] - ETA: 0s - loss: 0.4475 - accuracy: 0.9019
# Epoch 186: val_accuracy did not improve from 0.87860
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4475 - accuracy: 0.9019 - val_loss: 0.5361 - val_accuracy: 0.8778 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 187/200
# 250/250 [==============================] - ETA: 0s - loss: 0.4395 - accuracy: 0.9041
# Epoch 187: val_accuracy did not improve from 0.87860
# 250/250 [==============================] - 6s 23ms/step - loss: 0.4395 - accuracy: 0.9041 - val_loss: 0.5363 - val_accuracy: 0.8771 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 188/200
# 250/250 [==============================] - ETA: 0s - loss: 0.4379 - accuracy: 0.9055
# Epoch 188: val_accuracy did not improve from 0.87860
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4379 - accuracy: 0.9055 - val_loss: 0.5390 - val_accuracy: 0.8773 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 189/200
# 248/250 [============================>.] - ETA: 0s - loss: 0.4525 - accuracy: 0.9017
# Epoch 189: val_accuracy did not improve from 0.87860
# 250/250 [==============================] - 6s 23ms/step - loss: 0.4526 - accuracy: 0.9015 - val_loss: 0.5376 - val_accuracy: 0.8768 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 190/200
# 248/250 [============================>.] - ETA: 0s - loss: 0.4305 - accuracy: 0.9112
# Epoch 190: val_accuracy did not improve from 0.87860
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4297 - accuracy: 0.9118 - val_loss: 0.5366 - val_accuracy: 0.8771 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 191/200
# 247/250 [============================>.] - ETA: 0s - loss: 0.4426 - accuracy: 0.9040
# Epoch 191: val_accuracy did not improve from 0.87860
# 250/250 [==============================] - 6s 23ms/step - loss: 0.4420 - accuracy: 0.9041 - val_loss: 0.5358 - val_accuracy: 0.8776 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 192/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4359 - accuracy: 0.9042
# Epoch 192: val_accuracy did not improve from 0.87860
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4354 - accuracy: 0.9045 - val_loss: 0.5345 - val_accuracy: 0.8778 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 193/200
# 248/250 [============================>.] - ETA: 0s - loss: 0.4576 - accuracy: 0.9010
# Epoch 193: val_accuracy did not improve from 0.87860
# 250/250 [==============================] - 6s 23ms/step - loss: 0.4583 - accuracy: 0.9003 - val_loss: 0.5368 - val_accuracy: 0.8772 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 194/200
# 248/250 [============================>.] - ETA: 0s - loss: 0.4186 - accuracy: 0.9149
# Epoch 194: val_accuracy did not improve from 0.87860
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4194 - accuracy: 0.9146 - val_loss: 0.5356 - val_accuracy: 0.8774 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 195/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4439 - accuracy: 0.9062
# Epoch 195: val_accuracy did not improve from 0.87860
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4433 - accuracy: 0.9064 - val_loss: 0.5350 - val_accuracy: 0.8776 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 196/200
# 249/250 [============================>.] - ETA: 0s - loss: 0.4385 - accuracy: 0.9090
# Epoch 196: val_accuracy did not improve from 0.87860
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4384 - accuracy: 0.9091 - val_loss: 0.5333 - val_accuracy: 0.8782 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 197/200
# 247/250 [============================>.] - ETA: 0s - loss: 0.4452 - accuracy: 0.9047
# Epoch 197: val_accuracy did not improve from 0.87860
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4440 - accuracy: 0.9051 - val_loss: 0.5361 - val_accuracy: 0.8765 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 198/200
# 248/250 [============================>.] - ETA: 0s - loss: 0.4404 - accuracy: 0.9076
# Epoch 198: val_accuracy did not improve from 0.87860
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4407 - accuracy: 0.9075 - val_loss: 0.5369 - val_accuracy: 0.8774 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 199/200
# 248/250 [============================>.] - ETA: 0s - loss: 0.4315 - accuracy: 0.9107
# Epoch 199: val_accuracy did not improve from 0.87860
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4309 - accuracy: 0.9111 - val_loss: 0.5338 - val_accuracy: 0.8782 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 200/200
# 250/250 [==============================] - ETA: 0s - loss: 0.4441 - accuracy: 0.9032
# Epoch 200: val_accuracy did not improve from 0.87860
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4441 - accuracy: 0.9032 - val_loss: 0.5356 - val_accuracy: 0.8778 - lr: 5.0000e-07
# 313/313 [==============================] - 1s 4ms/step - loss: 0.5356 - accuracy: 0.8778
# Test loss: 0.5355639457702637
# Test accuracy: 0.8777999877929688
