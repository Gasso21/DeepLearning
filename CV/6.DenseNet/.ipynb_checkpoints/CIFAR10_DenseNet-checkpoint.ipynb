# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %% [markdown]
# ## Dataset Loading and EDA

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np
import os
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
cifar10 = keras.datasets.cifar10
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

unique, counts = np.unique(y_train, return_counts=True)
print(f"Train Labels: {dict(zip(unique, counts))}")

unique, counts = np.unique(y_test, return_counts=True)
print(f"Test Labels: {dict(zip(unique, counts))}")
# Out:
# Train Labels: {0: 5000, 1: 5000, 2: 5000, 3: 5000, 4: 5000, 5: 5000, 6: 5000, 7: 5000, 8: 5000, 9: 5000}
# Test Labels: {0: 1000, 1: 1000, 2: 1000, 3: 1000, 4: 1000, 5: 1000, 6: 1000, 7: 1000, 8: 1000, 9: 1000}

# %% [markdown]
# ## Preprocessing

# %%
num_classes = len(np.unique(y_train))

x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# Subtracting pixel mean improves accuracy
subtract_pixel_mean=True
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

# %% [markdown]
# ## Modeling

# %%
from keras.layers import Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Flatten, Dense, Dropout

# %%
# Training Parameters
batch_size = 32
epochs = 5 # 200
data_augmentation = True

# Network Parameters
num_dense_blocks = 3
use_max_pool = False

growth_rate = 12
depth = 100
num_bottleneck_layers = (depth-4)//(2*num_dense_blocks)

num_filters_bef_dense_block = 2*growth_rate
compression_factor = 0.5

input_shape = x_train.shape[1:]

# %%
def densenet(input_shape, num_filters_bef_dense_block, num_dense_blocks, num_bottleneck_layers, data_augmentation, compression_factor, num_classes):
    inputs = keras.Input(shape=input_shape)
    
    # <BN-ReLU-Conv2D>
    x = BatchNormalization()(inputs)
    x = Activation('relu')(x)
    x = Conv2D(filters=num_filters_bef_dense_block,
               kernel_size=3,
               padding='same',
               kernel_initializer='he_normal'
              )(x)
    x = keras.layers.concatenate([inputs, x])
    
    # Stack of dense blocks bridged by transition layers
    for i in range(num_dense_blocks):
        
        # A dense block is a stack of bottleneck layers
        # <BN-ReLU-Conv2D> - <BN-ReLU-Conv2D> - Concat
        for j in range(num_bottleneck_layers):
            y = BatchNormalization()(x)
            y = Activation('relu')(y)
            y = Conv2D(4*growth_rate, # Limit the number of Filters (4xk)
                       kernel_size=1,
                       padding='same',
                       kernel_initializer='he_normal'
                      )(y)
            if not data_augmentation:
                y = Dropout(0.2)(y)
            y = BatchNormalization()(y) # Through Bottleneck Layer, 4xk filters are input BN Layer
            y = Activation('relu')(y)
            y = Conv2D(growth_rate,
                       kernel_size=3,
                       padding='same',
                       kernel_initializer='he_normal'
                      )(y)
            if not data_augmentation:
                y = Dropout(0.2)(y)
            x = keras.layers.concatenate([x, y])
        
        # No transition layer after the last dense block
        if i == num_dense_blocks - 1:
            continue
        
        # Transition layer compresses num of feature maps and reduces the size by 2
        num_filters_bef_dense_block += num_bottleneck_layers * growth_rate
        num_filters_bef_dense_block = int(num_filters_bef_dense_block * compression_factor) # Reduce num of feature map by 0.5 times
        y = BatchNormalization()(x)
        y = Conv2D(num_filters_bef_dense_block,
                   kernel_size=1,
                   padding='same',
                   kernel_initializer='he_normal'
                  )(y)
        if not data_augmentation:
            y = Dropout(0.2)(y)
        x = AveragePooling2D()(y) # Reduce num of filters by 0.5 times
    
    
    # add classifier on top
    # after average pooling size of feature map is 1 x 1
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    kernel_initializer='he_normal',
                    activation='softmax'
                   )(y)
    
    # instantiate and compile model
    # orig paper uses SGD but RMSprop works better for DenseNet
    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# %%
model = densenet(input_shape = input_shape,
                 num_filters_bef_dense_block = num_filters_bef_dense_block,
                 num_dense_blocks = num_dense_blocks,
                 num_bottleneck_layers = num_bottleneck_layers,
                 data_augmentation = True,
                 compression_factor = compression_factor,
                 num_classes = num_classes)

model.summary()
# Out:
# 2023-06-23 14:46:46.269600: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2023-06-23 14:46:46.269645: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2023-06-23 14:46:46.269656: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2023-06-23 14:46:46.269867: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-06-23 14:46:46.270213: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]          0         []
#
#  batch_normalization (Batch  (None, 32, 32, 3)            12        ['input_1[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 32, 32, 3)            0         ['batch_normalization[0][0]']
#
#  conv2d (Conv2D)             (None, 32, 32, 24)           672       ['activation[0][0]']
#
#  concatenate (Concatenate)   (None, 32, 32, 27)           0         ['input_1[0][0]',
#                                                                      'conv2d[0][0]']
#
#  batch_normalization_1 (Bat  (None, 32, 32, 27)           108       ['concatenate[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 32, 32, 27)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 48)           1344      ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 32, 32, 48)           192       ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 32, 32, 48)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 12)           5196      ['activation_2[0][0]']
#
#  concatenate_1 (Concatenate  (None, 32, 32, 39)           0         ['concatenate[0][0]',
#  )                                                                   'conv2d_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 32, 32, 39)           156       ['concatenate_1[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 32, 32, 39)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 48)           1920      ['activation_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 32, 32, 48)           192       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 32, 32, 48)           0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 12)           5196      ['activation_4[0][0]']
#
#  concatenate_2 (Concatenate  (None, 32, 32, 51)           0         ['concatenate_1[0][0]',
#  )                                                                   'conv2d_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 32, 32, 51)           204       ['concatenate_2[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 32, 32, 51)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 48)           2496      ['activation_5[0][0]']
#
#  batch_normalization_6 (Bat  (None, 32, 32, 48)           192       ['conv2d_5[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 32, 32, 48)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 12)           5196      ['activation_6[0][0]']
#
#  concatenate_3 (Concatenate  (None, 32, 32, 63)           0         ['concatenate_2[0][0]',
#  )                                                                   'conv2d_6[0][0]']
#
#  batch_normalization_7 (Bat  (None, 32, 32, 63)           252       ['concatenate_3[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 32, 32, 63)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 48)           3072      ['activation_7[0][0]']
#
#  batch_normalization_8 (Bat  (None, 32, 32, 48)           192       ['conv2d_7[0][0]']
#  chNormalization)
#  activation_8 (Activation)   (None, 32, 32, 48)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_8 (Conv2D)           (None, 32, 32, 12)           5196      ['activation_8[0][0]']
#
#  concatenate_4 (Concatenate  (None, 32, 32, 75)           0         ['concatenate_3[0][0]',
#  )                                                                   'conv2d_8[0][0]']
#
#  batch_normalization_9 (Bat  (None, 32, 32, 75)           300       ['concatenate_4[0][0]']
#  chNormalization)
#
#  activation_9 (Activation)   (None, 32, 32, 75)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 48)           3648      ['activation_9[0][0]']
#
#  batch_normalization_10 (Ba  (None, 32, 32, 48)           192       ['conv2d_9[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 32, 32, 48)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv2d_10 (Conv2D)          (None, 32, 32, 12)           5196      ['activation_10[0][0]']
#
#  concatenate_5 (Concatenate  (None, 32, 32, 87)           0         ['concatenate_4[0][0]',
#  )                                                                   'conv2d_10[0][0]']
#
#  batch_normalization_11 (Ba  (None, 32, 32, 87)           348       ['concatenate_5[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 32, 32, 87)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_11 (Conv2D)          (None, 32, 32, 48)           4224      ['activation_11[0][0]']
#
#  batch_normalization_12 (Ba  (None, 32, 32, 48)           192       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 32, 32, 48)           0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_12 (Conv2D)          (None, 32, 32, 12)           5196      ['activation_12[0][0]']
#
#  concatenate_6 (Concatenate  (None, 32, 32, 99)           0         ['concatenate_5[0][0]',
#  )                                                                   'conv2d_12[0][0]']
#
#  batch_normalization_13 (Ba  (None, 32, 32, 99)           396       ['concatenate_6[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 32, 32, 99)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 48)           4800      ['activation_13[0][0]']
#
#  batch_normalization_14 (Ba  (None, 32, 32, 48)           192       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  activation_14 (Activation)  (None, 32, 32, 48)           0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_14 (Conv2D)          (None, 32, 32, 12)           5196      ['activation_14[0][0]']
#
#  concatenate_7 (Concatenate  (None, 32, 32, 111)          0         ['concatenate_6[0][0]',
#  )                                                                   'conv2d_14[0][0]']
#
#  batch_normalization_15 (Ba  (None, 32, 32, 111)          444       ['concatenate_7[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 32, 32, 111)          0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, 32, 32, 48)           5376      ['activation_15[0][0]']
#
#  batch_normalization_16 (Ba  (None, 32, 32, 48)           192       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_16 (Activation)  (None, 32, 32, 48)           0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_16 (Conv2D)          (None, 32, 32, 12)           5196      ['activation_16[0][0]']
#
#  concatenate_8 (Concatenate  (None, 32, 32, 123)          0         ['concatenate_7[0][0]',
#  )                                                                   'conv2d_16[0][0]']
#
#  batch_normalization_17 (Ba  (None, 32, 32, 123)          492       ['concatenate_8[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 32, 32, 123)          0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  conv2d_17 (Conv2D)          (None, 32, 32, 48)           5952      ['activation_17[0][0]']
#
#  batch_normalization_18 (Ba  (None, 32, 32, 48)           192       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 32, 32, 48)           0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_18 (Conv2D)          (None, 32, 32, 12)           5196      ['activation_18[0][0]']
#
#  concatenate_9 (Concatenate  (None, 32, 32, 135)          0         ['concatenate_8[0][0]',
#  )                                                                   'conv2d_18[0][0]']
#
#  batch_normalization_19 (Ba  (None, 32, 32, 135)          540       ['concatenate_9[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 32, 32, 135)          0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 32, 32, 48)           6528      ['activation_19[0][0]']
#
#  batch_normalization_20 (Ba  (None, 32, 32, 48)           192       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 32, 32, 48)           0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 32, 32, 12)           5196      ['activation_20[0][0]']
#
#  concatenate_10 (Concatenat  (None, 32, 32, 147)          0         ['concatenate_9[0][0]',
#  e)                                                                  'conv2d_20[0][0]']
#
#  batch_normalization_21 (Ba  (None, 32, 32, 147)          588       ['concatenate_10[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 32, 32, 147)          0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_21 (Conv2D)          (None, 32, 32, 48)           7104      ['activation_21[0][0]']
#
#  batch_normalization_22 (Ba  (None, 32, 32, 48)           192       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  activation_22 (Activation)  (None, 32, 32, 48)           0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_22 (Conv2D)          (None, 32, 32, 12)           5196      ['activation_22[0][0]']
#
#  concatenate_11 (Concatenat  (None, 32, 32, 159)          0         ['concatenate_10[0][0]',
#  e)                                                                  'conv2d_22[0][0]']
#
#  batch_normalization_23 (Ba  (None, 32, 32, 159)          636       ['concatenate_11[0][0]']
#  tchNormalization)
#
#  activation_23 (Activation)  (None, 32, 32, 159)          0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  conv2d_23 (Conv2D)          (None, 32, 32, 48)           7680      ['activation_23[0][0]']
#
#  batch_normalization_24 (Ba  (None, 32, 32, 48)           192       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 32, 32, 48)           0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 32, 32, 12)           5196      ['activation_24[0][0]']
#
#  concatenate_12 (Concatenat  (None, 32, 32, 171)          0         ['concatenate_11[0][0]',
#  e)                                                                  'conv2d_24[0][0]']
#
#  batch_normalization_25 (Ba  (None, 32, 32, 171)          684       ['concatenate_12[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 32, 32, 171)          0         ['batch_normalization_25[0][0]
#                                                                     ']
#  conv2d_25 (Conv2D)          (None, 32, 32, 48)           8256      ['activation_25[0][0]']
#
#  batch_normalization_26 (Ba  (None, 32, 32, 48)           192       ['conv2d_25[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 32, 32, 48)           0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 32, 32, 12)           5196      ['activation_26[0][0]']
#
#  concatenate_13 (Concatenat  (None, 32, 32, 183)          0         ['concatenate_12[0][0]',
#  e)                                                                  'conv2d_26[0][0]']
#
#  batch_normalization_27 (Ba  (None, 32, 32, 183)          732       ['concatenate_13[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 32, 32, 183)          0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_27 (Conv2D)          (None, 32, 32, 48)           8832      ['activation_27[0][0]']
#
#  batch_normalization_28 (Ba  (None, 32, 32, 48)           192       ['conv2d_27[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 32, 32, 48)           0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_28 (Conv2D)          (None, 32, 32, 12)           5196      ['activation_28[0][0]']
#
#  concatenate_14 (Concatenat  (None, 32, 32, 195)          0         ['concatenate_13[0][0]',
#  e)                                                                  'conv2d_28[0][0]']
#
#  batch_normalization_29 (Ba  (None, 32, 32, 195)          780       ['concatenate_14[0][0]']
#  tchNormalization)
#
#  activation_29 (Activation)  (None, 32, 32, 195)          0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  conv2d_29 (Conv2D)          (None, 32, 32, 48)           9408      ['activation_29[0][0]']
#
#  batch_normalization_30 (Ba  (None, 32, 32, 48)           192       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 32, 32, 48)           0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 32, 32, 12)           5196      ['activation_30[0][0]']
#
#  concatenate_15 (Concatenat  (None, 32, 32, 207)          0         ['concatenate_14[0][0]',
#  e)                                                                  'conv2d_30[0][0]']
#
#  batch_normalization_31 (Ba  (None, 32, 32, 207)          828       ['concatenate_15[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 32, 32, 207)          0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 32, 32, 48)           9984      ['activation_31[0][0]']
#
#  batch_normalization_32 (Ba  (None, 32, 32, 48)           192       ['conv2d_31[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 32, 32, 48)           0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  conv2d_32 (Conv2D)          (None, 32, 32, 12)           5196      ['activation_32[0][0]']
#
#  concatenate_16 (Concatenat  (None, 32, 32, 219)          0         ['concatenate_15[0][0]',
#  e)                                                                  'conv2d_32[0][0]']
#
#  batch_normalization_33 (Ba  (None, 32, 32, 219)          876       ['concatenate_16[0][0]']
#  tchNormalization)
#
#  conv2d_33 (Conv2D)          (None, 32, 32, 108)          23760     ['batch_normalization_33[0][0]
#                                                                     ']
#
#  average_pooling2d (Average  (None, 16, 16, 108)          0         ['conv2d_33[0][0]']
#  Pooling2D)
#
#  batch_normalization_34 (Ba  (None, 16, 16, 108)          432       ['average_pooling2d[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 16, 16, 108)          0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_34 (Conv2D)          (None, 16, 16, 48)           5232      ['activation_33[0][0]']
#
#  batch_normalization_35 (Ba  (None, 16, 16, 48)           192       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_34 (Activation)  (None, 16, 16, 48)           0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  conv2d_35 (Conv2D)          (None, 16, 16, 12)           5196      ['activation_34[0][0]']
#
#  concatenate_17 (Concatenat  (None, 16, 16, 120)          0         ['average_pooling2d[0][0]',
#  e)                                                                  'conv2d_35[0][0]']
#
#  batch_normalization_36 (Ba  (None, 16, 16, 120)          480       ['concatenate_17[0][0]']
#  tchNormalization)
#
#  activation_35 (Activation)  (None, 16, 16, 120)          0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 16, 16, 48)           5808      ['activation_35[0][0]']
#
#  batch_normalization_37 (Ba  (None, 16, 16, 48)           192       ['conv2d_36[0][0]']
#  tchNormalization)
#
#  activation_36 (Activation)  (None, 16, 16, 48)           0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 16, 16, 12)           5196      ['activation_36[0][0]']
#
#  concatenate_18 (Concatenat  (None, 16, 16, 132)          0         ['concatenate_17[0][0]',
#  e)                                                                  'conv2d_37[0][0]']
#
#  batch_normalization_38 (Ba  (None, 16, 16, 132)          528       ['concatenate_18[0][0]']
#  tchNormalization)
#
#  activation_37 (Activation)  (None, 16, 16, 132)          0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  conv2d_38 (Conv2D)          (None, 16, 16, 48)           6384      ['activation_37[0][0]']
#
#  batch_normalization_39 (Ba  (None, 16, 16, 48)           192       ['conv2d_38[0][0]']
#  tchNormalization)
#
#  activation_38 (Activation)  (None, 16, 16, 48)           0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  conv2d_39 (Conv2D)          (None, 16, 16, 12)           5196      ['activation_38[0][0]']
#
#  concatenate_19 (Concatenat  (None, 16, 16, 144)          0         ['concatenate_18[0][0]',
#  e)                                                                  'conv2d_39[0][0]']
#
#  batch_normalization_40 (Ba  (None, 16, 16, 144)          576       ['concatenate_19[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, 16, 16, 144)          0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  conv2d_40 (Conv2D)          (None, 16, 16, 48)           6960      ['activation_39[0][0]']
#
#  batch_normalization_41 (Ba  (None, 16, 16, 48)           192       ['conv2d_40[0][0]']
#  tchNormalization)
#
#  activation_40 (Activation)  (None, 16, 16, 48)           0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  conv2d_41 (Conv2D)          (None, 16, 16, 12)           5196      ['activation_40[0][0]']
#
#  concatenate_20 (Concatenat  (None, 16, 16, 156)          0         ['concatenate_19[0][0]',
#  e)                                                                  'conv2d_41[0][0]']
#
#  batch_normalization_42 (Ba  (None, 16, 16, 156)          624       ['concatenate_20[0][0]']
#  tchNormalization)
#
#  activation_41 (Activation)  (None, 16, 16, 156)          0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 16, 16, 48)           7536      ['activation_41[0][0]']
#
#  batch_normalization_43 (Ba  (None, 16, 16, 48)           192       ['conv2d_42[0][0]']
#  tchNormalization)
#  activation_42 (Activation)  (None, 16, 16, 48)           0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 16, 16, 12)           5196      ['activation_42[0][0]']
#
#  concatenate_21 (Concatenat  (None, 16, 16, 168)          0         ['concatenate_20[0][0]',
#  e)                                                                  'conv2d_43[0][0]']
#
#  batch_normalization_44 (Ba  (None, 16, 16, 168)          672       ['concatenate_21[0][0]']
#  tchNormalization)
#
#  activation_43 (Activation)  (None, 16, 16, 168)          0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  conv2d_44 (Conv2D)          (None, 16, 16, 48)           8112      ['activation_43[0][0]']
#
#  batch_normalization_45 (Ba  (None, 16, 16, 48)           192       ['conv2d_44[0][0]']
#  tchNormalization)
#
#  activation_44 (Activation)  (None, 16, 16, 48)           0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_45 (Conv2D)          (None, 16, 16, 12)           5196      ['activation_44[0][0]']
#
#  concatenate_22 (Concatenat  (None, 16, 16, 180)          0         ['concatenate_21[0][0]',
#  e)                                                                  'conv2d_45[0][0]']
#
#  batch_normalization_46 (Ba  (None, 16, 16, 180)          720       ['concatenate_22[0][0]']
#  tchNormalization)
#
#  activation_45 (Activation)  (None, 16, 16, 180)          0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  conv2d_46 (Conv2D)          (None, 16, 16, 48)           8688      ['activation_45[0][0]']
#
#  batch_normalization_47 (Ba  (None, 16, 16, 48)           192       ['conv2d_46[0][0]']
#  tchNormalization)
#
#  activation_46 (Activation)  (None, 16, 16, 48)           0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  conv2d_47 (Conv2D)          (None, 16, 16, 12)           5196      ['activation_46[0][0]']
#
#  concatenate_23 (Concatenat  (None, 16, 16, 192)          0         ['concatenate_22[0][0]',
#  e)                                                                  'conv2d_47[0][0]']
#
#  batch_normalization_48 (Ba  (None, 16, 16, 192)          768       ['concatenate_23[0][0]']
#  tchNormalization)
#
#  activation_47 (Activation)  (None, 16, 16, 192)          0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  conv2d_48 (Conv2D)          (None, 16, 16, 48)           9264      ['activation_47[0][0]']
#
#  batch_normalization_49 (Ba  (None, 16, 16, 48)           192       ['conv2d_48[0][0]']
#  tchNormalization)
#
#  activation_48 (Activation)  (None, 16, 16, 48)           0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  conv2d_49 (Conv2D)          (None, 16, 16, 12)           5196      ['activation_48[0][0]']
#
#  concatenate_24 (Concatenat  (None, 16, 16, 204)          0         ['concatenate_23[0][0]',
#  e)                                                                  'conv2d_49[0][0]']
#
#  batch_normalization_50 (Ba  (None, 16, 16, 204)          816       ['concatenate_24[0][0]']
# ...
#  batch_normalization_83 (Ba  (None, 8, 8, 246)            984       ['concatenate_40[0][0]']
#  tchNormalization)
#
#  activation_81 (Activation)  (None, 8, 8, 246)            0         ['batch_normalization_83[0][0]
#                                                                     ']
#
#  conv2d_83 (Conv2D)          (None, 8, 8, 48)             11856     ['activation_81[0][0]']
#
#  batch_normalization_84 (Ba  (None, 8, 8, 48)             192       ['conv2d_83[0][0]']
#  tchNormalization)
#
#  activation_82 (Activation)  (None, 8, 8, 48)             0         ['batch_normalization_84[0][0]
#                                                                     ']
#
#  conv2d_84 (Conv2D)          (None, 8, 8, 12)             5196      ['activation_82[0][0]']
#
#  concatenate_41 (Concatenat  (None, 8, 8, 258)            0         ['concatenate_40[0][0]',
#  e)                                                                  'conv2d_84[0][0]']
#
#  batch_normalization_85 (Ba  (None, 8, 8, 258)            1032      ['concatenate_41[0][0]']
#  tchNormalization)
#
#  activation_83 (Activation)  (None, 8, 8, 258)            0         ['batch_normalization_85[0][0]
#                                                                     ']
#
#  conv2d_85 (Conv2D)          (None, 8, 8, 48)             12432     ['activation_83[0][0]']
#
#  batch_normalization_86 (Ba  (None, 8, 8, 48)             192       ['conv2d_85[0][0]']
#  tchNormalization)
#
#  activation_84 (Activation)  (None, 8, 8, 48)             0         ['batch_normalization_86[0][0]
#                                                                     ']
#
#  conv2d_86 (Conv2D)          (None, 8, 8, 12)             5196      ['activation_84[0][0]']
#
#  concatenate_42 (Concatenat  (None, 8, 8, 270)            0         ['concatenate_41[0][0]',
#  e)                                                                  'conv2d_86[0][0]']
#
#  batch_normalization_87 (Ba  (None, 8, 8, 270)            1080      ['concatenate_42[0][0]']
#  tchNormalization)
#
#  activation_85 (Activation)  (None, 8, 8, 270)            0         ['batch_normalization_87[0][0]
#                                                                     ']
#
#  conv2d_87 (Conv2D)          (None, 8, 8, 48)             13008     ['activation_85[0][0]']
#
#  batch_normalization_88 (Ba  (None, 8, 8, 48)             192       ['conv2d_87[0][0]']
#  tchNormalization)
#
#  activation_86 (Activation)  (None, 8, 8, 48)             0         ['batch_normalization_88[0][0]
#                                                                     ']
#
#  conv2d_88 (Conv2D)          (None, 8, 8, 12)             5196      ['activation_86[0][0]']
#
#  concatenate_43 (Concatenat  (None, 8, 8, 282)            0         ['concatenate_42[0][0]',
#  e)                                                                  'conv2d_88[0][0]']
#
#  batch_normalization_89 (Ba  (None, 8, 8, 282)            1128      ['concatenate_43[0][0]']
#  tchNormalization)
#
#  activation_87 (Activation)  (None, 8, 8, 282)            0         ['batch_normalization_89[0][0]
#                                                                     ']
#
#  conv2d_89 (Conv2D)          (None, 8, 8, 48)             13584     ['activation_87[0][0]']
#
#  batch_normalization_90 (Ba  (None, 8, 8, 48)             192       ['conv2d_89[0][0]']
#  tchNormalization)
#
#  activation_88 (Activation)  (None, 8, 8, 48)             0         ['batch_normalization_90[0][0]
#                                                                     ']
#
#  conv2d_90 (Conv2D)          (None, 8, 8, 12)             5196      ['activation_88[0][0]']
#
#  concatenate_44 (Concatenat  (None, 8, 8, 294)            0         ['concatenate_43[0][0]',
#  e)                                                                  'conv2d_90[0][0]']
#
#  batch_normalization_91 (Ba  (None, 8, 8, 294)            1176      ['concatenate_44[0][0]']
#  tchNormalization)
#
#  activation_89 (Activation)  (None, 8, 8, 294)            0         ['batch_normalization_91[0][0]
#                                                                     ']
#
#  conv2d_91 (Conv2D)          (None, 8, 8, 48)             14160     ['activation_89[0][0]']
#
#  batch_normalization_92 (Ba  (None, 8, 8, 48)             192       ['conv2d_91[0][0]']
#  tchNormalization)
#
#  activation_90 (Activation)  (None, 8, 8, 48)             0         ['batch_normalization_92[0][0]
#                                                                     ']
#
#  conv2d_92 (Conv2D)          (None, 8, 8, 12)             5196      ['activation_90[0][0]']
#
#  concatenate_45 (Concatenat  (None, 8, 8, 306)            0         ['concatenate_44[0][0]',
#  e)                                                                  'conv2d_92[0][0]']
#
#  batch_normalization_93 (Ba  (None, 8, 8, 306)            1224      ['concatenate_45[0][0]']
#  tchNormalization)
#
#  activation_91 (Activation)  (None, 8, 8, 306)            0         ['batch_normalization_93[0][0]
#                                                                     ']
#
#  conv2d_93 (Conv2D)          (None, 8, 8, 48)             14736     ['activation_91[0][0]']
#
#  batch_normalization_94 (Ba  (None, 8, 8, 48)             192       ['conv2d_93[0][0]']
#  tchNormalization)
#
#  activation_92 (Activation)  (None, 8, 8, 48)             0         ['batch_normalization_94[0][0]
#                                                                     ']
#
#  conv2d_94 (Conv2D)          (None, 8, 8, 12)             5196      ['activation_92[0][0]']
#
#  concatenate_46 (Concatenat  (None, 8, 8, 318)            0         ['concatenate_45[0][0]',
#  e)                                                                  'conv2d_94[0][0]']
#
#  batch_normalization_95 (Ba  (None, 8, 8, 318)            1272      ['concatenate_46[0][0]']
#  tchNormalization)
#
#  activation_93 (Activation)  (None, 8, 8, 318)            0         ['batch_normalization_95[0][0]
#                                                                     ']
#  conv2d_95 (Conv2D)          (None, 8, 8, 48)             15312     ['activation_93[0][0]']
#
#  batch_normalization_96 (Ba  (None, 8, 8, 48)             192       ['conv2d_95[0][0]']
#  tchNormalization)
#
#  activation_94 (Activation)  (None, 8, 8, 48)             0         ['batch_normalization_96[0][0]
#                                                                     ']
#
#  conv2d_96 (Conv2D)          (None, 8, 8, 12)             5196      ['activation_94[0][0]']
#
#  concatenate_47 (Concatenat  (None, 8, 8, 330)            0         ['concatenate_46[0][0]',
#  e)                                                                  'conv2d_96[0][0]']
#
#  batch_normalization_97 (Ba  (None, 8, 8, 330)            1320      ['concatenate_47[0][0]']
#  tchNormalization)
#
#  activation_95 (Activation)  (None, 8, 8, 330)            0         ['batch_normalization_97[0][0]
#                                                                     ']
#
#  conv2d_97 (Conv2D)          (None, 8, 8, 48)             15888     ['activation_95[0][0]']
#
#  batch_normalization_98 (Ba  (None, 8, 8, 48)             192       ['conv2d_97[0][0]']
#  tchNormalization)
#
#  activation_96 (Activation)  (None, 8, 8, 48)             0         ['batch_normalization_98[0][0]
#                                                                     ']
#
#  conv2d_98 (Conv2D)          (None, 8, 8, 12)             5196      ['activation_96[0][0]']
#
#  concatenate_48 (Concatenat  (None, 8, 8, 342)            0         ['concatenate_47[0][0]',
#  e)                                                                  'conv2d_98[0][0]']
#
#  average_pooling2d_2 (Avera  (None, 1, 1, 342)            0         ['concatenate_48[0][0]']
#  gePooling2D)
#
#  flatten (Flatten)           (None, 342)                  0         ['average_pooling2d_2[0][0]']
#
#  dense (Dense)               (None, 10)                   3430      ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 797788 (3.04 MB)
# Trainable params: 774376 (2.95 MB)
# Non-trainable params: 23412 (91.45 KB)
# __________________________________________________________________________________________________

# %%
save_dir = os.path.join(os.getcwd(), 'DenseNet')
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
    
filepath1 = os.path.join(save_dir, 'DenseNet.png')

keras.utils.plot_model(model=model,
                       to_file=filepath1,
                       show_shapes=True
                      )

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=keras.optimizers.RMSprop(1e-3),
              metrics=['accuracy']
             )

# %%
def lr_schedule(epoch):
    # Learning Rate Schedule
    
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print(f"Learning rate: {lr}")
    return lr

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
import os

# %%
# Prepare model saving directory
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_densenet_model.{epoch:02d}.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir) # 경로 상의 모든 폴더들을 다 만들어줌
filepath = os.path.join(save_dir, model_name)

# %%
# Prepare callbacks for model saving and for learning rate adjustment
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True
                            )
lr_scheduler = LearningRateScheduler(lr_schedule)

# 학습속도 감소 스케줄 전에 지표 개선이 정체되는 경우, 검증 손실이 patience세대 후에 개선되지 않으면 factor만큼 학습속도를 감소
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6
                              )
callbacks = [checkpoint, lr_reducer, lr_scheduler]

# %%
if not data_augmentation:
    print("Not using data augmentation.")
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks
             )
else:
    print("Using real-time data augmentation.")
    #This will do preprocessing and realtime data augmentation
    datagen = ImageDataGenerator(
        # Set input mean to 0 over the dataset
        featurewise_center=False,
        
        # Set each sample mean to 0
        samplewise_center=False,
        
        # Divide inputs by std of dataset
        featurewise_std_normalization=False,
        
        # Divide each input by its std
        samplewise_std_normalization=False,
        
        # Apply ZCA whitening
        zca_whitening=False,
        
        # Epsilon for ZCA whitening
        zca_epsilon=1e-06,
        
        # Randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        
        # Randomly shift images horizontally
        width_shift_range=0.1,
        
        # Randomly shift images vertically
        height_shift_range=0.1,
        
        # Set range for random shear
        shear_range=0.,
        
        # Set range for random zoom
        zoom_range=0.,
        
        # Set range for random channel shifts
        channel_shift_range=0.,
        
        # Set mode for filling points outside the input boundaries
        fill_mode='nearest',
        
        # Value used for fill_mode = "constant"
        cval=0.,
        
        # Randomly flip images
        horizontal_flip=True,
        
        # Randomly flip images
        vertical_flip=False,
        
        # Set rescaling factor (applied before any other transformation)
        rescale=None,
        
        # Set function that will be applied on each input
        preprocessing_function=None,
        
        # Image data format, either "channels_first" or "channels_last"
        data_format=None,
        
        # Fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0
    )
    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied)
    datagen.fit(x_train)
    
    # Fit the model on the batches generated by datagen.flow().
    model.fit(datagen.flow(x_train, y_train, batch_size=batch_size),
              validation_data=(x_test, y_test),
              epochs=epochs, verbose=1,
              steps_per_epoch=x_train.shape[0] // batch_size,
              callbacks=callbacks
             )
    
    # Score trained model
    scores = model.evaluate(x_test, y_test, verbose=1)
    print("Test loss:", scores[0])
    print("Test accuracy:", scores[1])
# Out:
# Using real-time data augmentation.
# Learning rate: 0.001
# Epoch 1/5
# 1562/1562 [==============================] - ETA: 0s - loss: 1.5175 - accuracy: 0.4547
# Epoch 1: val_accuracy improved from -inf to 0.58890, saving model to /content/saved_models/cifar10_densenet_model.01.h5
# 1562/1562 [==============================] - 222s 128ms/step - loss: 1.5175 - accuracy: 0.4547 - val_loss: 1.1929 - val_accuracy: 0.5889 - lr: 0.0010
# Learning rate: 0.001
# Epoch 2/5
# 1562/1562 [==============================] - ETA: 0s - loss: 1.0025 - accuracy: 0.6463
# Epoch 2: val_accuracy did not improve from 0.58890
# 1562/1562 [==============================] - 197s 126ms/step - loss: 1.0025 - accuracy: 0.6463 - val_loss: 1.3257 - val_accuracy: 0.5872 - lr: 0.0010
# Learning rate: 0.001
# Epoch 3/5
# 1562/1562 [==============================] - ETA: 0s - loss: 0.7622 - accuracy: 0.7334
# Epoch 3: val_accuracy improved from 0.58890 to 0.74090, saving model to /content/saved_models/cifar10_densenet_model.03.h5
# 1562/1562 [==============================] - 197s 126ms/step - loss: 0.7622 - accuracy: 0.7334 - val_loss: 0.7645 - val_accuracy: 0.7409 - lr: 0.0010
# Learning rate: 0.001
# Epoch 4/5
# 1562/1562 [==============================] - ETA: 0s - loss: 0.6437 - accuracy: 0.7777
# Epoch 4: val_accuracy improved from 0.74090 to 0.78100, saving model to /content/saved_models/cifar10_densenet_model.04.h5
# 1562/1562 [==============================] - 196s 126ms/step - loss: 0.6437 - accuracy: 0.7777 - val_loss: 0.6325 - val_accuracy: 0.7810 - lr: 0.0010
# Learning rate: 0.001
# Epoch 5/5
# 1562/1562 [==============================] - ETA: 0s - loss: 0.5678 - accuracy: 0.8055
# Epoch 5: val_accuracy did not improve from 0.78100
# 1562/1562 [==============================] - 197s 126ms/step - loss: 0.5678 - accuracy: 0.8055 - val_loss: 0.7913 - val_accuracy: 0.7613 - lr: 0.0010
# 313/313 [==============================] - 9s 30ms/step - loss: 0.7913 - accuracy: 0.7613
# Test loss: 0.7913462519645691
# Test accuracy: 0.7613000273704529
