# %% [markdown]
# # Attention is All your Need

# %%
import torch
import torch.nn as nn
import torch.optim as optim

from torchtext.legacy.datasets import Multi30 # Datasets for Machine Laguage Translation
from torchtext.legacy import data, datasets

import spacy # Preprocessing Library, Tokenizing
import numpy as np

import random
import math
import time
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 5
#       2 import torch.nn as nn
#       3 import torch.optim as optim
# ----> 5 from torchtext.legacy.datasets import Multi30 # Datasets for Machine Laguage Translation
#       6 from torchtext.legacy import data, datasets
#       8 import spacy
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/torchtext/__init__.py:12
#       8 _TEXT_BUCKET = "https://download.pytorch.org/models/text/"
#      10 _CACHE_DIR = os.path.expanduser(os.path.join(_get_torch_home(), "text"))
# ---> 12 from . import data, datasets, prototype, functional, models, nn, transforms, utils, vocab, experimental
#      14 try:
#      15     from .version import __version__, git_version  # noqa: F401
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/torchtext/datasets/__init__.py:3
#       1 import importlib
# ...

# %%
import spacy

spacy_en = spacy.load('en') # 영어 토큰화(tokenization)
spacy_de = spacy.load('de') # 독일어 토큰화(tokenization)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[6], line 3
#       1 import spacy
# ----> 3 spacy_en = spacy.load('en') # 영어 토큰화(tokenization)
#       4 spacy_de = spacy.load('de') # 독일어 토큰화(tokenization)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/spacy/__init__.py:54, in load(name, vocab, disable, enable, exclude, config)
#      30 def load(
#      31     name: Union[str, Path],
#      32     *,
#    (...)
#      37     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      38 ) -> Language:
#      39     """Load a spaCy model from an installed package or a local path.
#      40
#      41     name (str): Package name or model path.
#    (...)
#      52     RETURNS (Language): The loaded nlp object.
#      53     """
# ---> 54     return util.load_model(
#      55         name,
#      56         vocab=vocab,
# ...

# %%
torch.__version__
# Out:
# '1.13.1'

# %%
# !python -V
# Out:
# Python 3.9.15

# %%
# !pip install torchtext==0.14.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 31.9 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
# WARNING: Error parsing requirements for google-pasta: [Errno 2] No such file or directory: '/opt/homebrew/anaconda3/lib/python3.9/site-packages/google_pasta-0.2.0.dist-info/METADATA'
# ...
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.15.2
#     Uninstalling torchtext-0.15.2:
#       Successfully uninstalled torchtext-0.15.2
# ...

# %%
import torchtext
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import torchtext
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/torchtext/__init__.py:12
#       8 _TEXT_BUCKET = "https://download.pytorch.org/models/text/"
#      10 _CACHE_DIR = os.path.expanduser(os.path.join(_get_torch_home(), "text"))
# ---> 12 from . import data, datasets, prototype, functional, models, nn, transforms, utils, vocab, experimental
#      14 try:
#      15     from .version import __version__, git_version  # noqa: F401
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/torchtext/datasets/__init__.py:3
#       1 import importlib
# ----> 3 from .ag_news import AG_NEWS
#       4 from .amazonreviewfull import AmazonReviewFull
#       5 from .amazonreviewpolarity import AmazonReviewPolarity
#
# ...
